# %% [markdown]
# # Baseline with mse loss with wide cnn modified + adam
# #### Convert histone mark signals and use deep CNN for training.

# %% [markdown]
# #### NOTE: Need to activate genomelake environment before this code. Simply type 'genomelake' in terminal.

# %%
# %env CUDA_VISIBLE_DEVICES=6,7
import os, sys
sys.path.append("..")
import random
# custom file path package
from data import Data_Directories
# custom utility package
from utils.compute_util import *
# package for genomic data
from pybedtools import Interval, BedTool
from genomelake.extractors import ArrayExtractor, BigwigExtractor
# package for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats.stats import pearsonr,spearmanr
import tensorflow as tf
# Out:
# env: CUDA_VISIBLE_DEVICES=6,7
# Using TensorFlow backend.

# %%
window_size = 2001
process_all = False
sample_num = 1000

# %%
# retrieve data
data = Data_Directories()
print data.intervals.keys()
print data.input_atac['day0'].keys()
print data.output_histone['day0'].keys()
# Out:
# ['day6', 'day3', 'day0']
# ['100', '140']
# ['H3K27me3', 'H3K4me1', 'H3K27ac']

# %%
# get intervals for day0 data
day0_intervals = list(BedTool(data.intervals['day0']))
print '# of Intervals Extracted for day0: {}'.format(len(day0_intervals))
# Out:
# # of Intervals Extracted for day0: 267226

# %%
# create an ArrayExtractor for ATAC-seq for day0 with 140 base pairs
bw_140bp_day0 = ArrayExtractor(data.input_atac['day0']['140'])
print 'Finished extracting bigwig for day0, 140bp'
# Out:
# Finished extracting bigwig for day0, 140bp

# %%
# create a BigWigExtractor for histone makr 'H3K27ac' for day0
bw_histone_mark_day0 = BigwigExtractor(data.output_histone['day0']['H3K27ac'])
print 'Finished extracting bigwig for day0, 140bp'
# Out:
# Finished extracting bigwig for day0, 140bp

# %%
# normalize day0 intervals
normalized_day0_intervals = [normalize_interval(interval, window_size) for interval in day0_intervals if normalize_interval(interval, window_size)]
print 'Finished normalizing day0 intervals!'
# Out:
# Finished normalizing day0 intervals!

# %%
assert (len(day0_intervals)==len(normalized_day0_intervals))
print "Examples of original intervals"
print [(int(_interval.start)+int(_interval[-1]), [int(_interval.start), int(_interval.end)])
       for _interval in day0_intervals[:3]]
print "Examples of normalized intervals with window size of {}".format(window_size)
print [([int(_interval.start), int(_interval.end)])
       for _interval in  normalized_day0_intervals[:3]]
# Out:
# Examples of original intervals
# [(123412027, [123411855, 123412989]), (123411941, [123411855, 123412989]), (131908564, [131908487, 131910071])]
# Examples of normalized intervals with window size of 2001
# [[123411027, 123413028], [123410941, 123412942], [131907564, 131909565]]

# %%
atac_seq_day0 = bw_140bp_day0(normalized_day0_intervals)
print atac_seq_day0.shape
# Out:
# (267226, 2001, 5)

# %%
#TODO: put this into utils if possible
def prune_invalid_intervals(intervals, bigwig_file):
    for _interval in intervals[:]:
        try:
            bigwig_file([_interval])
        except:
            intervals.remove(_interval)
            pass
        
print "Before pruning day0: {}".format(len(normalized_day0_intervals))
prune_invalid_intervals(normalized_day0_intervals, bw_140bp_day0)
print "After pruning day0: {}".format(len(normalized_day0_intervals))
# Out:
# Before pruning day0: 267226
# After pruning day0: 267226

# %%
print "Dimension of ATAC-seq signal: {}".format(bw_140bp_day0(normalized_day0_intervals[:1]).shape)
# Out:
# Dimension of ATAC-seq signal: (1, 2001, 5)

# %%
print "Dimension of histone mark signal: {}".format(bw_histone_mark_day0(normalized_day0_intervals[:1]).shape)
# Out:
# Dimension of histone mark signal: (1, 2001)

# %%
# replace nan values with zeros and convert it to p-values
histone_mark_day0 = np.nan_to_num(bw_histone_mark_day0(normalized_day0_intervals))
print histone_mark_day0.shape
# Out:
# (267226, 2001)

# %%
histone_mark_day0 = np.expand_dims(histone_mark_day0, axis=2)
print histone_mark_day0.shape
# Out:
# (267226, 2001, 1)

# %%
print "Example histone mark signal"
print "\tRaw value: {}".format(bw_histone_mark_day0(normalized_day0_intervals[:1])[0][:5].reshape(-1))
# Out:
# Example histone mark signal
# 	Raw value: [ 0.01014  0.01014  0.01014  0.02435  0.02435]

# %%
from keras.layers import Input, Dense, Conv1D, Dropout
from keras.models import Model
from keras import optimizers
from keras import metrics
from keras import losses
from keras import backend as K
from keras.callbacks import Callback, TensorBoard, ReduceLROnPlateau, ModelCheckpoint

# %%
dropout_rate = 0.5
# parameters for first conv layer
hidden_filters_1 = 32
hidden_kernel_size_1 = 2001
# parameters for second conv layer
output_filters = 1
output_kernel_size = 16
# parameters for training
batch_size = 128
num_epochs = 300
evaluation_freq = 10

# %%
'''
Baseline CNN (based on KERAS functional API)
'''
inputs = Input(shape=(window_size, 5, ))
x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1)(inputs)
x = Dropout(dropout_rate)(x)

outputs = Conv1D(
    filters=output_filters,
    kernel_size=output_kernel_size,
    padding='same',
    activation='linear',
    strides=1
    )(x)

model = Model(inputs=inputs, outputs=outputs)

# %%
# Print out model summary
print model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 2001, 5)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2001, 32)          320192
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2001, 32)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 2001, 1)           513
# =================================================================
# Total params: 320,705
# Trainable params: 320,705
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def pearson(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = K.mean(x)
    my = K.mean(y)
    xm, ym = x-mx, y-my
    r_num = K.sum(np.multiply(xm,ym))
    r_den = K.sqrt(np.multiply(K.sum(K.square(xm)), K.sum(K.square(ym))))
    r = r_num / r_den
    r = K.maximum(K.minimum(r, 1.0), -1.0)
    return K.square(r)

# %%
# Helper functions for writing the scores into bigwig file
from itertools import izip
from itertools import groupby
import subprocess

def interval_key(interval):
    return (interval.chrom, interval.start, interval.stop)

def merged_scores(scores, intervals, merge_type):
    # A generator that returns merged intervals/scores
    # Scores should have shape: #examples x #categories x #interval_size
    # Second dimension can be omitted for a 1D signal
    signal_dims = scores.ndim - 1
    assert signal_dims in {1, 2}

    # Only support max for now
    assert merge_type == 'max'
    score_first_dim = 1 if signal_dims == 1 else scores.shape[1]

    dtype = scores.dtype

    sort_idx, sorted_intervals = \
        zip(*sorted(enumerate(intervals),
                    key=lambda item: interval_key(item[1])))
    sorted_intervals = BedTool(sorted_intervals)

    # Require at least 1bp overlap
    # Explicitly convert to list otherwise it will keep opening a file when
    # retrieving an index resulting in an error (too many open files)
    interval_clust = list(sorted_intervals.cluster(d=-1))
    for _, group in groupby(izip(sort_idx, interval_clust),
                            key=lambda item: item[1].fields[-1]):
        idx_interval_pairs = list(group)
        group_idx, group_intervals = zip(*idx_interval_pairs)

        if len(idx_interval_pairs) == 1:
            yield group_intervals[0], scores[group_idx[0], ...]
        else:
            group_chrom = group_intervals[0].chrom
            group_start = min(interval.start for interval in group_intervals)
            group_stop = max(interval.stop for interval in group_intervals)

            # This part needs to change to support more merge_types (e.g. mean)
            group_score = np.full((score_first_dim, group_stop - group_start),
                                  -np.inf, dtype)
            for idx, interval in idx_interval_pairs:
                slice_start = interval.start - group_start
                slice_stop = slice_start + (interval.stop - interval.start)
                group_score[..., slice_start:slice_stop] = \
                    np.maximum(group_score[..., slice_start:slice_stop],
                               scores[idx, ...])
            if signal_dims == 1:
                group_score = group_score.squeeze(axis=0)
            yield Interval(group_chrom, group_start, group_stop), group_score
            
def interval_score_pairs(intervals, scores, merge_type):
    return (izip(intervals, scores) if merge_type is None
            else merged_scores(scores, intervals, merge_type))

def _write_1D_deeplift_track(scores, intervals, file_prefix, merge_type='max',
                             CHROM_SIZES='/mnt/data/annotations/by_release/hg19.GRCh37/hg19.chrom.sizes'):
    assert scores.ndim == 2

    bedgraph = file_prefix + '.bedGraph'
    bigwig = file_prefix + '.bw'

    print 'Writing 1D track of shape: {}'.format(scores.shape)
    print 'Writing to file: {}'.format(bigwig)

    with open(bedgraph, 'w') as fp:
        for interval, score in interval_score_pairs(intervals, scores,
                                                    merge_type):
            chrom = interval.chrom
            start = interval.start
            for score_idx, val in enumerate(score):
                fp.write('%s\t%d\t%d\t%g\n' % (chrom,
                                               start + score_idx,
                                               start + score_idx + 1,
                                               val))
    print 'Wrote bedgraph.'

    try:
        output = subprocess.check_output(
            ['wigToBigWig', bedgraph, CHROM_SIZES, bigwig],
            stderr=subprocess.STDOUT)
        print 'wigToBigWig output: {}'.format(output)
    except subprocess.CalledProcessError as e:
        print 'wigToBigWig terminated with exit code {}'.format(
            e.returncode)
        print 'output was:\n' + e.output

    print 'Wrote bigwig.'

# %%
model_dir = os.path.join("models", "mse_lowlr")
log_dir = os.path.join("logs", "mse_lowlr")
srv_dir = os.path.join("/srv", "www", "kundaje", "jesikmin", "mse_lowlr")
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
if not os.path.exists(log_dir):
    os.makedirs(log_dir)
if not os.path.exists(srv_dir):
    os.makedirs(srv_dir)

# %%
# setting an adam optimizer with 1.0 clip norm
adam = optimizers.Adam(lr=0.0001, clipnorm=1.)

print "Compiling a model with adam optimizer"
model.compile(loss=losses.mean_squared_error,
              optimizer=adam,
              metrics=[pearson, metrics.mse, metrics.mae])
# Out:
# Compiling a model with adam optimizer

# %%
# CallBack: tensorboard with grad histogram
tensorboard = TensorBoard(log_dir=log_dir,
                          histogram_freq=1,
                          batch_size=batch_size,
                          write_grads=True)

# %%
# CallBack: reduce learning rate when validation loss meets plateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.96,
                              patience=5,
                              min_lr=1e-7)

# %%
# CallBack: evaluate model for every evaulation epoch
class EvaluateModel(Callback):
    def __init__(self, X_test, y_test):
        self.X_test, self.y_test = X_test, y_test
        self.epochs = 0

    def on_epoch_end(self, batch, logs={}):
        self.epochs += 1
        # evaluate the model
        if self.epochs % evaluation_freq == 0:
            scores = model.evaluate(X_test, y_test)
            print zip(model.metrics_names, scores)
            test_prediction = model.predict(X_test)
            test_spearman_sum = 0.0
            for idx, _pred in enumerate(test_prediction):
                rho, _ = spearmanr(histone_mark_day0[10000+idx], _pred)
                test_spearman_sum += rho
            print "Test spearman: {}".format(test_spearman_sum * 1.0 / 1000)

# %%
# CallBack: store bigwig file for the best model
class SaveBigwig(Callback):
    def __init__(self, X_train, y_train, X_val, y_val, X_test, y_test):
        self.best_val_loss = float('Inf')
        self.best_epoch = -1
        self.X_train, self.y_train = X_train, y_train
        self.X_val, self.y_val = X_val, y_val
        self.X_test, self.y_test = X_test, y_test
        self.epochs = 0
    
    def on_epoch_end(self, batch, logs={}):
        self.epochs += 1
        cur_val_loss = logs['val_loss']
        if cur_val_loss < self.best_val_loss:
            self.best_val_loss = cur_val_loss
            self.best_epoch = self.epochs
            prediction = model.predict(X_train).reshape(7500, 2001)
            _write_1D_deeplift_track(prediction,
                                     normalized_day0_intervals[:7500], os.path.join(srv_dir, 'train'))
            prediction = model.predict(X_val).reshape(2500, 2001)
            _write_1D_deeplift_track(prediction,
                                     normalized_day0_intervals[7500:10000], os.path.join(srv_dir, 'val'))
            prediction = model.predict(X_test).reshape(1000, 2001)
            _write_1D_deeplift_track(prediction,
                                     normalized_day0_intervals[10000:11000], os.path.join(srv_dir, 'test'))
            f = open(os.path.join(srv_dir, 'meta.txt'), 'wb')
            f.write(str(self.epochs) + "  " + str(logs))
            f.close()

# %%
# CallBack: Save model checkpoint based on validation loss
checkpointer = ModelCheckpoint(os.path.join(model_dir, "best_model.h5"),
                               monitor='val_loss',
                               verbose=1,
                               save_best_only=True,
                               mode='min')

# %%
print "Fitting the model..."
X_train, y_train = atac_seq_day0[:7500], histone_mark_day0[:7500]
X_val, y_val = atac_seq_day0[7500:10000], histone_mark_day0[7500:10000]
X_test, y_test = atac_seq_day0[10000:11000], histone_mark_day0[10000:11000]

model.fit(atac_seq_day0[:10000],
          histone_mark_day0[:10000],
          batch_size=batch_size,
          epochs=num_epochs,
          validation_split=0.25,   
          #shuffle=True,
          callbacks=[tensorboard,
                     reduce_lr,
                     EvaluateModel(X_test, y_test),
                     checkpointer,
                     SaveBigwig(X_train, y_train, X_val, y_val, X_test, y_test)])
# Out:
# Fitting the model...
# Train on 7500 samples, validate on 2500 samples
# Epoch 1/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 434.6080 - pearson: 0.0894 - mean_squared_error: 434.6080 - mean_absolute_error: 7.8092
# Epoch 00001: val_loss improved from inf to 171.37028, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 151s 20ms/step - loss: 433.7566 - pearson: 0.0894 - mean_squared_error: 433.7566 - mean_absolute_error: 7.8119 - val_loss: 171.3703 - val_pearson: 0.1210 - val_mean_squared_error: 171.3703 - val_mean_absolute_error: 4.4525
# Epoch 2/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 399.6508 - pearson: 0.1382 - mean_squared_error: 399.6508 - mean_absolute_error: 8.1119
# Epoch 00002: val_loss improved from 171.37028 to 167.59067, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 156s 21ms/step - loss: 398.5237 - pearson: 0.1382 - mean_squared_error: 398.5237 - mean_absolute_error: 8.1017 - val_loss: 167.5907 - val_pearson: 0.1355 - val_mean_squared_error: 167.5907 - val_mean_absolute_error: 4.3292
# Epoch 3/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 389.8548 - pearson: 0.1544 - mean_squared_error: 389.8548 - mean_absolute_error: 7.9829
# Epoch 00003: val_loss improved from 167.59067 to 166.33650, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 155s 21ms/step - loss: 389.8702 - pearson: 0.1553 - mean_squared_error: 389.8702 - mean_absolute_error: 7.9716 - val_loss: 166.3365 - val_pearson: 0.1469 - val_mean_squared_error: 166.3365 - val_mean_absolute_error: 4.0869
# Epoch 4/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 382.5392 - pearson: 0.1716 - mean_squared_error: 382.5392 - mean_absolute_error: 7.8277
# Epoch 00004: val_loss improved from 166.33650 to 163.59916, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 151s 20ms/step - loss: 384.5987 - pearson: 0.1718 - mean_squared_error: 384.5987 - mean_absolute_error: 7.8531 - val_loss: 163.5992 - val_pearson: 0.1515 - val_mean_squared_error: 163.5992 - val_mean_absolute_error: 4.1737
# Epoch 5/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 379.0326 - pearson: 0.1792 - mean_squared_error: 379.0326 - mean_absolute_error: 7.8436
# Epoch 00005: val_loss improved from 163.59916 to 162.49422, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 153s 20ms/step - loss: 379.7344 - pearson: 0.1788 - mean_squared_error: 379.7344 - mean_absolute_error: 7.8521 - val_loss: 162.4942 - val_pearson: 0.1548 - val_mean_squared_error: 162.4942 - val_mean_absolute_error: 4.1540
# Epoch 6/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 377.5955 - pearson: 0.1843 - mean_squared_error: 377.5955 - mean_absolute_error: 7.8388
# Epoch 00006: val_loss improved from 162.49422 to 161.58796, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 150s 20ms/step - loss: 376.9441 - pearson: 0.1848 - mean_squared_error: 376.9441 - mean_absolute_error: 7.8302 - val_loss: 161.5880 - val_pearson: 0.1571 - val_mean_squared_error: 161.5880 - val_mean_absolute_error: 4.1870
# Epoch 7/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 376.6813 - pearson: 0.1899 - mean_squared_error: 376.6813 - mean_absolute_error: 7.8900
# Epoch 00007: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 375.5509 - pearson: 0.1903 - mean_squared_error: 375.5509 - mean_absolute_error: 7.8776 - val_loss: 161.6041 - val_pearson: 0.1581 - val_mean_squared_error: 161.6041 - val_mean_absolute_error: 4.1091
# Epoch 8/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 376.8843 - pearson: 0.1902 - mean_squared_error: 376.8843 - mean_absolute_error: 7.9599
# Epoch 00008: val_loss improved from 161.58796 to 161.02376, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 153s 20ms/step - loss: 374.7417 - pearson: 0.1902 - mean_squared_error: 374.7417 - mean_absolute_error: 7.9424 - val_loss: 161.0238 - val_pearson: 0.1572 - val_mean_squared_error: 161.0238 - val_mean_absolute_error: 4.5482
# Epoch 9/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 371.7273 - pearson: 0.1896 - mean_squared_error: 371.7273 - mean_absolute_error: 7.9023
# Epoch 00009: val_loss improved from 161.02376 to 160.44870, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 151s 20ms/step - loss: 373.7334 - pearson: 0.1914 - mean_squared_error: 373.7334 - mean_absolute_error: 7.9153 - val_loss: 160.4487 - val_pearson: 0.1599 - val_mean_squared_error: 160.4487 - val_mean_absolute_error: 4.2672
# Epoch 10/300
# 1000/1000 [==============================] - 1s 636us/steps: 370.5771 - pearson: 0.1924 - mean_squared_error: 370.5771 - mean_
# [('loss', 198.6124132232666), ('pearson', 0.27346986275911334), ('mean_squared_error', 198.61241351318358), ('mean_absolute_error', 5.1652755222320561)]
# Test spearman: 0.338485054984
#
# Epoch 00010: val_loss did not improve
# 7500/7500 [==============================] - 21s 3ms/step - loss: 372.8790 - pearson: 0.1924 - mean_squared_error: 372.8790 - mean_absolute_error: 7.9192 - val_loss: 160.9130 - val_pearson: 0.1605 - val_mean_squared_error: 160.9130 - val_mean_absolute_error: 4.1118
# Epoch 11/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 371.6963 - pearson: 0.1947 - mean_squared_error: 371.6963 - mean_absolute_error: 7.8779
# Epoch 00011: val_loss improved from 160.44870 to 160.18498, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 153s 20ms/step - loss: 372.7766 - pearson: 0.1934 - mean_squared_error: 372.7766 - mean_absolute_error: 7.8882 - val_loss: 160.1850 - val_pearson: 0.1612 - val_mean_squared_error: 160.1850 - val_mean_absolute_error: 4.2920
# Epoch 12/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 368.9765 - pearson: 0.1967 - mean_squared_error: 368.9765 - mean_absolute_error: 7.8566
# Epoch 00012: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 372.1577 - pearson: 0.1961 - mean_squared_error: 372.1577 - mean_absolute_error: 7.8754 - val_loss: 160.9434 - val_pearson: 0.1597 - val_mean_squared_error: 160.9434 - val_mean_absolute_error: 4.1282
# Epoch 13/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 372.8257 - pearson: 0.1983 - mean_squared_error: 372.8257 - mean_absolute_error: 7.9637
# Epoch 00013: val_loss improved from 160.18498 to 159.78239, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 151s 20ms/step - loss: 371.6936 - pearson: 0.1982 - mean_squared_error: 371.6935 - mean_absolute_error: 7.9546 - val_loss: 159.7824 - val_pearson: 0.1619 - val_mean_squared_error: 159.7824 - val_mean_absolute_error: 4.4938
# Epoch 14/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 372.1390 - pearson: 0.1955 - mean_squared_error: 372.1390 - mean_absolute_error: 7.8420
# Epoch 00014: val_loss improved from 159.78239 to 159.72521, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 151s 20ms/step - loss: 371.4142 - pearson: 0.1968 - mean_squared_error: 371.4142 - mean_absolute_error: 7.8351 - val_loss: 159.7252 - val_pearson: 0.1625 - val_mean_squared_error: 159.7252 - val_mean_absolute_error: 4.4176
# Epoch 15/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 371.2923 - pearson: 0.1940 - mean_squared_error: 371.2923 - mean_absolute_error: 7.9629
# Epoch 00015: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 370.8781 - pearson: 0.1948 - mean_squared_error: 370.8781 - mean_absolute_error: 7.9648 - val_loss: 160.0190 - val_pearson: 0.1630 - val_mean_squared_error: 160.0190 - val_mean_absolute_error: 4.1641
# Epoch 16/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 368.3333 - pearson: 0.1963 - mean_squared_error: 368.3334 - mean_absolute_error: 7.8390
# Epoch 00016: val_loss improved from 159.72521 to 159.59014, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 156s 21ms/step - loss: 369.5613 - pearson: 0.1963 - mean_squared_error: 369.5613 - mean_absolute_error: 7.8521 - val_loss: 159.5901 - val_pearson: 0.1631 - val_mean_squared_error: 159.5901 - val_mean_absolute_error: 4.4068
# Epoch 17/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 372.6707 - pearson: 0.2037 - mean_squared_error: 372.6707 - mean_absolute_error: 8.0723
# Epoch 00017: val_loss improved from 159.59014 to 159.38751, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 155s 21ms/step - loss: 370.6125 - pearson: 0.2028 - mean_squared_error: 370.6125 - mean_absolute_error: 8.0614 - val_loss: 159.3875 - val_pearson: 0.1640 - val_mean_squared_error: 159.3875 - val_mean_absolute_error: 4.2594
# Epoch 18/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 368.8702 - pearson: 0.2000 - mean_squared_error: 368.8702 - mean_absolute_error: 7.8803
# Epoch 00018: val_loss improved from 159.38751 to 159.28899, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 155s 21ms/step - loss: 368.8470 - pearson: 0.1997 - mean_squared_error: 368.8469 - mean_absolute_error: 7.8851 - val_loss: 159.2890 - val_pearson: 0.1646 - val_mean_squared_error: 159.2890 - val_mean_absolute_error: 4.3028
# Epoch 19/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 367.8767 - pearson: 0.2042 - mean_squared_error: 367.8767 - mean_absolute_error: 7.7965
# Epoch 00019: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 368.6719 - pearson: 0.2037 - mean_squared_error: 368.6719 - mean_absolute_error: 7.8088 - val_loss: 159.5458 - val_pearson: 0.1650 - val_mean_squared_error: 159.5458 - val_mean_absolute_error: 4.1968
# Epoch 20/300
# 1000/1000 [==============================] - 1s 648us/steps: 367.5577 - pearson: 0.2006 - mean_squared_error: 367.5577 - mean_
# [('loss', 195.16454814147949), ('pearson', 0.28008484148979185), ('mean_squared_error', 195.16454748535156), ('mean_absolute_error', 5.5444767799377441)]
# Test spearman: 0.333710609383
#
# Epoch 00020: val_loss improved from 159.28899 to 158.61994, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 156s 21ms/step - loss: 367.7121 - pearson: 0.2028 - mean_squared_error: 367.7121 - mean_absolute_error: 7.9262 - val_loss: 158.6199 - val_pearson: 0.1671 - val_mean_squared_error: 158.6199 - val_mean_absolute_error: 4.4551
# Epoch 21/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 367.2261 - pearson: 0.2016 - mean_squared_error: 367.2261 - mean_absolute_error: 7.8996
# Epoch 00021: val_loss did not improve
# 7500/7500 [==============================] - 19s 2ms/step - loss: 367.2314 - pearson: 0.2028 - mean_squared_error: 367.2314 - mean_absolute_error: 7.8991 - val_loss: 159.1259 - val_pearson: 0.1654 - val_mean_squared_error: 159.1259 - val_mean_absolute_error: 4.3085
# Epoch 22/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 367.4291 - pearson: 0.2098 - mean_squared_error: 367.4291 - mean_absolute_error: 8.0325
# Epoch 00022: val_loss improved from 158.61994 to 158.33267, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 153s 20ms/step - loss: 367.1680 - pearson: 0.2094 - mean_squared_error: 367.1680 - mean_absolute_error: 8.0344 - val_loss: 158.3327 - val_pearson: 0.1677 - val_mean_squared_error: 158.3327 - val_mean_absolute_error: 4.4537
# Epoch 23/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 366.4293 - pearson: 0.2050 - mean_squared_error: 366.4293 - mean_absolute_error: 7.8509
# Epoch 00023: val_loss did not improve
# 7500/7500 [==============================] - 19s 2ms/step - loss: 365.9584 - pearson: 0.2043 - mean_squared_error: 365.9584 - mean_absolute_error: 7.8521 - val_loss: 158.3815 - val_pearson: 0.1686 - val_mean_squared_error: 158.3815 - val_mean_absolute_error: 4.4961
# Epoch 24/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 359.9643 - pearson: 0.2128 - mean_squared_error: 359.9643 - mean_absolute_error: 7.8537
# Epoch 00024: val_loss improved from 158.33267 to 158.18772, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 156s 21ms/step - loss: 365.3322 - pearson: 0.2127 - mean_squared_error: 365.3322 - mean_absolute_error: 7.8881 - val_loss: 158.1877 - val_pearson: 0.1695 - val_mean_squared_error: 158.1877 - val_mean_absolute_error: 4.3035
# Epoch 25/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 359.8634 - pearson: 0.2126 - mean_squared_error: 359.8634 - mean_absolute_error: 7.8123
# Epoch 00025: val_loss did not improve
# 7500/7500 [==============================] - 19s 2ms/step - loss: 363.9171 - pearson: 0.2119 - mean_squared_error: 363.9171 - mean_absolute_error: 7.8307 - val_loss: 160.1999 - val_pearson: 0.1680 - val_mean_squared_error: 160.1999 - val_mean_absolute_error: 4.9427
# Epoch 26/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 367.2498 - pearson: 0.2148 - mean_squared_error: 367.2498 - mean_absolute_error: 8.0378
# Epoch 00026: val_loss did not improve
# 7500/7500 [==============================] - 19s 3ms/step - loss: 366.0338 - pearson: 0.2150 - mean_squared_error: 366.0338 - mean_absolute_error: 8.0239 - val_loss: 158.5117 - val_pearson: 0.1695 - val_mean_squared_error: 158.5117 - val_mean_absolute_error: 4.7131
# Epoch 27/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 364.4842 - pearson: 0.2142 - mean_squared_error: 364.4842 - mean_absolute_error: 8.0306
# Epoch 00027: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 364.1314 - pearson: 0.2130 - mean_squared_error: 364.1314 - mean_absolute_error: 8.0307 - val_loss: 159.2440 - val_pearson: 0.1699 - val_mean_squared_error: 159.2440 - val_mean_absolute_error: 4.0551
# Epoch 28/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 365.5223 - pearson: 0.2160 - mean_squared_error: 365.5223 - mean_absolute_error: 7.8299
# Epoch 00028: val_loss improved from 158.18772 to 157.65052, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 147s 20ms/step - loss: 364.0941 - pearson: 0.2162 - mean_squared_error: 364.0941 - mean_absolute_error: 7.8235 - val_loss: 157.6505 - val_pearson: 0.1717 - val_mean_squared_error: 157.6505 - val_mean_absolute_error: 4.4695
# Epoch 29/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 357.9920 - pearson: 0.2202 - mean_squared_error: 357.9920 - mean_absolute_error: 7.8709
# Epoch 00029: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 362.1143 - pearson: 0.2184 - mean_squared_error: 362.1143 - mean_absolute_error: 7.8932 - val_loss: 157.6744 - val_pearson: 0.1720 - val_mean_squared_error: 157.6744 - val_mean_absolute_error: 4.3757
# Epoch 30/300
# 1000/1000 [==============================] - 1s 647us/steps: 361.2692 - pearson: 0.2141 - mean_squared_error: 361.2692 - mean_
# [('loss', 194.49035906982422), ('pearson', 0.28678688472509384), ('mean_squared_error', 194.4903529510498), ('mean_absolute_error', 5.2390315704345705)]
# Test spearman: 0.314288369862
#
# Epoch 00030: val_loss did not improve
# 7500/7500 [==============================] - 21s 3ms/step - loss: 362.8486 - pearson: 0.2126 - mean_squared_error: 362.8486 - mean_absolute_error: 7.9063 - val_loss: 157.8831 - val_pearson: 0.1725 - val_mean_squared_error: 157.8831 - val_mean_absolute_error: 4.2284
# Epoch 31/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 363.2011 - pearson: 0.2174 - mean_squared_error: 363.2011 - mean_absolute_error: 7.8717
# Epoch 00031: val_loss did not improve
# 7500/7500 [==============================] - 19s 3ms/step - loss: 361.7485 - pearson: 0.2168 - mean_squared_error: 361.7484 - mean_absolute_error: 7.8565 - val_loss: 157.9064 - val_pearson: 0.1727 - val_mean_squared_error: 157.9064 - val_mean_absolute_error: 4.2127
# Epoch 32/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 364.2134 - pearson: 0.2149 - mean_squared_error: 364.2134 - mean_absolute_error: 7.9335
# Epoch 00032: val_loss did not improve
# 7500/7500 [==============================] - 19s 2ms/step - loss: 362.9164 - pearson: 0.2146 - mean_squared_error: 362.9164 - mean_absolute_error: 7.9109 - val_loss: 158.3215 - val_pearson: 0.1720 - val_mean_squared_error: 158.3215 - val_mean_absolute_error: 4.1842
# Epoch 33/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 357.8358 - pearson: 0.2230 - mean_squared_error: 357.8358 - mean_absolute_error: 7.8230
# Epoch 00033: val_loss did not improve
# 7500/7500 [==============================] - 19s 3ms/step - loss: 361.0989 - pearson: 0.2225 - mean_squared_error: 361.0989 - mean_absolute_error: 7.8491 - val_loss: 158.8817 - val_pearson: 0.1728 - val_mean_squared_error: 158.8817 - val_mean_absolute_error: 4.0836
# Epoch 34/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 363.6338 - pearson: 0.2181 - mean_squared_error: 363.6338 - mean_absolute_error: 7.9422
# Epoch 00034: val_loss improved from 157.65052 to 157.29764, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 157s 21ms/step - loss: 362.0199 - pearson: 0.2196 - mean_squared_error: 362.0199 - mean_absolute_error: 7.9327 - val_loss: 157.2976 - val_pearson: 0.1742 - val_mean_squared_error: 157.2976 - val_mean_absolute_error: 4.3329
# Epoch 35/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 359.2269 - pearson: 0.2155 - mean_squared_error: 359.2269 - mean_absolute_error: 7.9098
# Epoch 00035: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 360.6993 - pearson: 0.2150 - mean_squared_error: 360.6993 - mean_absolute_error: 7.9063 - val_loss: 158.1853 - val_pearson: 0.1741 - val_mean_squared_error: 158.1853 - val_mean_absolute_error: 4.1480
# Epoch 36/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 351.9299 - pearson: 0.2168 - mean_squared_error: 351.9299 - mean_absolute_error: 7.8251
# Epoch 00036: val_loss did not improve
# 7500/7500 [==============================] - 19s 2ms/step - loss: 360.2254 - pearson: 0.2170 - mean_squared_error: 360.2254 - mean_absolute_error: 7.8763 - val_loss: 160.2315 - val_pearson: 0.1721 - val_mean_squared_error: 160.2315 - val_mean_absolute_error: 4.0124
# Epoch 37/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 357.3543 - pearson: 0.2234 - mean_squared_error: 357.3543 - mean_absolute_error: 7.8510
# Epoch 00037: val_loss did not improve
# 7500/7500 [==============================] - 19s 2ms/step - loss: 359.0369 - pearson: 0.2230 - mean_squared_error: 359.0369 - mean_absolute_error: 7.8750 - val_loss: 157.4455 - val_pearson: 0.1734 - val_mean_squared_error: 157.4455 - val_mean_absolute_error: 4.5823
# Epoch 38/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 360.7407 - pearson: 0.2262 - mean_squared_error: 360.7407 - mean_absolute_error: 7.9145
# Epoch 00038: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 359.7095 - pearson: 0.2259 - mean_squared_error: 359.7095 - mean_absolute_error: 7.9020 - val_loss: 157.9389 - val_pearson: 0.1734 - val_mean_squared_error: 157.9389 - val_mean_absolute_error: 4.2137
# Epoch 39/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 356.8451 - pearson: 0.2270 - mean_squared_error: 356.8450 - mean_absolute_error: 7.9306
# Epoch 00039: val_loss did not improve
# 7500/7500 [==============================] - 19s 2ms/step - loss: 358.7588 - pearson: 0.2255 - mean_squared_error: 358.7588 - mean_absolute_error: 7.9434 - val_loss: 158.7718 - val_pearson: 0.1727 - val_mean_squared_error: 158.7718 - val_mean_absolute_error: 4.1389
# Epoch 40/300
# 1000/1000 [==============================] - 1s 651us/steps: 356.8684 - pearson: 0.2313 - mean_squared_error: 356.8684 - mean_
# [('loss', 193.13625926208496), ('pearson', 0.28737254232168197), ('mean_squared_error', 193.13625567626954), ('mean_absolute_error', 5.7245775070190428)]
# Test spearman: 0.32055673251
#
# Epoch 00040: val_loss did not improve
# 7500/7500 [==============================] - 21s 3ms/step - loss: 358.6586 - pearson: 0.2298 - mean_squared_error: 358.6586 - mean_absolute_error: 7.8002 - val_loss: 157.2995 - val_pearson: 0.1746 - val_mean_squared_error: 157.2995 - val_mean_absolute_error: 4.6639
# Epoch 41/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 359.1693 - pearson: 0.2285 - mean_squared_error: 359.1693 - mean_absolute_error: 7.9641
# Epoch 00041: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 358.0826 - pearson: 0.2273 - mean_squared_error: 358.0826 - mean_absolute_error: 7.9538 - val_loss: 157.5716 - val_pearson: 0.1747 - val_mean_squared_error: 157.5716 - val_mean_absolute_error: 4.2322
# Epoch 42/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 357.9960 - pearson: 0.2253 - mean_squared_error: 357.9960 - mean_absolute_error: 7.8487
# Epoch 00042: val_loss did not improve
# 7500/7500 [==============================] - 19s 2ms/step - loss: 358.2740 - pearson: 0.2249 - mean_squared_error: 358.2740 - mean_absolute_error: 7.8542 - val_loss: 157.5330 - val_pearson: 0.1750 - val_mean_squared_error: 157.5330 - val_mean_absolute_error: 4.3745
# Epoch 43/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 360.4425 - pearson: 0.2257 - mean_squared_error: 360.4425 - mean_absolute_error: 7.9364
# Epoch 00043: val_loss improved from 157.29764 to 157.06102, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 158s 21ms/step - loss: 358.2733 - pearson: 0.2254 - mean_squared_error: 358.2733 - mean_absolute_error: 7.9149 - val_loss: 157.0610 - val_pearson: 0.1753 - val_mean_squared_error: 157.0610 - val_mean_absolute_error: 4.5492
# Epoch 44/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 355.5135 - pearson: 0.2252 - mean_squared_error: 355.5135 - mean_absolute_error: 7.9124
# Epoch 00044: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 357.3525 - pearson: 0.2256 - mean_squared_error: 357.3525 - mean_absolute_error: 7.9379 - val_loss: 157.4590 - val_pearson: 0.1753 - val_mean_squared_error: 157.4590 - val_mean_absolute_error: 4.7337
# Epoch 45/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 357.8983 - pearson: 0.2281 - mean_squared_error: 357.8983 - mean_absolute_error: 8.0178
# Epoch 00045: val_loss improved from 157.06102 to 156.97553, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 154s 21ms/step - loss: 356.4830 - pearson: 0.2281 - mean_squared_error: 356.4830 - mean_absolute_error: 7.9985 - val_loss: 156.9755 - val_pearson: 0.1757 - val_mean_squared_error: 156.9755 - val_mean_absolute_error: 4.4131
# Epoch 46/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 351.9993 - pearson: 0.2235 - mean_squared_error: 351.9993 - mean_absolute_error: 7.9162
# Epoch 00046: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 356.4929 - pearson: 0.2256 - mean_squared_error: 356.4929 - mean_absolute_error: 7.9566 - val_loss: 157.0199 - val_pearson: 0.1754 - val_mean_squared_error: 157.0199 - val_mean_absolute_error: 4.4152
# Epoch 47/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 356.9293 - pearson: 0.2268 - mean_squared_error: 356.9293 - mean_absolute_error: 7.9903
# Epoch 00047: val_loss improved from 156.97553 to 156.94171, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 155s 21ms/step - loss: 356.5430 - pearson: 0.2273 - mean_squared_error: 356.5430 - mean_absolute_error: 7.9836 - val_loss: 156.9417 - val_pearson: 0.1761 - val_mean_squared_error: 156.9417 - val_mean_absolute_error: 4.5413
# Epoch 48/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 357.6200 - pearson: 0.2312 - mean_squared_error: 357.6200 - mean_absolute_error: 7.8791
# Epoch 00048: val_loss improved from 156.94171 to 156.82885, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 153s 20ms/step - loss: 355.7168 - pearson: 0.2326 - mean_squared_error: 355.7168 - mean_absolute_error: 7.8632 - val_loss: 156.8289 - val_pearson: 0.1766 - val_mean_squared_error: 156.8288 - val_mean_absolute_error: 4.4906
# Epoch 49/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 355.4856 - pearson: 0.2266 - mean_squared_error: 355.4856 - mean_absolute_error: 7.8490
# Epoch 00049: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 355.2602 - pearson: 0.2286 - mean_squared_error: 355.2602 - mean_absolute_error: 7.8476 - val_loss: 157.6140 - val_pearson: 0.1753 - val_mean_squared_error: 157.6139 - val_mean_absolute_error: 4.7781
# Epoch 50/300
# 1000/1000 [==============================] - 1s 646us/steps: 354.8645 - pearson: 0.2316 - mean_squared_error: 354.8645 - mean_
# [('loss', 192.67394450378418), ('pearson', 0.28881532424688339), ('mean_squared_error', 192.67395536804199), ('mean_absolute_error', 5.7072371082305908)]
# Test spearman: 0.318087035213
#
# Epoch 00050: val_loss did not improve
# 7500/7500 [==============================] - 21s 3ms/step - loss: 355.0401 - pearson: 0.2317 - mean_squared_error: 355.0401 - mean_absolute_error: 7.9996 - val_loss: 157.0262 - val_pearson: 0.1765 - val_mean_squared_error: 157.0262 - val_mean_absolute_error: 4.6666
# Epoch 51/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 357.1532 - pearson: 0.2333 - mean_squared_error: 357.1532 - mean_absolute_error: 7.9884
# Epoch 00051: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 355.2920 - pearson: 0.2322 - mean_squared_error: 355.2920 - mean_absolute_error: 7.9769 - val_loss: 157.2467 - val_pearson: 0.1769 - val_mean_squared_error: 157.2467 - val_mean_absolute_error: 4.7357
# Epoch 52/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 354.8250 - pearson: 0.2315 - mean_squared_error: 354.8250 - mean_absolute_error: 7.9113
# Epoch 00052: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 353.9303 - pearson: 0.2319 - mean_squared_error: 353.9303 - mean_absolute_error: 7.8964 - val_loss: 157.2914 - val_pearson: 0.1763 - val_mean_squared_error: 157.2914 - val_mean_absolute_error: 4.3019
# Epoch 53/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 351.2554 - pearson: 0.2329 - mean_squared_error: 351.2553 - mean_absolute_error: 7.8782
# Epoch 00053: val_loss did not improve
# 7500/7500 [==============================] - 19s 2ms/step - loss: 353.9517 - pearson: 0.2325 - mean_squared_error: 353.9517 - mean_absolute_error: 7.9033 - val_loss: 156.8687 - val_pearson: 0.1764 - val_mean_squared_error: 156.8687 - val_mean_absolute_error: 4.6591
# Epoch 54/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 355.4898 - pearson: 0.2315 - mean_squared_error: 355.4898 - mean_absolute_error: 7.9771
# Epoch 00054: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 354.8485 - pearson: 0.2304 - mean_squared_error: 354.8485 - mean_absolute_error: 7.9712 - val_loss: 157.7892 - val_pearson: 0.1752 - val_mean_squared_error: 157.7892 - val_mean_absolute_error: 4.2560
# Epoch 55/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 348.8419 - pearson: 0.2290 - mean_squared_error: 348.8419 - mean_absolute_error: 7.8807
# Epoch 00055: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 353.1098 - pearson: 0.2305 - mean_squared_error: 353.1097 - mean_absolute_error: 7.9010 - val_loss: 157.1029 - val_pearson: 0.1758 - val_mean_squared_error: 157.1029 - val_mean_absolute_error: 4.3687
# Epoch 56/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 351.9913 - pearson: 0.2346 - mean_squared_error: 351.9913 - mean_absolute_error: 7.9355
# Epoch 00056: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 353.1514 - pearson: 0.2341 - mean_squared_error: 353.1514 - mean_absolute_error: 7.9448 - val_loss: 157.0000 - val_pearson: 0.1762 - val_mean_squared_error: 157.0000 - val_mean_absolute_error: 4.4603
# Epoch 57/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 354.4832 - pearson: 0.2295 - mean_squared_error: 354.4832 - mean_absolute_error: 8.0089
# Epoch 00057: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 353.1178 - pearson: 0.2295 - mean_squared_error: 353.1178 - mean_absolute_error: 7.9939 - val_loss: 158.2111 - val_pearson: 0.1734 - val_mean_squared_error: 158.2111 - val_mean_absolute_error: 4.1852
# Epoch 58/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 353.7424 - pearson: 0.2373 - mean_squared_error: 353.7424 - mean_absolute_error: 7.9597
# Epoch 00058: val_loss improved from 156.82885 to 156.71149, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 158s 21ms/step - loss: 354.9769 - pearson: 0.2364 - mean_squared_error: 354.9769 - mean_absolute_error: 7.9760 - val_loss: 156.7115 - val_pearson: 0.1782 - val_mean_squared_error: 156.7115 - val_mean_absolute_error: 4.6717
# Epoch 59/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 351.9018 - pearson: 0.2380 - mean_squared_error: 351.9018 - mean_absolute_error: 7.8700
# Epoch 00059: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 352.7155 - pearson: 0.2402 - mean_squared_error: 352.7155 - mean_absolute_error: 7.8811 - val_loss: 156.9713 - val_pearson: 0.1761 - val_mean_squared_error: 156.9713 - val_mean_absolute_error: 4.6196
# Epoch 60/300
# 1000/1000 [==============================] - 1s 648us/steps: 351.9065 - pearson: 0.2364 - mean_squared_error: 351.9065 - mean_
# [('loss', 192.76827102661133), ('pearson', 0.28838495385646817), ('mean_squared_error', 192.76827099609375), ('mean_absolute_error', 5.3672949256896976)]
# Test spearman: 0.302417194645
#
# Epoch 00060: val_loss did not improve
# 7500/7500 [==============================] - 21s 3ms/step - loss: 351.7896 - pearson: 0.2373 - mean_squared_error: 351.7896 - mean_absolute_error: 7.9448 - val_loss: 156.7791 - val_pearson: 0.1770 - val_mean_squared_error: 156.7791 - val_mean_absolute_error: 4.3947
# Epoch 61/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 354.5630 - pearson: 0.2355 - mean_squared_error: 354.5630 - mean_absolute_error: 7.9417
# Epoch 00061: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 352.5148 - pearson: 0.2341 - mean_squared_error: 352.5148 - mean_absolute_error: 7.9278 - val_loss: 156.9518 - val_pearson: 0.1762 - val_mean_squared_error: 156.9518 - val_mean_absolute_error: 4.3845
# Epoch 62/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 350.3160 - pearson: 0.2358 - mean_squared_error: 350.3160 - mean_absolute_error: 7.8691
# Epoch 00062: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 352.3326 - pearson: 0.2357 - mean_squared_error: 352.3326 - mean_absolute_error: 7.8851 - val_loss: 156.7468 - val_pearson: 0.1776 - val_mean_squared_error: 156.7468 - val_mean_absolute_error: 4.6706
# Epoch 63/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 354.9780 - pearson: 0.2328 - mean_squared_error: 354.9780 - mean_absolute_error: 7.9676
# Epoch 00063: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 352.3544 - pearson: 0.2325 - mean_squared_error: 352.3544 - mean_absolute_error: 7.9374 - val_loss: 157.0342 - val_pearson: 0.1768 - val_mean_squared_error: 157.0342 - val_mean_absolute_error: 4.4114
# Epoch 64/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 354.4340 - pearson: 0.2404 - mean_squared_error: 354.4340 - mean_absolute_error: 7.9090
# Epoch 00064: val_loss improved from 156.71149 to 156.68577, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 156s 21ms/step - loss: 352.2161 - pearson: 0.2422 - mean_squared_error: 352.2161 - mean_absolute_error: 7.8942 - val_loss: 156.6858 - val_pearson: 0.1773 - val_mean_squared_error: 156.6858 - val_mean_absolute_error: 4.5830
# Epoch 65/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 351.7694 - pearson: 0.2380 - mean_squared_error: 351.7694 - mean_absolute_error: 7.9415
# Epoch 00065: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 350.9236 - pearson: 0.2401 - mean_squared_error: 350.9236 - mean_absolute_error: 7.9422 - val_loss: 156.6889 - val_pearson: 0.1774 - val_mean_squared_error: 156.6889 - val_mean_absolute_error: 4.5887
# Epoch 66/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 351.4639 - pearson: 0.2419 - mean_squared_error: 351.4639 - mean_absolute_error: 7.8348
# Epoch 00066: val_loss improved from 156.68577 to 156.52962, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 155s 21ms/step - loss: 350.9121 - pearson: 0.2406 - mean_squared_error: 350.9121 - mean_absolute_error: 7.8445 - val_loss: 156.5296 - val_pearson: 0.1784 - val_mean_squared_error: 156.5296 - val_mean_absolute_error: 4.5717
# Epoch 67/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 350.4242 - pearson: 0.2397 - mean_squared_error: 350.4243 - mean_absolute_error: 7.9335
# Epoch 00067: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 350.6684 - pearson: 0.2394 - mean_squared_error: 350.6684 - mean_absolute_error: 7.9279 - val_loss: 156.5835 - val_pearson: 0.1779 - val_mean_squared_error: 156.5835 - val_mean_absolute_error: 4.5334
# Epoch 68/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 351.6761 - pearson: 0.2468 - mean_squared_error: 351.6761 - mean_absolute_error: 7.9897
# Epoch 00068: val_loss improved from 156.52962 to 156.38061, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 157s 21ms/step - loss: 350.7670 - pearson: 0.2457 - mean_squared_error: 350.7670 - mean_absolute_error: 7.9873 - val_loss: 156.3806 - val_pearson: 0.1786 - val_mean_squared_error: 156.3806 - val_mean_absolute_error: 4.6350
# Epoch 69/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 349.9148 - pearson: 0.2401 - mean_squared_error: 349.9148 - mean_absolute_error: 7.9776
# Epoch 00069: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 350.1033 - pearson: 0.2392 - mean_squared_error: 350.1033 - mean_absolute_error: 7.9859 - val_loss: 156.6031 - val_pearson: 0.1783 - val_mean_squared_error: 156.6031 - val_mean_absolute_error: 4.6191
# Epoch 70/300
# 1000/1000 [==============================] - 1s 642us/steps: 352.3532 - pearson: 0.2365 - mean_squared_error: 352.3532 - mean_
# [('loss', 193.72314527893067), ('pearson', 0.28170240843296052), ('mean_squared_error', 193.72313973999024), ('mean_absolute_error', 5.434929618835449)]
# Test spearman: 0.299960063318
#
# Epoch 00070: val_loss did not improve
# ...
# Epoch 00269: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 331.1468 - pearson: 0.2796 - mean_squared_error: 331.1468 - mean_absolute_error: 7.8548 - val_loss: 155.1654 - val_pearson: 0.1842 - val_mean_squared_error: 155.1654 - val_mean_absolute_error: 4.5005
# Epoch 270/300
# 1000/1000 [==============================] - 1s 640us/steps: 332.2369 - pearson: 0.2795 - mean_squared_error: 332.2369 - mean_
# [('loss', 188.11575437927246), ('pearson', 0.28892379307746885), ('mean_squared_error', 188.11574951171875), ('mean_absolute_error', 5.4830026626586914)]
# Test spearman: 0.304658626476
#
# Epoch 00270: val_loss did not improve
# 7500/7500 [==============================] - 20s 3ms/step - loss: 331.2465 - pearson: 0.2777 - mean_squared_error: 331.2465 - mean_absolute_error: 7.8778 - val_loss: 155.2987 - val_pearson: 0.1843 - val_mean_squared_error: 155.2987 - val_mean_absolute_error: 4.4920
# Epoch 271/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 326.9690 - pearson: 0.2844 - mean_squared_error: 326.9690 - mean_absolute_error: 7.8727
# Epoch 00271: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.6663 - pearson: 0.2839 - mean_squared_error: 330.6663 - mean_absolute_error: 7.8986 - val_loss: 155.2809 - val_pearson: 0.1841 - val_mean_squared_error: 155.2809 - val_mean_absolute_error: 4.4585
# Epoch 272/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 331.3356 - pearson: 0.2848 - mean_squared_error: 331.3356 - mean_absolute_error: 7.8735
# Epoch 00272: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 331.2373 - pearson: 0.2845 - mean_squared_error: 331.2373 - mean_absolute_error: 7.8768 - val_loss: 155.3999 - val_pearson: 0.1833 - val_mean_squared_error: 155.3999 - val_mean_absolute_error: 4.4683
# Epoch 273/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 332.2978 - pearson: 0.2725 - mean_squared_error: 332.2978 - mean_absolute_error: 7.8185
# Epoch 00273: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 331.6725 - pearson: 0.2734 - mean_squared_error: 331.6724 - mean_absolute_error: 7.8149 - val_loss: 155.2924 - val_pearson: 0.1839 - val_mean_squared_error: 155.2924 - val_mean_absolute_error: 4.4429
# Epoch 274/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 330.2935 - pearson: 0.2758 - mean_squared_error: 330.2935 - mean_absolute_error: 7.8653
# Epoch 00274: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 331.2955 - pearson: 0.2765 - mean_squared_error: 331.2955 - mean_absolute_error: 7.8771 - val_loss: 155.4623 - val_pearson: 0.1847 - val_mean_squared_error: 155.4623 - val_mean_absolute_error: 4.5717
# Epoch 275/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 332.2280 - pearson: 0.2764 - mean_squared_error: 332.2280 - mean_absolute_error: 7.9067
# Epoch 00275: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 331.4106 - pearson: 0.2774 - mean_squared_error: 331.4106 - mean_absolute_error: 7.9011 - val_loss: 155.3229 - val_pearson: 0.1841 - val_mean_squared_error: 155.3229 - val_mean_absolute_error: 4.4494
# Epoch 276/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 326.1480 - pearson: 0.2862 - mean_squared_error: 326.1480 - mean_absolute_error: 7.8370
# Epoch 00276: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.3413 - pearson: 0.2855 - mean_squared_error: 330.3413 - mean_absolute_error: 7.8524 - val_loss: 155.2804 - val_pearson: 0.1846 - val_mean_squared_error: 155.2804 - val_mean_absolute_error: 4.5004
# Epoch 277/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 331.5801 - pearson: 0.2731 - mean_squared_error: 331.5801 - mean_absolute_error: 7.8804
# Epoch 00277: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.3330 - pearson: 0.2741 - mean_squared_error: 330.3330 - mean_absolute_error: 7.8736 - val_loss: 155.1857 - val_pearson: 0.1851 - val_mean_squared_error: 155.1857 - val_mean_absolute_error: 4.5383
# Epoch 278/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 333.8045 - pearson: 0.2813 - mean_squared_error: 333.8045 - mean_absolute_error: 7.9148
# Epoch 00278: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 331.6795 - pearson: 0.2801 - mean_squared_error: 331.6795 - mean_absolute_error: 7.8963 - val_loss: 155.2740 - val_pearson: 0.1840 - val_mean_squared_error: 155.2740 - val_mean_absolute_error: 4.4195
# Epoch 279/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 331.0181 - pearson: 0.2730 - mean_squared_error: 331.0181 - mean_absolute_error: 7.8714
# Epoch 00279: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.8194 - pearson: 0.2743 - mean_squared_error: 330.8194 - mean_absolute_error: 7.8676 - val_loss: 155.2844 - val_pearson: 0.1853 - val_mean_squared_error: 155.2844 - val_mean_absolute_error: 4.5760
# Epoch 280/300
# 1000/1000 [==============================] - 1s 646us/steps: 331.6255 - pearson: 0.2807 - mean_squared_error: 331.6255 - mean_
# [('loss', 188.82386627197266), ('pearson', 0.28587644004821777), ('mean_squared_error', 188.82386054992676), ('mean_absolute_error', 5.3858060531616214)]
# Test spearman: 0.302499679886
#
# Epoch 00280: val_loss did not improve
# 7500/7500 [==============================] - 20s 3ms/step - loss: 330.9773 - pearson: 0.2811 - mean_squared_error: 330.9773 - mean_absolute_error: 7.8986 - val_loss: 155.2138 - val_pearson: 0.1840 - val_mean_squared_error: 155.2138 - val_mean_absolute_error: 4.4032
# Epoch 281/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 331.8563 - pearson: 0.2775 - mean_squared_error: 331.8563 - mean_absolute_error: 7.7943
# Epoch 00281: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.9246 - pearson: 0.2770 - mean_squared_error: 330.9246 - mean_absolute_error: 7.7965 - val_loss: 155.2651 - val_pearson: 0.1844 - val_mean_squared_error: 155.2651 - val_mean_absolute_error: 4.5213
# Epoch 282/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 327.4045 - pearson: 0.2809 - mean_squared_error: 327.4045 - mean_absolute_error: 7.8869
# Epoch 00282: val_loss improved from 155.12132 to 155.09947, saving model to models/mse_lowlr/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_lowlr/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 155s 21ms/step - loss: 330.5433 - pearson: 0.2796 - mean_squared_error: 330.5433 - mean_absolute_error: 7.9005 - val_loss: 155.0995 - val_pearson: 0.1849 - val_mean_squared_error: 155.0995 - val_mean_absolute_error: 4.4965
# Epoch 283/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 329.1053 - pearson: 0.2808 - mean_squared_error: 329.1053 - mean_absolute_error: 7.8730
# Epoch 00283: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.6445 - pearson: 0.2807 - mean_squared_error: 330.6445 - mean_absolute_error: 7.8789 - val_loss: 155.3740 - val_pearson: 0.1830 - val_mean_squared_error: 155.3740 - val_mean_absolute_error: 4.3743
# Epoch 284/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 331.6917 - pearson: 0.2796 - mean_squared_error: 331.6917 - mean_absolute_error: 7.7666
# Epoch 00284: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 331.2019 - pearson: 0.2807 - mean_squared_error: 331.2019 - mean_absolute_error: 7.7689 - val_loss: 155.2227 - val_pearson: 0.1851 - val_mean_squared_error: 155.2227 - val_mean_absolute_error: 4.5275
# Epoch 285/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 332.1437 - pearson: 0.2807 - mean_squared_error: 332.1437 - mean_absolute_error: 7.8870
# Epoch 00285: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 331.2619 - pearson: 0.2804 - mean_squared_error: 331.2619 - mean_absolute_error: 7.8828 - val_loss: 155.5344 - val_pearson: 0.1847 - val_mean_squared_error: 155.5344 - val_mean_absolute_error: 4.5383
# Epoch 286/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 332.3853 - pearson: 0.2796 - mean_squared_error: 332.3853 - mean_absolute_error: 7.8522
# Epoch 00286: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 331.0895 - pearson: 0.2794 - mean_squared_error: 331.0895 - mean_absolute_error: 7.8432 - val_loss: 155.1601 - val_pearson: 0.1842 - val_mean_squared_error: 155.1601 - val_mean_absolute_error: 4.4602
# Epoch 287/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 332.7986 - pearson: 0.2791 - mean_squared_error: 332.7986 - mean_absolute_error: 7.8985
# Epoch 00287: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 331.4801 - pearson: 0.2778 - mean_squared_error: 331.4801 - mean_absolute_error: 7.8949 - val_loss: 155.3047 - val_pearson: 0.1854 - val_mean_squared_error: 155.3047 - val_mean_absolute_error: 4.5692
# Epoch 288/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 328.6971 - pearson: 0.2838 - mean_squared_error: 328.6971 - mean_absolute_error: 7.8062
# Epoch 00288: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.0375 - pearson: 0.2845 - mean_squared_error: 330.0375 - mean_absolute_error: 7.8215 - val_loss: 155.5067 - val_pearson: 0.1856 - val_mean_squared_error: 155.5067 - val_mean_absolute_error: 4.6089
# Epoch 289/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 331.1343 - pearson: 0.2824 - mean_squared_error: 331.1343 - mean_absolute_error: 7.9240
# Epoch 00289: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.0985 - pearson: 0.2817 - mean_squared_error: 330.0984 - mean_absolute_error: 7.9229 - val_loss: 155.2136 - val_pearson: 0.1848 - val_mean_squared_error: 155.2136 - val_mean_absolute_error: 4.4996
# Epoch 290/300
# 1000/1000 [==============================] - 1s 646us/steps: 332.3330 - pearson: 0.2767 - mean_squared_error: 332.3330 - mean_
# [('loss', 188.8457445526123), ('pearson', 0.28585273861885069), ('mean_squared_error', 188.84574382019042), ('mean_absolute_error', 5.4585506820678713)]
# Test spearman: 0.303075772777
#
# Epoch 00290: val_loss did not improve
# 7500/7500 [==============================] - 20s 3ms/step - loss: 331.2556 - pearson: 0.2785 - mean_squared_error: 331.2556 - mean_absolute_error: 7.8045 - val_loss: 155.1430 - val_pearson: 0.1843 - val_mean_squared_error: 155.1430 - val_mean_absolute_error: 4.4616
# Epoch 291/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 330.5684 - pearson: 0.2805 - mean_squared_error: 330.5684 - mean_absolute_error: 7.9004
# Epoch 00291: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.3143 - pearson: 0.2811 - mean_squared_error: 330.3143 - mean_absolute_error: 7.9090 - val_loss: 155.2028 - val_pearson: 0.1855 - val_mean_squared_error: 155.2028 - val_mean_absolute_error: 4.5472
# Epoch 292/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 332.0482 - pearson: 0.2768 - mean_squared_error: 332.0482 - mean_absolute_error: 7.8933
# Epoch 00292: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 331.1590 - pearson: 0.2757 - mean_squared_error: 331.1590 - mean_absolute_error: 7.8821 - val_loss: 155.1385 - val_pearson: 0.1847 - val_mean_squared_error: 155.1385 - val_mean_absolute_error: 4.4915
# Epoch 293/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 329.9495 - pearson: 0.2829 - mean_squared_error: 329.9495 - mean_absolute_error: 7.8304
# Epoch 00293: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.4467 - pearson: 0.2836 - mean_squared_error: 330.4467 - mean_absolute_error: 7.8312 - val_loss: 155.2413 - val_pearson: 0.1854 - val_mean_squared_error: 155.2413 - val_mean_absolute_error: 4.5553
# Epoch 294/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 326.2553 - pearson: 0.2843 - mean_squared_error: 326.2553 - mean_absolute_error: 7.8539
# Epoch 00294: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.5506 - pearson: 0.2844 - mean_squared_error: 330.5506 - mean_absolute_error: 7.8794 - val_loss: 155.2701 - val_pearson: 0.1856 - val_mean_squared_error: 155.2701 - val_mean_absolute_error: 4.5476
# Epoch 295/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 331.1387 - pearson: 0.2837 - mean_squared_error: 331.1387 - mean_absolute_error: 7.9165
# Epoch 00295: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.2792 - pearson: 0.2834 - mean_squared_error: 330.2792 - mean_absolute_error: 7.9128 - val_loss: 155.7295 - val_pearson: 0.1859 - val_mean_squared_error: 155.7295 - val_mean_absolute_error: 4.6799
# Epoch 296/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 332.2216 - pearson: 0.2797 - mean_squared_error: 332.2216 - mean_absolute_error: 7.8754
# Epoch 00296: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.5610 - pearson: 0.2806 - mean_squared_error: 330.5610 - mean_absolute_error: 7.8593 - val_loss: 155.1028 - val_pearson: 0.1848 - val_mean_squared_error: 155.1028 - val_mean_absolute_error: 4.4930
# Epoch 297/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 329.4394 - pearson: 0.2735 - mean_squared_error: 329.4394 - mean_absolute_error: 7.8293
# Epoch 00297: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.1060 - pearson: 0.2763 - mean_squared_error: 330.1060 - mean_absolute_error: 7.8387 - val_loss: 155.2299 - val_pearson: 0.1840 - val_mean_squared_error: 155.2299 - val_mean_absolute_error: 4.4032
# Epoch 298/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 328.7333 - pearson: 0.2760 - mean_squared_error: 328.7333 - mean_absolute_error: 7.8399
# Epoch 00298: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.7407 - pearson: 0.2764 - mean_squared_error: 330.7407 - mean_absolute_error: 7.8453 - val_loss: 155.1829 - val_pearson: 0.1839 - val_mean_squared_error: 155.1829 - val_mean_absolute_error: 4.3967
# Epoch 299/300
# 7424/7500 [============================>.] - ETA: 0s - loss: 332.0173 - pearson: 0.2811 - mean_squared_error: 332.0173 - mean_absolute_error: 7.8813
# Epoch 00299: val_loss did not improve
# 7500/7500 [==============================] - 18s 2ms/step - loss: 330.3391 - pearson: 0.2805 - mean_squared_error: 330.3391 - mean_absolute_error: 7.8622 - val_loss: 155.1878 - val_pearson: 0.1844 - val_mean_squared_error: 155.1878 - val_mean_absolute_error: 4.4435
# Epoch 300/300
# 1000/1000 [==============================] - 1s 648us/steps: 331.6178 - pearson: 0.2804 - mean_squared_error: 331.6178 - mean_
# [('loss', 189.25038694763182), ('pearson', 0.28467375659942629), ('mean_squared_error', 189.25038861083985), ('mean_absolute_error', 5.3744796524047853)]
# Test spearman: 0.300074001175
#
# Epoch 00300: val_loss did not improve
# 7500/7500 [==============================] - 20s 3ms/step - loss: 330.3138 - pearson: 0.2811 - mean_squared_error: 330.3138 - mean_absolute_error: 7.8299 - val_loss: 155.2492 - val_pearson: 0.1836 - val_mean_squared_error: 155.2492 - val_mean_absolute_error: 4.3909
