# %% [markdown]
# # Baseline with mse loss with wide cnn modified + adam
# #### Convert histone mark signals and use deep CNN for training.

# %% [markdown]
# #### NOTE: Need to activate genomelake environment before this code. Simply type 'genomelake' in terminal.

# %%
# %env CUDA_VISIBLE_DEVICES=1
import os, sys
sys.path.append("..")
import random
# custom file path package
from data import Data_Directories
# custom utility package
from utils.compute_util import *
# package for genomic data
from pybedtools import Interval, BedTool
from genomelake.extractors import ArrayExtractor, BigwigExtractor
# package for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats.stats import pearsonr,spearmanr
import tensorflow as tf
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
window_size = 2001
sample_num = 10000

# %%
# retrieve data
data = Data_Directories()
print data.intervals.keys()
print data.input_atac['day0'].keys()
print data.output_histone['day0'].keys()
# Out:
# ['day6', 'day3', 'day0']
# ['100', '140']
# ['H3K27me3', 'H3K4me1', 'H3K27ac']

# %%
# get intervals for day0 data
day0_intervals = list(BedTool(data.intervals['day0']))
print '# of Intervals Extracted for day0: {}'.format(len(day0_intervals))
# Out:
# # of Intervals Extracted for day0: 267226

# %%
# create an ArrayExtractor for ATAC-seq for day0 with 140 base pairs
bw_140bp_day0 = ArrayExtractor(data.input_atac['day0']['140'])
print 'Finished extracting bigwig for day0, 140bp'
# Out:
# Finished extracting bigwig for day0, 140bp

# %%
# create a BigWigExtractor for histone makr 'H3K27ac' for day0
bw_histone_mark_day0 = BigwigExtractor(data.output_histone['day0']['H3K27ac'])
print 'Finished extracting bigwig for day0, 140bp'
# Out:
# Finished extracting bigwig for day0, 140bp

# %%
# normalize day0 intervals
normalized_day0_intervals = [normalize_interval(interval, window_size) for interval in day0_intervals if normalize_interval(interval, window_size)]
print 'Finished normalizing day0 intervals!'
# Out:
# Finished normalizing day0 intervals!

# %%
assert (len(day0_intervals)==len(normalized_day0_intervals))
print "Examples of original intervals"
print [(int(_interval.start)+int(_interval[-1]), [int(_interval.start), int(_interval.end)])
       for _interval in day0_intervals[:3]]
print "Examples of normalized intervals with window size of {}".format(window_size)
print [([int(_interval.start), int(_interval.end)])
       for _interval in  normalized_day0_intervals[:3]]
# Out:
# Examples of original intervals
# [(123412027, [123411855, 123412989]), (123411941, [123411855, 123412989]), (131908564, [131908487, 131910071])]
# Examples of normalized intervals with window size of 2001
# [[123411027, 123413028], [123410941, 123412942], [131907564, 131909565]]

# %%
atac_seq_day0 = bw_140bp_day0(normalized_day0_intervals)
print atac_seq_day0.shape
# Out:
# (267226, 2001, 5)

# %%
#TODO: put this into utils if possible
def prune_invalid_intervals(intervals, bigwig_file):
    for _interval in intervals[:]:
        try:
            bigwig_file([_interval])
        except:
            intervals.remove(_interval)
            pass
        
print "Before pruning day0: {}".format(len(normalized_day0_intervals))
prune_invalid_intervals(normalized_day0_intervals, bw_140bp_day0)
print "After pruning day0: {}".format(len(normalized_day0_intervals))
# Out:
# Before pruning day0: 267226
# After pruning day0: 267226

# %%
print "Dimension of ATAC-seq signal: {}".format(bw_140bp_day0(normalized_day0_intervals[:1]).shape)
# Out:
# Dimension of ATAC-seq signal: (1, 2001, 5)

# %%
print "Dimension of histone mark signal: {}".format(bw_histone_mark_day0(normalized_day0_intervals[:1]).shape)
# Out:
# Dimension of histone mark signal: (1, 2001)

# %%
# replace nan values with zeros and convert it to p-values
histone_mark_day0 = np.nan_to_num(bw_histone_mark_day0(normalized_day0_intervals))
print histone_mark_day0.shape
# Out:
# (267226, 2001)

# %%
histone_mark_day0 = np.expand_dims(histone_mark_day0, axis=2)
print histone_mark_day0.shape
# Out:
# (267226, 2001, 1)

# %%
print "Example histone mark signal"
print "\tRaw value: {}".format(bw_histone_mark_day0(normalized_day0_intervals[:1])[0][:5].reshape(-1))
# Out:
# Example histone mark signal
# 	Raw value: [ 0.01014  0.01014  0.01014  0.02435  0.02435]

# %%
from keras.layers import Input, Dense, Conv1D, Dropout, BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Model
from keras import optimizers
from keras import metrics
from keras import losses
from keras import backend as K
from keras.callbacks import Callback, TensorBoard, ReduceLROnPlateau, ModelCheckpoint

# %%
dropout_rate = 0.5
# parameters for first conv layer
hidden_filters_1 = 32
hidden_kernel_size_1 = window_size
# parameters for second conv layer
output_filters = 1
output_kernel_size = 32
# parameters for training
batch_size = 128
num_epochs = 150
evaluation_freq = 10

# %%
'''
Baseline CNN (based on KERAS functional API)
'''
inputs = Input(shape=(window_size, 5, ))
x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1,
    name='gen_conv1d_1')(inputs)
x = Dropout(dropout_rate,
            name='gen_dropout_1')(x)
# x = BatchNormalization(momentum=0.8)(x)

outputs = Conv1D(
    filters=output_filters,
    kernel_size=output_kernel_size,
    padding='same',
    activation='linear',
    strides=1,
    name='gen_conv1d_output'
    )(x)

model = Model(inputs=inputs, outputs=outputs)

# %%
# Print out model summary
print model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 2001, 5)           0
# _________________________________________________________________
# gen_conv1d_1 (Conv1D)        (None, 2001, 32)          320192
# _________________________________________________________________
# gen_dropout_1 (Dropout)      (None, 2001, 32)          0
# _________________________________________________________________
# gen_conv1d_output (Conv1D)   (None, 2001, 1)           1025
# =================================================================
# Total params: 321,217
# Trainable params: 321,217
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def pearson(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = K.mean(x)
    my = K.mean(y)
    xm, ym = x-mx, y-my
    r_num = K.sum(np.multiply(xm,ym))
    r_den = K.sqrt(np.multiply(K.sum(K.square(xm)), K.sum(K.square(ym))))
    r = r_num / r_den
    r = K.maximum(K.minimum(r, 1.0), -1.0)
    return K.square(r)

# %%
# Helper functions for writing the scores into bigwig file
from itertools import izip
from itertools import groupby
import subprocess

def interval_key(interval):
    return (interval.chrom, interval.start, interval.stop)

def merged_scores(scores, intervals, merge_type):
    # A generator that returns merged intervals/scores
    # Scores should have shape: #examples x #categories x #interval_size
    # Second dimension can be omitted for a 1D signal
    signal_dims = scores.ndim - 1
    assert signal_dims in {1, 2}

    # Only support max for now
    assert merge_type == 'max'
    score_first_dim = 1 if signal_dims == 1 else scores.shape[1]

    dtype = scores.dtype

    sort_idx, sorted_intervals = \
        zip(*sorted(enumerate(intervals),
                    key=lambda item: interval_key(item[1])))
    sorted_intervals = BedTool(sorted_intervals)

    # Require at least 1bp overlap
    # Explicitly convert to list otherwise it will keep opening a file when
    # retrieving an index resulting in an error (too many open files)
    interval_clust = list(sorted_intervals.cluster(d=-1))
    for _, group in groupby(izip(sort_idx, interval_clust),
                            key=lambda item: item[1].fields[-1]):
        idx_interval_pairs = list(group)
        group_idx, group_intervals = zip(*idx_interval_pairs)

        if len(idx_interval_pairs) == 1:
            yield group_intervals[0], scores[group_idx[0], ...]
        else:
            group_chrom = group_intervals[0].chrom
            group_start = min(interval.start for interval in group_intervals)
            group_stop = max(interval.stop for interval in group_intervals)

            # This part needs to change to support more merge_types (e.g. mean)
            group_score = np.full((score_first_dim, group_stop - group_start),
                                  -np.inf, dtype)
            for idx, interval in idx_interval_pairs:
                slice_start = interval.start - group_start
                slice_stop = slice_start + (interval.stop - interval.start)
                group_score[..., slice_start:slice_stop] = \
                    np.maximum(group_score[..., slice_start:slice_stop],
                               scores[idx, ...])
            if signal_dims == 1:
                group_score = group_score.squeeze(axis=0)
            yield Interval(group_chrom, group_start, group_stop), group_score
            
def interval_score_pairs(intervals, scores, merge_type):
    return (izip(intervals, scores) if merge_type is None
            else merged_scores(scores, intervals, merge_type))

def _write_1D_deeplift_track(scores, intervals, file_prefix, merge_type='max',
                             CHROM_SIZES='/mnt/data/annotations/by_release/hg19.GRCh37/hg19.chrom.sizes'):
    assert scores.ndim == 2

    bedgraph = file_prefix + '.bedGraph'
    bigwig = file_prefix + '.bw'

    print 'Writing 1D track of shape: {}'.format(scores.shape)
    print 'Writing to file: {}'.format(bigwig)

    with open(bedgraph, 'w') as fp:
        for interval, score in interval_score_pairs(intervals, scores,
                                                    merge_type):
            chrom = interval.chrom
            start = interval.start
            for score_idx, val in enumerate(score):
                fp.write('%s\t%d\t%d\t%g\n' % (chrom,
                                               start + score_idx,
                                               start + score_idx + 1,
                                               val))
    print 'Wrote bedgraph.'

    try:
        output = subprocess.check_output(
            ['wigToBigWig', bedgraph, CHROM_SIZES, bigwig],
            stderr=subprocess.STDOUT)
        print 'wigToBigWig output: {}'.format(output)
    except subprocess.CalledProcessError as e:
        print 'wigToBigWig terminated with exit code {}'.format(
            e.returncode)
        print 'output was:\n' + e.output

    print 'Wrote bigwig.'

# %%
model_dir = os.path.join("models", "cnn_2000_new")
log_dir = os.path.join("logs", "cnn_2000_new")
srv_dir = os.path.join("/srv", "www", "kundaje", "jesikmin", "cnn_2000_new")
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
if not os.path.exists(log_dir):
    os.makedirs(log_dir)
if not os.path.exists(srv_dir):
    os.makedirs(srv_dir)

# %%
# setting an adam optimizer with 1.0 clip norm
adam = optimizers.Adam(lr=1e-3, clipnorm=1.)

print "Compiling a model with adam optimizer"
model.compile(loss=losses.mean_squared_error,
              optimizer=adam,
              metrics=[pearson, metrics.mse, metrics.mae])
# Out:
# Compiling a model with adam optimizer

# %%
# CallBack: tensorboard with grad histogram
tensorboard = TensorBoard(log_dir=log_dir,
                          histogram_freq=1,
                          batch_size=batch_size,
                          write_grads=True)

# %%
# CallBack: reduce learning rate when validation loss meets plateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.96,
                              patience=5,
                              min_lr=1e-7)

# %%
# CallBack: evaluate model for every evaulation epoch
class EvaluateModel(Callback):
    def __init__(self, X_test, y_test):
        self.X_test, self.y_test = X_test, y_test
        self.epochs = 0

    def on_epoch_end(self, batch, logs={}):
        self.epochs += 1
        # evaluate the model
        if self.epochs % evaluation_freq == 0:
            scores = model.evaluate(X_test, y_test)
            print zip(model.metrics_names, scores)
            test_prediction = model.predict(X_test)
            test_spearman_sum = 0.0
            for idx, _pred in enumerate(test_prediction):
                rho, _ = spearmanr(histone_mark_day0[10000+idx], _pred)
                test_spearman_sum += rho
            print "Test spearman: {}".format(test_spearman_sum * 1.0 / 1000)

# %%
# CallBack: store bigwig file for the best model
class SaveBigwig(Callback):
    def __init__(self, X_train, y_train, X_val, y_val, X_test, y_test):
        self.best_val_loss = float('Inf')
        self.best_epoch = -1
        self.X_train, self.y_train = X_train, y_train
        self.X_val, self.y_val = X_val, y_val
        self.X_test, self.y_test = X_test, y_test
        self.epochs = 0
    
    def on_epoch_end(self, batch, logs={}):
        self.epochs += 1
        cur_val_loss = logs['val_loss']
        if cur_val_loss < self.best_val_loss:
            self.best_val_loss = cur_val_loss
            self.best_epoch = self.epochs
            prediction = model.predict(X_train).reshape(int(sample_num*0.8), window_size)
            _write_1D_deeplift_track(prediction,
                                     normalized_day0_intervals[:int(sample_num*0.8)], os.path.join(srv_dir, 'train'))
            prediction = model.predict(X_val).reshape(int(sample_num*0.2), window_size)
            _write_1D_deeplift_track(prediction,
                                     normalized_day0_intervals[int(sample_num*0.8):sample_num], os.path.join(srv_dir, 'val'))
            prediction = model.predict(X_test).reshape(int(sample_num*0.1), window_size)
            _write_1D_deeplift_track(prediction,
                                     normalized_day0_intervals[sample_num:int(sample_num*1.1)], os.path.join(srv_dir, 'test'))
            f = open(os.path.join(srv_dir, 'meta.txt'), 'wb')
            f.write(str(self.epochs) + "  " + str(logs))
            f.close()

# %%
# CallBack: Save model checkpoint based on validation loss
checkpointer = ModelCheckpoint(os.path.join(model_dir, "best_model.h5"),
                               monitor='val_loss',
                               verbose=1,
                               save_best_only=True,
                               mode='min')

# %%
print "Fitting the model..."
train_index = int(sample_num*0.8)
val_index = sample_num
test_index = int(sample_num*1.1) 
X_train, y_train = atac_seq_day0[:train_index], histone_mark_day0[:train_index]
X_val, y_val = atac_seq_day0[train_index:val_index], histone_mark_day0[train_index:val_index]
X_test, y_test = atac_seq_day0[val_index:test_index], histone_mark_day0[val_index:test_index]

model.fit(atac_seq_day0[:sample_num],
          histone_mark_day0[:sample_num],
          batch_size=batch_size,
          epochs=num_epochs,
          validation_split=0.2,   
          #shuffle=True,
          callbacks=[tensorboard,
                     reduce_lr,
                     EvaluateModel(X_test, y_test),
                     checkpointer,
                     SaveBigwig(X_train, y_train, X_val, y_val, X_test, y_test)])
# Out:
# Fitting the model...
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 397.7688 - pearson: 0.1440 - mean_squared_error: 397.7688 - mean_absolute_error: 7.9988
# Epoch 00001: val_loss improved from inf to 133.56077, saving model to models/cnn_2000_new/best_model.h5
# Writing 1D track of shape: (8000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 8000/8000 [==============================] - 168s 21ms/step - loss: 396.6375 - pearson: 0.1455 - mean_squared_error: 396.6375 - mean_absolute_error: 7.9981 - val_loss: 133.5608 - val_pearson: 0.1425 - val_mean_squared_error: 133.5608 - val_mean_absolute_error: 4.1110
# Epoch 2/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 377.6051 - pearson: 0.1809 - mean_squared_error: 377.6051 - mean_absolute_error: 8.1318
# Epoch 00002: val_loss improved from 133.56077 to 132.09322, saving model to models/cnn_2000_new/best_model.h5
# Writing 1D track of shape: (8000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 8000/8000 [==============================] - 166s 21ms/step - loss: 380.0348 - pearson: 0.1807 - mean_squared_error: 380.0348 - mean_absolute_error: 8.1414 - val_loss: 132.0932 - val_pearson: 0.1474 - val_mean_squared_error: 132.0932 - val_mean_absolute_error: 4.1021
# Epoch 3/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 375.5123 - pearson: 0.1854 - mean_squared_error: 375.5123 - mean_absolute_error: 7.9581
# Epoch 00003: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 374.8633 - pearson: 0.1852 - mean_squared_error: 374.8633 - mean_absolute_error: 7.9622 - val_loss: 132.1292 - val_pearson: 0.1457 - val_mean_squared_error: 132.1292 - val_mean_absolute_error: 3.8600
# Epoch 4/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 371.7068 - pearson: 0.1881 - mean_squared_error: 371.7068 - mean_absolute_error: 7.9251
# Epoch 00004: val_loss improved from 132.09322 to 131.13081, saving model to models/cnn_2000_new/best_model.h5
# Writing 1D track of shape: (8000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 8000/8000 [==============================] - 171s 21ms/step - loss: 371.3054 - pearson: 0.1882 - mean_squared_error: 371.3054 - mean_absolute_error: 7.9112 - val_loss: 131.1308 - val_pearson: 0.1553 - val_mean_squared_error: 131.1308 - val_mean_absolute_error: 3.5093
# Epoch 5/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 365.4549 - pearson: 0.1953 - mean_squared_error: 365.4549 - mean_absolute_error: 7.9184
# Epoch 00005: val_loss improved from 131.13081 to 130.29468, saving model to models/cnn_2000_new/best_model.h5
# Writing 1D track of shape: (8000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 8000/8000 [==============================] - 170s 21ms/step - loss: 368.8184 - pearson: 0.1948 - mean_squared_error: 368.8183 - mean_absolute_error: 7.9430 - val_loss: 130.2947 - val_pearson: 0.1515 - val_mean_squared_error: 130.2947 - val_mean_absolute_error: 3.9784
# Epoch 6/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 370.2732 - pearson: 0.1961 - mean_squared_error: 370.2732 - mean_absolute_error: 8.0519
# Epoch 00006: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 369.5091 - pearson: 0.1949 - mean_squared_error: 369.5091 - mean_absolute_error: 8.0583 - val_loss: 130.4421 - val_pearson: 0.1527 - val_mean_squared_error: 130.4421 - val_mean_absolute_error: 3.8800
# Epoch 7/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 368.3356 - pearson: 0.1966 - mean_squared_error: 368.3356 - mean_absolute_error: 7.9830
# Epoch 00007: val_loss improved from 130.29468 to 129.80511, saving model to models/cnn_2000_new/best_model.h5
# Writing 1D track of shape: (8000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/cnn_2000_new/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 8000/8000 [==============================] - 170s 21ms/step - loss: 367.9628 - pearson: 0.1969 - mean_squared_error: 367.9628 - mean_absolute_error: 7.9815 - val_loss: 129.8051 - val_pearson: 0.1539 - val_mean_squared_error: 129.8051 - val_mean_absolute_error: 3.8425
# Epoch 8/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 368.6770 - pearson: 0.2031 - mean_squared_error: 368.6770 - mean_absolute_error: 8.0463
# Epoch 00008: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 368.7929 - pearson: 0.2035 - mean_squared_error: 368.7929 - mean_absolute_error: 8.0386 - val_loss: 131.6800 - val_pearson: 0.1500 - val_mean_squared_error: 131.6800 - val_mean_absolute_error: 3.6732
# Epoch 9/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 363.7294 - pearson: 0.2035 - mean_squared_error: 363.7294 - mean_absolute_error: 7.8971
# Epoch 00009: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 364.8794 - pearson: 0.2031 - mean_squared_error: 364.8794 - mean_absolute_error: 7.9094 - val_loss: 131.1724 - val_pearson: 0.1505 - val_mean_squared_error: 131.1724 - val_mean_absolute_error: 4.0616
# Epoch 10/150
# 1000/1000 [==============================] - 1s 675us/steps: 365.9223 - pearson: 0.2016 - mean_squared_error: 365.9223 - mean_
# [('loss', 196.16334562683105), ('pearson', 0.27058312499523163), ('mean_squared_error', 196.16334872436522), ('mean_absolute_error', 5.7625620250701903)]
# Test spearman: 0.326397888559
#
# Epoch 00010: val_loss did not improve
# 8000/8000 [==============================] - 18s 2ms/step - loss: 364.2198 - pearson: 0.2010 - mean_squared_error: 364.2198 - mean_absolute_error: 7.9932 - val_loss: 130.7311 - val_pearson: 0.1536 - val_mean_squared_error: 130.7311 - val_mean_absolute_error: 4.1577
# Epoch 11/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 365.1627 - pearson: 0.2081 - mean_squared_error: 365.1627 - mean_absolute_error: 8.0193
# Epoch 00011: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 364.8789 - pearson: 0.2086 - mean_squared_error: 364.8789 - mean_absolute_error: 8.0145 - val_loss: 132.2538 - val_pearson: 0.1546 - val_mean_squared_error: 132.2538 - val_mean_absolute_error: 3.5600
# Epoch 12/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 362.3485 - pearson: 0.2092 - mean_squared_error: 362.3485 - mean_absolute_error: 7.9769
# Epoch 00012: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 360.4872 - pearson: 0.2088 - mean_squared_error: 360.4872 - mean_absolute_error: 7.9589 - val_loss: 129.8220 - val_pearson: 0.1585 - val_mean_squared_error: 129.8220 - val_mean_absolute_error: 3.6965
# Epoch 13/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 360.1336 - pearson: 0.2120 - mean_squared_error: 360.1336 - mean_absolute_error: 7.8770
# Epoch 00013: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 360.4342 - pearson: 0.2122 - mean_squared_error: 360.4342 - mean_absolute_error: 7.8731 - val_loss: 130.5987 - val_pearson: 0.1553 - val_mean_squared_error: 130.5987 - val_mean_absolute_error: 3.7587
# Epoch 14/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 358.2926 - pearson: 0.2141 - mean_squared_error: 358.2926 - mean_absolute_error: 7.9109
# Epoch 00014: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 360.0284 - pearson: 0.2156 - mean_squared_error: 360.0284 - mean_absolute_error: 7.9206 - val_loss: 130.4365 - val_pearson: 0.1555 - val_mean_squared_error: 130.4365 - val_mean_absolute_error: 4.2319
# Epoch 15/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 358.7905 - pearson: 0.2089 - mean_squared_error: 358.7905 - mean_absolute_error: 7.9807
# Epoch 00015: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 358.6495 - pearson: 0.2086 - mean_squared_error: 358.6495 - mean_absolute_error: 7.9763 - val_loss: 130.6110 - val_pearson: 0.1545 - val_mean_squared_error: 130.6110 - val_mean_absolute_error: 3.7621
# Epoch 16/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 360.4406 - pearson: 0.2150 - mean_squared_error: 360.4406 - mean_absolute_error: 8.0467
# Epoch 00016: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 360.4100 - pearson: 0.2152 - mean_squared_error: 360.4100 - mean_absolute_error: 8.0566 - val_loss: 131.7685 - val_pearson: 0.1545 - val_mean_squared_error: 131.7685 - val_mean_absolute_error: 4.4134
# Epoch 17/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 358.7603 - pearson: 0.2164 - mean_squared_error: 358.7603 - mean_absolute_error: 8.0061
# Epoch 00017: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 359.0670 - pearson: 0.2157 - mean_squared_error: 359.0670 - mean_absolute_error: 8.0065 - val_loss: 130.3014 - val_pearson: 0.1558 - val_mean_squared_error: 130.3014 - val_mean_absolute_error: 4.0429
# Epoch 18/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 357.9127 - pearson: 0.2170 - mean_squared_error: 357.9127 - mean_absolute_error: 7.9036
# Epoch 00018: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 356.7174 - pearson: 0.2167 - mean_squared_error: 356.7174 - mean_absolute_error: 7.8932 - val_loss: 130.2305 - val_pearson: 0.1554 - val_mean_squared_error: 130.2305 - val_mean_absolute_error: 4.0385
# Epoch 19/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 357.4531 - pearson: 0.2164 - mean_squared_error: 357.4531 - mean_absolute_error: 7.8672
# Epoch 00019: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 357.1566 - pearson: 0.2174 - mean_squared_error: 357.1566 - mean_absolute_error: 7.8723 - val_loss: 133.5143 - val_pearson: 0.1506 - val_mean_squared_error: 133.5143 - val_mean_absolute_error: 4.5158
# Epoch 20/150
# 1000/1000 [==============================] - 1s 662us/steps: 360.3941 - pearson: 0.2229 - mean_squared_error: 360.3941 - mean_
# [('loss', 195.65322561645507), ('pearson', 0.27125075006484983), ('mean_squared_error', 195.6532265777588), ('mean_absolute_error', 5.4401463851928709)]
# Test spearman: 0.322607539691
#
# Epoch 00020: val_loss did not improve
# 8000/8000 [==============================] - 19s 2ms/step - loss: 359.5503 - pearson: 0.2217 - mean_squared_error: 359.5503 - mean_absolute_error: 8.2307 - val_loss: 131.0056 - val_pearson: 0.1521 - val_mean_squared_error: 131.0055 - val_mean_absolute_error: 3.9537
# Epoch 21/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 351.4042 - pearson: 0.2162 - mean_squared_error: 351.4042 - mean_absolute_error: 7.8532
# Epoch 00021: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 355.3248 - pearson: 0.2181 - mean_squared_error: 355.3248 - mean_absolute_error: 7.8811 - val_loss: 139.8462 - val_pearson: 0.1553 - val_mean_squared_error: 139.8462 - val_mean_absolute_error: 5.1309
# Epoch 22/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 357.2381 - pearson: 0.2149 - mean_squared_error: 357.2381 - mean_absolute_error: 8.0142
# Epoch 00022: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 358.0910 - pearson: 0.2151 - mean_squared_error: 358.0910 - mean_absolute_error: 8.0276 - val_loss: 131.0151 - val_pearson: 0.1542 - val_mean_squared_error: 131.0151 - val_mean_absolute_error: 4.0260
# Epoch 23/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 352.9677 - pearson: 0.2193 - mean_squared_error: 352.9677 - mean_absolute_error: 7.8956
# Epoch 00023: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 355.7279 - pearson: 0.2190 - mean_squared_error: 355.7279 - mean_absolute_error: 7.9141 - val_loss: 130.5329 - val_pearson: 0.1541 - val_mean_squared_error: 130.5330 - val_mean_absolute_error: 4.0411
# Epoch 24/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 354.9106 - pearson: 0.2167 - mean_squared_error: 354.9106 - mean_absolute_error: 8.0130
# Epoch 00024: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 354.6915 - pearson: 0.2182 - mean_squared_error: 354.6915 - mean_absolute_error: 8.0062 - val_loss: 131.1127 - val_pearson: 0.1517 - val_mean_squared_error: 131.1127 - val_mean_absolute_error: 3.8745
# Epoch 25/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 354.8386 - pearson: 0.2180 - mean_squared_error: 354.8386 - mean_absolute_error: 7.9654
# Epoch 00025: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 355.1327 - pearson: 0.2170 - mean_squared_error: 355.1327 - mean_absolute_error: 7.9702 - val_loss: 131.2860 - val_pearson: 0.1492 - val_mean_squared_error: 131.2860 - val_mean_absolute_error: 4.1848
# Epoch 26/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 356.9172 - pearson: 0.2212 - mean_squared_error: 356.9172 - mean_absolute_error: 7.9334
# Epoch 00026: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 356.1374 - pearson: 0.2211 - mean_squared_error: 356.1374 - mean_absolute_error: 7.9269 - val_loss: 131.8010 - val_pearson: 0.1468 - val_mean_squared_error: 131.8010 - val_mean_absolute_error: 3.8719
# Epoch 27/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 355.7601 - pearson: 0.2239 - mean_squared_error: 355.7601 - mean_absolute_error: 8.0581
# Epoch 00027: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 355.0606 - pearson: 0.2245 - mean_squared_error: 355.0606 - mean_absolute_error: 8.0431 - val_loss: 131.1964 - val_pearson: 0.1549 - val_mean_squared_error: 131.1964 - val_mean_absolute_error: 4.3451
# Epoch 28/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 353.7398 - pearson: 0.2208 - mean_squared_error: 353.7398 - mean_absolute_error: 8.0481
# Epoch 00028: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 353.2771 - pearson: 0.2209 - mean_squared_error: 353.2771 - mean_absolute_error: 8.0522 - val_loss: 133.7173 - val_pearson: 0.1493 - val_mean_squared_error: 133.7173 - val_mean_absolute_error: 4.6124
# Epoch 29/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 354.5317 - pearson: 0.2271 - mean_squared_error: 354.5317 - mean_absolute_error: 7.9772
# Epoch 00029: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 352.9278 - pearson: 0.2262 - mean_squared_error: 352.9278 - mean_absolute_error: 7.9606 - val_loss: 131.4655 - val_pearson: 0.1540 - val_mean_squared_error: 131.4655 - val_mean_absolute_error: 4.3563
# Epoch 30/150
# 1000/1000 [==============================] - 1s 666us/steps: 354.0758 - pearson: 0.2259 - mean_squared_error: 354.0758 - mean_
# [('loss', 199.20786364746093), ('pearson', 0.26734363746643064), ('mean_squared_error', 199.20786975097656), ('mean_absolute_error', 6.447439685821533)]
# Test spearman: 0.315688502966
#
# Epoch 00030: val_loss did not improve
# 8000/8000 [==============================] - 18s 2ms/step - loss: 353.9914 - pearson: 0.2255 - mean_squared_error: 353.9914 - mean_absolute_error: 8.0030 - val_loss: 135.1138 - val_pearson: 0.1509 - val_mean_squared_error: 135.1138 - val_mean_absolute_error: 4.8203
# Epoch 31/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 353.0135 - pearson: 0.2252 - mean_squared_error: 353.0135 - mean_absolute_error: 7.9737
# Epoch 00031: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 353.9490 - pearson: 0.2255 - mean_squared_error: 353.9490 - mean_absolute_error: 7.9822 - val_loss: 131.4826 - val_pearson: 0.1483 - val_mean_squared_error: 131.4826 - val_mean_absolute_error: 4.0996
# Epoch 32/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 353.2897 - pearson: 0.2275 - mean_squared_error: 353.2897 - mean_absolute_error: 7.9888
# Epoch 00032: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 352.2979 - pearson: 0.2270 - mean_squared_error: 352.2979 - mean_absolute_error: 7.9796 - val_loss: 130.4705 - val_pearson: 0.1553 - val_mean_squared_error: 130.4705 - val_mean_absolute_error: 4.1545
# Epoch 33/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 353.0921 - pearson: 0.2284 - mean_squared_error: 353.0921 - mean_absolute_error: 8.0528
# Epoch 00033: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 355.1795 - pearson: 0.2274 - mean_squared_error: 355.1795 - mean_absolute_error: 8.0742 - val_loss: 130.3958 - val_pearson: 0.1565 - val_mean_squared_error: 130.3958 - val_mean_absolute_error: 4.2233
# Epoch 34/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 352.3824 - pearson: 0.2226 - mean_squared_error: 352.3824 - mean_absolute_error: 7.9037
# Epoch 00034: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 352.0821 - pearson: 0.2234 - mean_squared_error: 352.0821 - mean_absolute_error: 7.9074 - val_loss: 131.5154 - val_pearson: 0.1559 - val_mean_squared_error: 131.5154 - val_mean_absolute_error: 4.4101
# Epoch 35/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 355.4451 - pearson: 0.2271 - mean_squared_error: 355.4452 - mean_absolute_error: 8.1245
# Epoch 00035: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 354.2662 - pearson: 0.2279 - mean_squared_error: 354.2662 - mean_absolute_error: 8.1175 - val_loss: 131.5632 - val_pearson: 0.1512 - val_mean_squared_error: 131.5632 - val_mean_absolute_error: 4.3457
# Epoch 36/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 353.1303 - pearson: 0.2289 - mean_squared_error: 353.1303 - mean_absolute_error: 7.9748
# Epoch 00036: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 352.1938 - pearson: 0.2291 - mean_squared_error: 352.1938 - mean_absolute_error: 7.9684 - val_loss: 131.5187 - val_pearson: 0.1522 - val_mean_squared_error: 131.5187 - val_mean_absolute_error: 4.3898
# Epoch 37/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 355.3694 - pearson: 0.2243 - mean_squared_error: 355.3694 - mean_absolute_error: 7.9075
# Epoch 00037: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 353.6432 - pearson: 0.2256 - mean_squared_error: 353.6432 - mean_absolute_error: 7.8984 - val_loss: 132.0846 - val_pearson: 0.1540 - val_mean_squared_error: 132.0846 - val_mean_absolute_error: 4.5404
# Epoch 38/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 349.0314 - pearson: 0.2220 - mean_squared_error: 349.0314 - mean_absolute_error: 7.9042
# Epoch 00038: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 352.9929 - pearson: 0.2217 - mean_squared_error: 352.9929 - mean_absolute_error: 7.9249 - val_loss: 132.6501 - val_pearson: 0.1531 - val_mean_squared_error: 132.6501 - val_mean_absolute_error: 4.5314
# Epoch 39/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 353.1436 - pearson: 0.2324 - mean_squared_error: 353.1436 - mean_absolute_error: 8.0141
# Epoch 00039: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 351.3334 - pearson: 0.2322 - mean_squared_error: 351.3334 - mean_absolute_error: 7.9961 - val_loss: 132.1688 - val_pearson: 0.1460 - val_mean_squared_error: 132.1688 - val_mean_absolute_error: 3.8629
# Epoch 40/150
# 1000/1000 [==============================] - 1s 659us/steps: 348.1602 - pearson: 0.2238 - mean_squared_error: 348.1602 - mean_
# [('loss', 196.36005346679687), ('pearson', 0.25355741131305692), ('mean_squared_error', 196.36004431152344), ('mean_absolute_error', 5.3878864326477052)]
# Test spearman: 0.326044059936
#
# Epoch 00040: val_loss did not improve
# 8000/8000 [==============================] - 18s 2ms/step - loss: 350.7063 - pearson: 0.2253 - mean_squared_error: 350.7063 - mean_absolute_error: 7.9683 - val_loss: 132.9133 - val_pearson: 0.1429 - val_mean_squared_error: 132.9133 - val_mean_absolute_error: 3.9675
# Epoch 41/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 348.3639 - pearson: 0.2309 - mean_squared_error: 348.3639 - mean_absolute_error: 7.9422
# Epoch 00041: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 350.4914 - pearson: 0.2315 - mean_squared_error: 350.4914 - mean_absolute_error: 7.9531 - val_loss: 132.3392 - val_pearson: 0.1494 - val_mean_squared_error: 132.3392 - val_mean_absolute_error: 4.3996
# Epoch 42/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 350.3724 - pearson: 0.2302 - mean_squared_error: 350.3724 - mean_absolute_error: 7.9952
# Epoch 00042: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 350.3489 - pearson: 0.2294 - mean_squared_error: 350.3489 - mean_absolute_error: 7.9874 - val_loss: 131.9572 - val_pearson: 0.1487 - val_mean_squared_error: 131.9572 - val_mean_absolute_error: 3.8951
# Epoch 43/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 351.3054 - pearson: 0.2298 - mean_squared_error: 351.3054 - mean_absolute_error: 7.9456
# Epoch 00043: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 349.8345 - pearson: 0.2299 - mean_squared_error: 349.8345 - mean_absolute_error: 7.9370 - val_loss: 132.2016 - val_pearson: 0.1477 - val_mean_squared_error: 132.2016 - val_mean_absolute_error: 4.1179
# Epoch 44/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 350.1923 - pearson: 0.2279 - mean_squared_error: 350.1923 - mean_absolute_error: 7.9562
# Epoch 00044: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 349.8925 - pearson: 0.2274 - mean_squared_error: 349.8925 - mean_absolute_error: 7.9563 - val_loss: 132.7284 - val_pearson: 0.1501 - val_mean_squared_error: 132.7284 - val_mean_absolute_error: 4.4413
# Epoch 45/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 349.5689 - pearson: 0.2288 - mean_squared_error: 349.5689 - mean_absolute_error: 7.9292
# Epoch 00045: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 348.4406 - pearson: 0.2283 - mean_squared_error: 348.4406 - mean_absolute_error: 7.9231 - val_loss: 132.0287 - val_pearson: 0.1469 - val_mean_squared_error: 132.0287 - val_mean_absolute_error: 4.1809
# Epoch 46/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 349.3282 - pearson: 0.2325 - mean_squared_error: 349.3282 - mean_absolute_error: 7.9355
# Epoch 00046: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 349.4650 - pearson: 0.2325 - mean_squared_error: 349.4650 - mean_absolute_error: 7.9328 - val_loss: 131.5234 - val_pearson: 0.1508 - val_mean_squared_error: 131.5234 - val_mean_absolute_error: 4.3367
# Epoch 47/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 351.2707 - pearson: 0.2305 - mean_squared_error: 351.2707 - mean_absolute_error: 7.9646
# Epoch 00047: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 351.6580 - pearson: 0.2302 - mean_squared_error: 351.6580 - mean_absolute_error: 7.9693 - val_loss: 133.4320 - val_pearson: 0.1475 - val_mean_squared_error: 133.4320 - val_mean_absolute_error: 4.5482
# Epoch 48/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 346.5639 - pearson: 0.2299 - mean_squared_error: 346.5639 - mean_absolute_error: 8.0003
# Epoch 00048: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 347.7598 - pearson: 0.2297 - mean_squared_error: 347.7598 - mean_absolute_error: 8.0067 - val_loss: 133.2380 - val_pearson: 0.1450 - val_mean_squared_error: 133.2380 - val_mean_absolute_error: 4.4829
# Epoch 49/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 351.8246 - pearson: 0.2311 - mean_squared_error: 351.8246 - mean_absolute_error: 8.0628
# Epoch 00049: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 350.2079 - pearson: 0.2336 - mean_squared_error: 350.2079 - mean_absolute_error: 8.0510 - val_loss: 130.9492 - val_pearson: 0.1513 - val_mean_squared_error: 130.9492 - val_mean_absolute_error: 4.1470
# Epoch 50/150
# 1000/1000 [==============================] - 1s 651us/steps: 350.0105 - pearson: 0.2289 - mean_squared_error: 350.0105 - mean_
# [('loss', 200.3134364013672), ('pearson', 0.26445817571878433), ('mean_squared_error', 200.31342892456055), ('mean_absolute_error', 6.5042720451354983)]
# Test spearman: 0.323856014531
#
# Epoch 00050: val_loss did not improve
# 8000/8000 [==============================] - 19s 2ms/step - loss: 349.0269 - pearson: 0.2301 - mean_squared_error: 349.0269 - mean_absolute_error: 7.9926 - val_loss: 139.6611 - val_pearson: 0.1437 - val_mean_squared_error: 139.6611 - val_mean_absolute_error: 4.9490
# Epoch 51/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 351.4947 - pearson: 0.2247 - mean_squared_error: 351.4947 - mean_absolute_error: 7.9885
# Epoch 00051: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 350.9650 - pearson: 0.2257 - mean_squared_error: 350.9650 - mean_absolute_error: 7.9775 - val_loss: 131.4406 - val_pearson: 0.1482 - val_mean_squared_error: 131.4406 - val_mean_absolute_error: 4.0468
# Epoch 52/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 348.2622 - pearson: 0.2286 - mean_squared_error: 348.2622 - mean_absolute_error: 7.9445
# Epoch 00052: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 347.6422 - pearson: 0.2285 - mean_squared_error: 347.6422 - mean_absolute_error: 7.9372 - val_loss: 131.2436 - val_pearson: 0.1491 - val_mean_squared_error: 131.2436 - val_mean_absolute_error: 4.2456
# Epoch 53/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 352.2823 - pearson: 0.2366 - mean_squared_error: 352.2823 - mean_absolute_error: 7.9959
# Epoch 00053: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 350.3415 - pearson: 0.2360 - mean_squared_error: 350.3415 - mean_absolute_error: 7.9758 - val_loss: 130.7007 - val_pearson: 0.1492 - val_mean_squared_error: 130.7007 - val_mean_absolute_error: 4.0634
# Epoch 54/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 348.0528 - pearson: 0.2351 - mean_squared_error: 348.0528 - mean_absolute_error: 8.0302
# Epoch 00054: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 348.1582 - pearson: 0.2338 - mean_squared_error: 348.1582 - mean_absolute_error: 8.0326 - val_loss: 132.0278 - val_pearson: 0.1459 - val_mean_squared_error: 132.0278 - val_mean_absolute_error: 4.1629
# Epoch 55/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 348.8326 - pearson: 0.2351 - mean_squared_error: 348.8326 - mean_absolute_error: 7.9354
# Epoch 00055: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 347.6446 - pearson: 0.2349 - mean_squared_error: 347.6446 - mean_absolute_error: 7.9365 - val_loss: 132.5955 - val_pearson: 0.1531 - val_mean_squared_error: 132.5955 - val_mean_absolute_error: 4.6274
# Epoch 56/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 346.8852 - pearson: 0.2294 - mean_squared_error: 346.8852 - mean_absolute_error: 7.9180
# Epoch 00056: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 347.4220 - pearson: 0.2312 - mean_squared_error: 347.4220 - mean_absolute_error: 7.9277 - val_loss: 132.1908 - val_pearson: 0.1458 - val_mean_squared_error: 132.1908 - val_mean_absolute_error: 4.1191
# Epoch 57/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 349.1274 - pearson: 0.2373 - mean_squared_error: 349.1274 - mean_absolute_error: 8.0190
# Epoch 00057: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 349.6176 - pearson: 0.2376 - mean_squared_error: 349.6176 - mean_absolute_error: 8.0226 - val_loss: 130.7672 - val_pearson: 0.1518 - val_mean_squared_error: 130.7672 - val_mean_absolute_error: 4.2334
# Epoch 58/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 348.4783 - pearson: 0.2360 - mean_squared_error: 348.4783 - mean_absolute_error: 8.0501
# Epoch 00058: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 348.5241 - pearson: 0.2357 - mean_squared_error: 348.5241 - mean_absolute_error: 8.0599 - val_loss: 133.1837 - val_pearson: 0.1529 - val_mean_squared_error: 133.1837 - val_mean_absolute_error: 4.7168
# Epoch 59/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 348.9285 - pearson: 0.2370 - mean_squared_error: 348.9285 - mean_absolute_error: 7.9567
# Epoch 00059: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 347.9001 - pearson: 0.2369 - mean_squared_error: 347.9001 - mean_absolute_error: 7.9568 - val_loss: 133.6367 - val_pearson: 0.1516 - val_mean_squared_error: 133.6367 - val_mean_absolute_error: 4.6698
# Epoch 60/150
# 1000/1000 [==============================] - ETA: 0s - loss: 344.6969 - pearson: 0.2354 - mean_squared_error: 344.6969 - mean_ - 1s 662us/step
# [('loss', 192.1361039428711), ('pearson', 0.27186146920919418), ('mean_squared_error', 192.13610366821288), ('mean_absolute_error', 5.9799284076690675)]
# Test spearman: 0.315782104403
#
# Epoch 00060: val_loss did not improve
# 8000/8000 [==============================] - 19s 2ms/step - loss: 346.7166 - pearson: 0.2351 - mean_squared_error: 346.7166 - mean_absolute_error: 7.9395 - val_loss: 132.3840 - val_pearson: 0.1494 - val_mean_squared_error: 132.3840 - val_mean_absolute_error: 4.5158
# Epoch 61/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 345.2025 - pearson: 0.2382 - mean_squared_error: 345.2025 - mean_absolute_error: 8.0578
# Epoch 00061: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 346.4795 - pearson: 0.2370 - mean_squared_error: 346.4795 - mean_absolute_error: 8.0673 - val_loss: 131.5003 - val_pearson: 0.1498 - val_mean_squared_error: 131.5003 - val_mean_absolute_error: 4.3111
# Epoch 62/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 349.1166 - pearson: 0.2408 - mean_squared_error: 349.1166 - mean_absolute_error: 7.9813
# Epoch 00062: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 348.2681 - pearson: 0.2411 - mean_squared_error: 348.2681 - mean_absolute_error: 7.9701 - val_loss: 131.7154 - val_pearson: 0.1495 - val_mean_squared_error: 131.7154 - val_mean_absolute_error: 4.3002
# Epoch 63/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 345.3427 - pearson: 0.2350 - mean_squared_error: 345.3427 - mean_absolute_error: 7.9745
# Epoch 00063: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 346.8021 - pearson: 0.2353 - mean_squared_error: 346.8021 - mean_absolute_error: 7.9837 - val_loss: 132.5795 - val_pearson: 0.1449 - val_mean_squared_error: 132.5795 - val_mean_absolute_error: 4.3252
# Epoch 64/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 347.0059 - pearson: 0.2362 - mean_squared_error: 347.0059 - mean_absolute_error: 7.9746
# Epoch 00064: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 346.3576 - pearson: 0.2353 - mean_squared_error: 346.3576 - mean_absolute_error: 7.9754 - val_loss: 132.3859 - val_pearson: 0.1448 - val_mean_squared_error: 132.3859 - val_mean_absolute_error: 4.1553
# Epoch 65/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 347.2516 - pearson: 0.2315 - mean_squared_error: 347.2516 - mean_absolute_error: 7.9105
# Epoch 00065: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 346.1731 - pearson: 0.2329 - mean_squared_error: 346.1731 - mean_absolute_error: 7.8968 - val_loss: 131.5180 - val_pearson: 0.1465 - val_mean_squared_error: 131.5180 - val_mean_absolute_error: 4.1347
# Epoch 66/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 347.2752 - pearson: 0.2430 - mean_squared_error: 347.2752 - mean_absolute_error: 7.9605
# Epoch 00066: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 346.2533 - pearson: 0.2418 - mean_squared_error: 346.2533 - mean_absolute_error: 7.9612 - val_loss: 133.1255 - val_pearson: 0.1386 - val_mean_squared_error: 133.1255 - val_mean_absolute_error: 3.8691
# Epoch 67/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 345.7108 - pearson: 0.2360 - mean_squared_error: 345.7108 - mean_absolute_error: 7.9309
# Epoch 00067: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 346.2942 - pearson: 0.2356 - mean_squared_error: 346.2942 - mean_absolute_error: 7.9310 - val_loss: 131.6661 - val_pearson: 0.1489 - val_mean_squared_error: 131.6661 - val_mean_absolute_error: 4.2696
# Epoch 68/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 341.1042 - pearson: 0.2386 - mean_squared_error: 341.1042 - mean_absolute_error: 7.8848
# Epoch 00068: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 347.0782 - pearson: 0.2386 - mean_squared_error: 347.0782 - mean_absolute_error: 7.9084 - val_loss: 131.9272 - val_pearson: 0.1448 - val_mean_squared_error: 131.9272 - val_mean_absolute_error: 4.0173
# Epoch 69/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 349.3216 - pearson: 0.2434 - mean_squared_error: 349.3216 - mean_absolute_error: 7.9652
# Epoch 00069: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 347.6589 - pearson: 0.2427 - mean_squared_error: 347.6589 - mean_absolute_error: 7.9545 - val_loss: 133.0960 - val_pearson: 0.1454 - val_mean_squared_error: 133.0960 - val_mean_absolute_error: 4.4400
# Epoch 70/150
# 1000/1000 [==============================] - 1s 671us/steps: 346.6768 - pearson: 0.2364 - mean_squared_error: 346.6768 - mean_
# [('loss', 193.89069903564453), ('pearson', 0.27192369532585142), ('mean_squared_error', 193.89069540405274), ('mean_absolute_error', 6.1848601055145265)]
# Test spearman: 0.32775053977
#
# Epoch 00070: val_loss did not improve
# 8000/8000 [==============================] - 19s 2ms/step - loss: 345.8164 - pearson: 0.2374 - mean_squared_error: 345.8164 - mean_absolute_error: 7.9142 - val_loss: 132.7063 - val_pearson: 0.1512 - val_mean_squared_error: 132.7063 - val_mean_absolute_error: 4.6595
# Epoch 71/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 346.6126 - pearson: 0.2335 - mean_squared_error: 346.6126 - mean_absolute_error: 8.0179
# Epoch 00071: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 344.8933 - pearson: 0.2338 - mean_squared_error: 344.8933 - mean_absolute_error: 8.0040 - val_loss: 132.0977 - val_pearson: 0.1439 - val_mean_squared_error: 132.0977 - val_mean_absolute_error: 4.0020
# Epoch 72/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 346.2688 - pearson: 0.2395 - mean_squared_error: 346.2688 - mean_absolute_error: 7.9883
# Epoch 00072: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 346.0117 - pearson: 0.2391 - mean_squared_error: 346.0117 - mean_absolute_error: 7.9901 - val_loss: 131.7242 - val_pearson: 0.1459 - val_mean_squared_error: 131.7242 - val_mean_absolute_error: 4.2259
# Epoch 73/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 346.2900 - pearson: 0.2386 - mean_squared_error: 346.2900 - mean_absolute_error: 7.9687
# Epoch 00073: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 346.6589 - pearson: 0.2402 - mean_squared_error: 346.6589 - mean_absolute_error: 7.9698 - val_loss: 130.8108 - val_pearson: 0.1505 - val_mean_squared_error: 130.8108 - val_mean_absolute_error: 4.2412
# Epoch 74/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 344.0498 - pearson: 0.2422 - mean_squared_error: 344.0498 - mean_absolute_error: 7.8850
# Epoch 00074: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 345.0209 - pearson: 0.2428 - mean_squared_error: 345.0209 - mean_absolute_error: 7.9052 - val_loss: 132.5648 - val_pearson: 0.1439 - val_mean_squared_error: 132.5648 - val_mean_absolute_error: 4.2810
# Epoch 75/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 343.5602 - pearson: 0.2396 - mean_squared_error: 343.5602 - mean_absolute_error: 7.9158
# Epoch 00075: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 345.0865 - pearson: 0.2382 - mean_squared_error: 345.0865 - mean_absolute_error: 7.9286 - val_loss: 131.4707 - val_pearson: 0.1454 - val_mean_squared_error: 131.4707 - val_mean_absolute_error: 4.1057
# Epoch 76/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 346.2234 - pearson: 0.2381 - mean_squared_error: 346.2234 - mean_absolute_error: 8.0260
# Epoch 00076: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 345.7668 - pearson: 0.2410 - mean_squared_error: 345.7668 - mean_absolute_error: 8.0231 - val_loss: 132.1930 - val_pearson: 0.1448 - val_mean_squared_error: 132.1930 - val_mean_absolute_error: 4.2529
# Epoch 77/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 346.5078 - pearson: 0.2350 - mean_squared_error: 346.5078 - mean_absolute_error: 7.8577
# Epoch 00077: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 346.3842 - pearson: 0.2343 - mean_squared_error: 346.3842 - mean_absolute_error: 7.8680 - val_loss: 134.1366 - val_pearson: 0.1488 - val_mean_squared_error: 134.1366 - val_mean_absolute_error: 4.7314
# Epoch 78/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 345.5210 - pearson: 0.2452 - mean_squared_error: 345.5210 - mean_absolute_error: 8.0451
# Epoch 00078: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 345.3243 - pearson: 0.2448 - mean_squared_error: 345.3243 - mean_absolute_error: 8.0472 - val_loss: 132.1096 - val_pearson: 0.1440 - val_mean_squared_error: 132.1096 - val_mean_absolute_error: 4.0224
# Epoch 79/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 346.4792 - pearson: 0.2446 - mean_squared_error: 346.4792 - mean_absolute_error: 7.8508
# Epoch 00079: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 345.4316 - pearson: 0.2438 - mean_squared_error: 345.4316 - mean_absolute_error: 7.8493 - val_loss: 132.1536 - val_pearson: 0.1442 - val_mean_squared_error: 132.1536 - val_mean_absolute_error: 4.2120
# Epoch 80/150
# 1000/1000 [==============================] - 1s 654us/steps: 345.7548 - pearson: 0.2509 - mean_squared_error: 345.7548 - mean_
# [('loss', 193.09801365661622), ('pearson', 0.27205539405345919), ('mean_squared_error', 193.09801461791992), ('mean_absolute_error', 6.1043274002075192)]
# Test spearman: 0.314699651884
#
# Epoch 00080: val_loss did not improve
# 8000/8000 [==============================] - 19s 2ms/step - loss: 344.9817 - pearson: 0.2516 - mean_squared_error: 344.9817 - mean_absolute_error: 7.9486 - val_loss: 133.2805 - val_pearson: 0.1469 - val_mean_squared_error: 133.2805 - val_mean_absolute_error: 4.6150
# Epoch 81/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 345.8297 - pearson: 0.2373 - mean_squared_error: 345.8297 - mean_absolute_error: 8.0190
# Epoch 00081: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 344.9244 - pearson: 0.2366 - mean_squared_error: 344.9244 - mean_absolute_error: 8.0120 - val_loss: 132.6915 - val_pearson: 0.1421 - val_mean_squared_error: 132.6915 - val_mean_absolute_error: 3.9821
# Epoch 82/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 346.5936 - pearson: 0.2376 - mean_squared_error: 346.5936 - mean_absolute_error: 7.9807
# Epoch 00082: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 345.8725 - pearson: 0.2370 - mean_squared_error: 345.8725 - mean_absolute_error: 7.9789 - val_loss: 132.4267 - val_pearson: 0.1451 - val_mean_squared_error: 132.4267 - val_mean_absolute_error: 4.3462
# Epoch 83/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 340.8122 - pearson: 0.2422 - mean_squared_error: 340.8122 - mean_absolute_error: 7.8976
# Epoch 00083: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 343.5659 - pearson: 0.2415 - mean_squared_error: 343.5659 - mean_absolute_error: 7.9151 - val_loss: 133.9070 - val_pearson: 0.1426 - val_mean_squared_error: 133.9070 - val_mean_absolute_error: 4.5289
# Epoch 84/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 346.7124 - pearson: 0.2435 - mean_squared_error: 346.7124 - mean_absolute_error: 7.9753
# Epoch 00084: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 345.0716 - pearson: 0.2427 - mean_squared_error: 345.0716 - mean_absolute_error: 7.9593 - val_loss: 132.5120 - val_pearson: 0.1464 - val_mean_squared_error: 132.5120 - val_mean_absolute_error: 4.4528
# Epoch 85/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 343.9391 - pearson: 0.2442 - mean_squared_error: 343.9391 - mean_absolute_error: 7.9969
# Epoch 00085: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 344.2539 - pearson: 0.2450 - mean_squared_error: 344.2539 - mean_absolute_error: 7.9932 - val_loss: 132.6074 - val_pearson: 0.1437 - val_mean_squared_error: 132.6074 - val_mean_absolute_error: 4.3895
# Epoch 86/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 345.2863 - pearson: 0.2400 - mean_squared_error: 345.2863 - mean_absolute_error: 7.8948
# Epoch 00086: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 344.1225 - pearson: 0.2407 - mean_squared_error: 344.1225 - mean_absolute_error: 7.8836 - val_loss: 132.2738 - val_pearson: 0.1439 - val_mean_squared_error: 132.2738 - val_mean_absolute_error: 4.2526
# Epoch 87/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 344.7780 - pearson: 0.2380 - mean_squared_error: 344.7780 - mean_absolute_error: 7.9468
# Epoch 00087: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 343.9325 - pearson: 0.2411 - mean_squared_error: 343.9325 - mean_absolute_error: 7.9321 - val_loss: 132.6127 - val_pearson: 0.1426 - val_mean_squared_error: 132.6127 - val_mean_absolute_error: 4.2025
# Epoch 88/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 345.7250 - pearson: 0.2404 - mean_squared_error: 345.7250 - mean_absolute_error: 7.9835
# Epoch 00088: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 343.8247 - pearson: 0.2404 - mean_squared_error: 343.8247 - mean_absolute_error: 7.9611 - val_loss: 132.9742 - val_pearson: 0.1397 - val_mean_squared_error: 132.9742 - val_mean_absolute_error: 4.1250
# Epoch 89/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 345.6244 - pearson: 0.2444 - mean_squared_error: 345.6244 - mean_absolute_error: 7.9578
# Epoch 00089: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 343.7425 - pearson: 0.2462 - mean_squared_error: 343.7425 - mean_absolute_error: 7.9385 - val_loss: 133.1146 - val_pearson: 0.1382 - val_mean_squared_error: 133.1146 - val_mean_absolute_error: 4.0543
# Epoch 90/150
# 1000/1000 [==============================] - 1s 660us/steps: 347.1718 - pearson: 0.2415 - mean_squared_error: 347.1718 - mean_
# [('loss', 194.27667802429198), ('pearson', 0.26056502240896223), ('mean_squared_error', 194.27667430114747), ('mean_absolute_error', 5.5834083805084225)]
# Test spearman: 0.302470412997
#
# Epoch 00090: val_loss did not improve
# 8000/8000 [==============================] - 19s 2ms/step - loss: 346.1993 - pearson: 0.2410 - mean_squared_error: 346.1993 - mean_absolute_error: 8.0339 - val_loss: 132.8874 - val_pearson: 0.1391 - val_mean_squared_error: 132.8874 - val_mean_absolute_error: 4.2059
# Epoch 91/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 343.6558 - pearson: 0.2444 - mean_squared_error: 343.6558 - mean_absolute_error: 7.8633
# Epoch 00091: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 343.1745 - pearson: 0.2455 - mean_squared_error: 343.1745 - mean_absolute_error: 7.8666 - val_loss: 132.5126 - val_pearson: 0.1408 - val_mean_squared_error: 132.5126 - val_mean_absolute_error: 4.1711
# Epoch 92/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 341.4072 - pearson: 0.2421 - mean_squared_error: 341.4072 - mean_absolute_error: 7.8644
# Epoch 00092: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 344.3271 - pearson: 0.2412 - mean_squared_error: 344.3271 - mean_absolute_error: 7.8798 - val_loss: 133.0620 - val_pearson: 0.1414 - val_mean_squared_error: 133.0620 - val_mean_absolute_error: 4.2706
# Epoch 93/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 339.7717 - pearson: 0.2427 - mean_squared_error: 339.7717 - mean_absolute_error: 8.0100
# Epoch 00093: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 343.0622 - pearson: 0.2433 - mean_squared_error: 343.0622 - mean_absolute_error: 8.0294 - val_loss: 132.4278 - val_pearson: 0.1425 - val_mean_squared_error: 132.4278 - val_mean_absolute_error: 4.1007
# Epoch 94/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 342.1674 - pearson: 0.2459 - mean_squared_error: 342.1674 - mean_absolute_error: 7.8499
# Epoch 00094: val_loss did not improve
# ...
# Epoch 00118: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 342.3767 - pearson: 0.2441 - mean_squared_error: 342.3767 - mean_absolute_error: 7.9139 - val_loss: 133.3427 - val_pearson: 0.1445 - val_mean_squared_error: 133.3427 - val_mean_absolute_error: 4.5285
# Epoch 119/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 341.9666 - pearson: 0.2472 - mean_squared_error: 341.9666 - mean_absolute_error: 7.9926
# Epoch 00119: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 341.1395 - pearson: 0.2460 - mean_squared_error: 341.1395 - mean_absolute_error: 7.9888 - val_loss: 133.8932 - val_pearson: 0.1401 - val_mean_squared_error: 133.8932 - val_mean_absolute_error: 4.4209
# Epoch 120/150
# 1000/1000 [==============================] - 1s 669us/steps: 340.7401 - pearson: 0.2495 - mean_squared_error: 340.7401 - mean_
# [('loss', 190.42836163330077), ('pearson', 0.2731304762363434), ('mean_squared_error', 190.42836297607423), ('mean_absolute_error', 5.8428546772003171)]
# Test spearman: 0.319138318391
#
# Epoch 00120: val_loss did not improve
# 8000/8000 [==============================] - 19s 2ms/step - loss: 340.7454 - pearson: 0.2493 - mean_squared_error: 340.7454 - mean_absolute_error: 7.9355 - val_loss: 132.1950 - val_pearson: 0.1459 - val_mean_squared_error: 132.1950 - val_mean_absolute_error: 4.4392
# Epoch 121/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 342.1536 - pearson: 0.2499 - mean_squared_error: 342.1536 - mean_absolute_error: 7.9897
# Epoch 00121: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 342.2516 - pearson: 0.2488 - mean_squared_error: 342.2516 - mean_absolute_error: 7.9848 - val_loss: 133.1923 - val_pearson: 0.1382 - val_mean_squared_error: 133.1923 - val_mean_absolute_error: 4.1170
# Epoch 122/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 339.3513 - pearson: 0.2468 - mean_squared_error: 339.3513 - mean_absolute_error: 8.0001
# Epoch 00122: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 341.2166 - pearson: 0.2465 - mean_squared_error: 341.2166 - mean_absolute_error: 8.0155 - val_loss: 132.9667 - val_pearson: 0.1378 - val_mean_squared_error: 132.9667 - val_mean_absolute_error: 4.0795
# Epoch 123/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 340.3337 - pearson: 0.2468 - mean_squared_error: 340.3337 - mean_absolute_error: 7.8267
# Epoch 00123: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 341.5631 - pearson: 0.2457 - mean_squared_error: 341.5631 - mean_absolute_error: 7.8414 - val_loss: 133.2208 - val_pearson: 0.1414 - val_mean_squared_error: 133.2208 - val_mean_absolute_error: 4.3485
# Epoch 124/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 333.3285 - pearson: 0.2481 - mean_squared_error: 333.3285 - mean_absolute_error: 7.8530
# Epoch 00124: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 340.9095 - pearson: 0.2480 - mean_squared_error: 340.9095 - mean_absolute_error: 7.8927 - val_loss: 132.9264 - val_pearson: 0.1436 - val_mean_squared_error: 132.9264 - val_mean_absolute_error: 4.4181
# Epoch 125/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 342.8931 - pearson: 0.2471 - mean_squared_error: 342.8931 - mean_absolute_error: 7.9112
# Epoch 00125: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 342.6278 - pearson: 0.2475 - mean_squared_error: 342.6278 - mean_absolute_error: 7.9174 - val_loss: 133.6942 - val_pearson: 0.1428 - val_mean_squared_error: 133.6942 - val_mean_absolute_error: 4.4620
# Epoch 126/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 342.0371 - pearson: 0.2470 - mean_squared_error: 342.0371 - mean_absolute_error: 7.8714
# Epoch 00126: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 341.6753 - pearson: 0.2456 - mean_squared_error: 341.6753 - mean_absolute_error: 7.8728 - val_loss: 133.6720 - val_pearson: 0.1366 - val_mean_squared_error: 133.6720 - val_mean_absolute_error: 4.1606
# Epoch 127/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 343.3921 - pearson: 0.2449 - mean_squared_error: 343.3921 - mean_absolute_error: 7.9035
# Epoch 00127: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 342.6417 - pearson: 0.2468 - mean_squared_error: 342.6417 - mean_absolute_error: 7.9053 - val_loss: 134.2248 - val_pearson: 0.1425 - val_mean_squared_error: 134.2248 - val_mean_absolute_error: 4.5710
# Epoch 128/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 340.9929 - pearson: 0.2448 - mean_squared_error: 340.9929 - mean_absolute_error: 7.9855
# Epoch 00128: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 341.7595 - pearson: 0.2456 - mean_squared_error: 341.7596 - mean_absolute_error: 7.9853 - val_loss: 132.9030 - val_pearson: 0.1414 - val_mean_squared_error: 132.9030 - val_mean_absolute_error: 4.3449
# Epoch 129/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 338.5166 - pearson: 0.2442 - mean_squared_error: 338.5166 - mean_absolute_error: 7.9346
# Epoch 00129: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 340.5856 - pearson: 0.2449 - mean_squared_error: 340.5856 - mean_absolute_error: 7.9486 - val_loss: 133.6919 - val_pearson: 0.1362 - val_mean_squared_error: 133.6919 - val_mean_absolute_error: 4.1508
# Epoch 130/150
# 1000/1000 [==============================] - 1s 661us/steps: 340.6675 - pearson: 0.2554 - mean_squared_error: 340.6675 - mean_
# [('loss', 192.26026411437988), ('pearson', 0.26982437789440156), ('mean_squared_error', 192.26026510620116), ('mean_absolute_error', 5.5946189765930177)]
# Test spearman: 0.318507012627
#
# Epoch 00130: val_loss did not improve
# 8000/8000 [==============================] - 19s 2ms/step - loss: 341.1740 - pearson: 0.2539 - mean_squared_error: 341.1739 - mean_absolute_error: 7.8701 - val_loss: 132.8668 - val_pearson: 0.1397 - val_mean_squared_error: 132.8668 - val_mean_absolute_error: 4.2305
# Epoch 131/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 341.0545 - pearson: 0.2480 - mean_squared_error: 341.0545 - mean_absolute_error: 7.8564
# Epoch 00131: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 341.1305 - pearson: 0.2469 - mean_squared_error: 341.1305 - mean_absolute_error: 7.8605 - val_loss: 133.5933 - val_pearson: 0.1407 - val_mean_squared_error: 133.5933 - val_mean_absolute_error: 4.4088
# Epoch 132/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 341.5896 - pearson: 0.2567 - mean_squared_error: 341.5897 - mean_absolute_error: 7.8932
# Epoch 00132: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 341.3562 - pearson: 0.2561 - mean_squared_error: 341.3562 - mean_absolute_error: 7.8982 - val_loss: 133.3616 - val_pearson: 0.1385 - val_mean_squared_error: 133.3616 - val_mean_absolute_error: 4.2312
# Epoch 133/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 341.2721 - pearson: 0.2475 - mean_squared_error: 341.2721 - mean_absolute_error: 8.0179
# Epoch 00133: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 340.7617 - pearson: 0.2480 - mean_squared_error: 340.7617 - mean_absolute_error: 8.0149 - val_loss: 133.5631 - val_pearson: 0.1385 - val_mean_squared_error: 133.5631 - val_mean_absolute_error: 4.3430
# Epoch 134/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 341.7039 - pearson: 0.2447 - mean_squared_error: 341.7038 - mean_absolute_error: 7.9104
# Epoch 00134: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 340.2984 - pearson: 0.2480 - mean_squared_error: 340.2984 - mean_absolute_error: 7.9009 - val_loss: 133.0876 - val_pearson: 0.1381 - val_mean_squared_error: 133.0876 - val_mean_absolute_error: 4.2685
# Epoch 135/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 340.0672 - pearson: 0.2477 - mean_squared_error: 340.0672 - mean_absolute_error: 8.0107
# Epoch 00135: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 340.7655 - pearson: 0.2487 - mean_squared_error: 340.7655 - mean_absolute_error: 8.0218 - val_loss: 133.2399 - val_pearson: 0.1396 - val_mean_squared_error: 133.2399 - val_mean_absolute_error: 4.3658
# Epoch 136/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 340.0525 - pearson: 0.2454 - mean_squared_error: 340.0525 - mean_absolute_error: 7.9415
# Epoch 00136: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 340.9839 - pearson: 0.2444 - mean_squared_error: 340.9839 - mean_absolute_error: 7.9482 - val_loss: 133.5478 - val_pearson: 0.1366 - val_mean_squared_error: 133.5478 - val_mean_absolute_error: 4.1910
# Epoch 137/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 342.0405 - pearson: 0.2454 - mean_squared_error: 342.0405 - mean_absolute_error: 7.9235
# Epoch 00137: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 341.2043 - pearson: 0.2457 - mean_squared_error: 341.2043 - mean_absolute_error: 7.9189 - val_loss: 132.9670 - val_pearson: 0.1388 - val_mean_squared_error: 132.9670 - val_mean_absolute_error: 4.2337
# Epoch 138/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 340.2322 - pearson: 0.2510 - mean_squared_error: 340.2322 - mean_absolute_error: 7.8338
# Epoch 00138: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 341.2707 - pearson: 0.2498 - mean_squared_error: 341.2707 - mean_absolute_error: 7.8471 - val_loss: 133.5729 - val_pearson: 0.1402 - val_mean_squared_error: 133.5729 - val_mean_absolute_error: 4.4513
# Epoch 139/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 339.9323 - pearson: 0.2538 - mean_squared_error: 339.9323 - mean_absolute_error: 7.8927
# Epoch 00139: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 339.6957 - pearson: 0.2542 - mean_squared_error: 339.6957 - mean_absolute_error: 7.8924 - val_loss: 134.2978 - val_pearson: 0.1396 - val_mean_squared_error: 134.2978 - val_mean_absolute_error: 4.5149
# Epoch 140/150
# 1000/1000 [==============================] - 1s 675us/steps: 341.3793 - pearson: 0.2487 - mean_squared_error: 341.3793 - mean_
# [('loss', 192.18818878173829), ('pearson', 0.26286900573968885), ('mean_squared_error', 192.18818449401854), ('mean_absolute_error', 5.6982094287872318)]
# Test spearman: 0.319748867464
#
# Epoch 00140: val_loss did not improve
# 8000/8000 [==============================] - 19s 2ms/step - loss: 340.2980 - pearson: 0.2518 - mean_squared_error: 340.2980 - mean_absolute_error: 7.9832 - val_loss: 133.2181 - val_pearson: 0.1399 - val_mean_squared_error: 133.2181 - val_mean_absolute_error: 4.3218
# Epoch 141/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 341.5699 - pearson: 0.2534 - mean_squared_error: 341.5699 - mean_absolute_error: 7.8958
# Epoch 00141: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 340.2255 - pearson: 0.2527 - mean_squared_error: 340.2255 - mean_absolute_error: 7.8855 - val_loss: 133.2986 - val_pearson: 0.1365 - val_mean_squared_error: 133.2985 - val_mean_absolute_error: 4.1005
# Epoch 142/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 342.3300 - pearson: 0.2508 - mean_squared_error: 342.3300 - mean_absolute_error: 7.8971
# Epoch 00142: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 341.5165 - pearson: 0.2512 - mean_squared_error: 341.5165 - mean_absolute_error: 7.9026 - val_loss: 133.3492 - val_pearson: 0.1423 - val_mean_squared_error: 133.3492 - val_mean_absolute_error: 4.4468
# Epoch 143/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 339.5243 - pearson: 0.2502 - mean_squared_error: 339.5243 - mean_absolute_error: 7.9140
# Epoch 00143: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 340.0107 - pearson: 0.2514 - mean_squared_error: 340.0107 - mean_absolute_error: 7.9249 - val_loss: 133.3181 - val_pearson: 0.1384 - val_mean_squared_error: 133.3181 - val_mean_absolute_error: 4.3054
# Epoch 144/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 342.6484 - pearson: 0.2458 - mean_squared_error: 342.6484 - mean_absolute_error: 8.0090
# Epoch 00144: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 340.8835 - pearson: 0.2486 - mean_squared_error: 340.8835 - mean_absolute_error: 7.9920 - val_loss: 133.3398 - val_pearson: 0.1388 - val_mean_squared_error: 133.3398 - val_mean_absolute_error: 4.3085
# Epoch 145/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 339.7725 - pearson: 0.2580 - mean_squared_error: 339.7725 - mean_absolute_error: 7.9608
# Epoch 00145: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 339.9352 - pearson: 0.2586 - mean_squared_error: 339.9352 - mean_absolute_error: 7.9616 - val_loss: 132.6428 - val_pearson: 0.1417 - val_mean_squared_error: 132.6428 - val_mean_absolute_error: 4.3365
# Epoch 146/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 341.3587 - pearson: 0.2478 - mean_squared_error: 341.3587 - mean_absolute_error: 7.9211
# Epoch 00146: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 340.4367 - pearson: 0.2487 - mean_squared_error: 340.4367 - mean_absolute_error: 7.9179 - val_loss: 133.6034 - val_pearson: 0.1375 - val_mean_squared_error: 133.6034 - val_mean_absolute_error: 4.3129
# Epoch 147/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 342.6168 - pearson: 0.2443 - mean_squared_error: 342.6168 - mean_absolute_error: 7.9550
# Epoch 00147: val_loss did not improve
# 8000/8000 [==============================] - 17s 2ms/step - loss: 340.9897 - pearson: 0.2440 - mean_squared_error: 340.9897 - mean_absolute_error: 7.9388 - val_loss: 133.4552 - val_pearson: 0.1387 - val_mean_squared_error: 133.4552 - val_mean_absolute_error: 4.2943
# Epoch 148/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 340.8184 - pearson: 0.2476 - mean_squared_error: 340.8184 - mean_absolute_error: 7.8314
# Epoch 00148: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 340.2210 - pearson: 0.2474 - mean_squared_error: 340.2210 - mean_absolute_error: 7.8317 - val_loss: 133.0116 - val_pearson: 0.1397 - val_mean_squared_error: 133.0116 - val_mean_absolute_error: 4.3517
# Epoch 149/150
# 7936/8000 [============================>.] - ETA: 0s - loss: 340.0891 - pearson: 0.2507 - mean_squared_error: 340.0891 - mean_absolute_error: 7.8994
# Epoch 00149: val_loss did not improve
# 8000/8000 [==============================] - 16s 2ms/step - loss: 340.0626 - pearson: 0.2498 - mean_squared_error: 340.0626 - mean_absolute_error: 7.9017 - val_loss: 133.9546 - val_pearson: 0.1341 - val_mean_squared_error: 133.9546 - val_mean_absolute_error: 4.0674
# Epoch 150/150
# 1000/1000 [==============================] - 1s 670us/steps: 342.0458 - pearson: 0.2481 - mean_squared_error: 342.0458 - mean_
# [('loss', 191.53926989746094), ('pearson', 0.26872505080699921), ('mean_squared_error', 191.53926698303223), ('mean_absolute_error', 5.6033562793731688)]
# Test spearman: 0.31984576752
#
# Epoch 00150: val_loss did not improve
# 8000/8000 [==============================] - 19s 2ms/step - loss: 340.5690 - pearson: 0.2471 - mean_squared_error: 340.5690 - mean_absolute_error: 7.7957 - val_loss: 133.0419 - val_pearson: 0.1396 - val_mean_squared_error: 133.0419 - val_mean_absolute_error: 4.2520
