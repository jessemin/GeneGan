# %% [markdown]
# # Gan Baseline

# %% [markdown]
# #### NOTE: Need to activate genomelake environment before this code. Simply type 'genomelake' in terminal.

# %%
# %env CUDA_VISIBLE_DEVICES=6,7
import os, sys
sys.path.append("..")
import random
# custom file path package
from data import Data_Directories
# custom utility package
from utils.compute_util import *
# package for genomic data
from pybedtools import Interval, BedTool
from genomelake.extractors import ArrayExtractor, BigwigExtractor
# package for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats.stats import pearsonr,spearmanr
import tensorflow as tf
# Out:
# env: CUDA_VISIBLE_DEVICES=6,7
# Using TensorFlow backend.

# %%
window_size = 2001
process_all = False
sample_num = 1000

# %%
# retrieve data
data = Data_Directories()
print data.intervals.keys()
print data.input_atac['day0'].keys()
print data.output_histone['day0'].keys()
# Out:
# ['day6', 'day3', 'day0']
# ['100', '140']
# ['H3K27me3', 'H3K4me1', 'H3K27ac']

# %%
# get intervals for day0 data
day0_intervals = list(BedTool(data.intervals['day0']))
print '# of Intervals Extracted for day0: {}'.format(len(day0_intervals))
# Out:
# # of Intervals Extracted for day0: 267226

# %%
# create an ArrayExtractor for ATAC-seq for day0 with 140 base pairs
bw_140bp_day0 = ArrayExtractor(data.input_atac['day0']['140'])
print 'Finished extracting bigwig for day0, 140bp'
# Out:
# Finished extracting bigwig for day0, 140bp

# %%
# create a BigWigExtractor for histone makr 'H3K27ac' for day0
bw_histone_mark_day0 = BigwigExtractor(data.output_histone['day0']['H3K27ac'])
print 'Finished extracting bigwig for day0, 140bp'
# Out:
# Finished extracting bigwig for day0, 140bp

# %%
# normalize day0 intervals
normalized_day0_intervals = [normalize_interval(interval, window_size) for interval in day0_intervals if normalize_interval(interval, window_size)]
print 'Finished normalizing day0 intervals!'
# Out:
# Finished normalizing day0 intervals!

# %%
assert (len(day0_intervals)==len(normalized_day0_intervals))
print "Examples of original intervals"
print [(int(_interval.start)+int(_interval[-1]), [int(_interval.start), int(_interval.end)])
       for _interval in day0_intervals[:3]]
print "Examples of normalized intervals with window size of {}".format(window_size)
print [([int(_interval.start), int(_interval.end)])
       for _interval in  normalized_day0_intervals[:3]]
# Out:
# Examples of original intervals
# [(123412027, [123411855, 123412989]), (123411941, [123411855, 123412989]), (131908564, [131908487, 131910071])]
# Examples of normalized intervals with window size of 2001
# [[123411027, 123413028], [123410941, 123412942], [131907564, 131909565]]

# %%
atac_seq_day0 = bw_140bp_day0(normalized_day0_intervals)
print atac_seq_day0.shape
# Out:
# (267226, 2001, 5)

# %%
#TODO: put this into utils if possible
def prune_invalid_intervals(intervals, bigwig_file):
    for _interval in intervals[:]:
        try:
            bigwig_file([_interval])
        except:
            intervals.remove(_interval)
            pass
        
print "Before pruning day0: {}".format(len(normalized_day0_intervals))
prune_invalid_intervals(normalized_day0_intervals, bw_140bp_day0)
print "After pruning day0: {}".format(len(normalized_day0_intervals))
# Out:
# Before pruning day0: 267226
# After pruning day0: 267226

# %%
print "Dimension of ATAC-seq signal: {}".format(bw_140bp_day0(normalized_day0_intervals[:1]).shape)
# Out:
# Dimension of ATAC-seq signal: (1, 2001, 5)

# %%
print "Dimension of histone mark signal: {}".format(bw_histone_mark_day0(normalized_day0_intervals[:1]).shape)
# Out:
# Dimension of histone mark signal: (1, 2001)

# %%
# replace nan values with zeros and convert it to p-values
histone_mark_day0 = np.nan_to_num(bw_histone_mark_day0(normalized_day0_intervals))
print histone_mark_day0.shape
# Out:
# (267226, 2001)

# %%
histone_mark_day0 = np.expand_dims(histone_mark_day0, axis=2)
print histone_mark_day0.shape
# Out:
# (267226, 2001, 1)

# %%
print "Example histone mark signal"
print "\tRaw value: {}".format(bw_histone_mark_day0(normalized_day0_intervals[:1])[0][:5].reshape(-1))
# Out:
# Example histone mark signal
# 	Raw value: [ 0.01014  0.01014  0.01014  0.02435  0.02435]

# %%
from keras.layers import Input, Dense, Conv1D, Dropout, BatchNormalization, Activation, ZeroPadding1D, Reshape, Flatten
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from keras import optimizers
from keras import metrics
from keras import losses
from keras import backend as K
from keras.callbacks import Callback, TensorBoard, ReduceLROnPlateau, ModelCheckpoint
from keras.optimizers import Adam

# %%
dropout_rate = 0.5
# parameters for first conv layer
hidden_filters_1 = 32
hidden_kernel_size_1 = 2001
# parameters for second conv layer
output_filters = 1
output_kernel_size = 16
# parameters for training
batch_size = 128
num_epochs = 300
evaluation_freq = 10

# %%
model_dir = os.path.join("models", "gan")
log_dir = os.path.join("logs", "gan")
srv_dir = os.path.join("/srv", "www", "kundaje", "jesikmin", "gan")
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
if not os.path.exists(log_dir):
    os.makedirs(log_dir)
if not os.path.exists(srv_dir):
    os.makedirs(srv_dir)

# %%
class GAN():
    def __init__(self):
        
        self.window_size = window_size
        self.channels = 5
        self.input_shape = (self.window_size, self.channels,)
        self.output_shape = (self.window_size, 1,)

        optimizer = Adam(0.0002, 0.5)

        # Build and compile the discriminator
        self.discriminator = self.build_discriminator()
        self.discriminator.compile(loss='binary_crossentropy', 
                                   optimizer=optimizer,
                                   metrics=['accuracy'])

        # Build and compile the generator
        self.generator = self.build_generator()
        self.generator.compile(loss='binary_crossentropy',
                               optimizer=optimizer)

        # The generator takes noise as input and generated imgs
        z = Input(shape=self.input_shape)
        img = self.generator(z)

        # For the combined model we will only train the generator
        self.discriminator.trainable = False

        # The valid takes generated images as input and determines validity
        valid = self.discriminator(img)

        # The combined model  (stacked generator and discriminator) takes
        # noise as input => generates images => determines validity 
        self.combined = Model(z, valid)
        self.combined.compile(loss='binary_crossentropy',
                              optimizer=optimizer)

    def build_generator(self):

        noise_shape = self.input_shape
        
        model = Sequential()

        model.add(Flatten(input_shape=noise_shape))
        model.add(Dense(256, input_shape=noise_shape))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(512))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(1024))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(np.prod(self.output_shape), activation='tanh'))
        model.add(Reshape(self.output_shape))

        model.summary()

        noise = Input(shape=noise_shape)
        img = model(noise)

        return Model(noise, img)

    def build_discriminator(self):
        model = Sequential()

        model.add(Flatten(input_shape=self.output_shape))
        model.add(Dense(512))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(256))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(1, activation='sigmoid'))
        model.summary()

        img = Input(shape=self.output_shape)
        validity = model(img)

        return Model(img, validity)

    def train(self, epochs, batch_size, X_train, y_train):
        
        max_pearson = -1.0

        half_batch = int(batch_size / 2)
            
        d_loss_real, d_loss_fake, g_loss = [1, 0], [1, 0], [1, 0]
            
        for epoch in range(epochs):
            
            # list for storing losses/accuracies for both discriminator and generator
            d_losses, d_accuracies, g_losses = [], [], []
            
            # sufficient number of minibatches for each epoch
            for _minibatch_idx in range(128):

                # ---------------------
                #  Train Discriminator
                # ---------------------

                # Select a random half batch of images
                dis_idx = np.random.randint(0, y_train.shape[0], half_batch)
                imgs = y_train[dis_idx]
                dis_noise = X_train[dis_idx]
                #noise = np.random.normal(0, 1, (half_batch, 100))

                # Generate a half batch of new images
                gen_imgs = self.generator.predict(dis_noise)

                # Train the discriminator
                if _minibatch_idx % 32 == 0:
                    d_loss_real = self.discriminator.train_on_batch(imgs, np.ones((half_batch, 1)))
                    d_loss_fake = self.discriminator.train_on_batch(gen_imgs, np.zeros((half_batch, 1)))
                    
                # take the average of each loss and accuracy
                d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
                
                # ---------------------
                #  Train Generator
                # ---------------------
                
                gen_idx = np.random.randint(0, y_train.shape[0], batch_size)
                gen_noise = X_train[gen_idx]
                #noise = np.random.normal(0, 1, (batch_size, 100))

                # The generator wants the discriminator to label the generated samples
                # as valid (ones)
                valid_y = np.array([1] * batch_size)

                # Train the generator
                g_loss = self.combined.train_on_batch(gen_noise, valid_y)
                
                d_losses.append(d_loss[0])
                d_accuracies.append(d_loss[1])
                
                g_losses.append(g_loss)
                
            # convert each histories into numpy arrays to get means
            d_losses = np.array(d_losses)
            d_accuracies = np.array(d_accuracies)
            g_losses = np.array(g_losses)
            
            predictions = self.generator.predict(X_train)
            pearsons = []
            for pred_idx in range(len(predictions)):
                prediction = predictions[pred_idx]
                pearsons.append(pearsonr(prediction, y_train[pred_idx]))
            avg_pearson = np.array(pearsons).mean()
            print "Pearson R on Train set: {}".format(avg_pearson)
            
            val_predictions = self.generator.predict(X_val)
            val_pearsons = []
            for val_pred_idx in range(len(val_predictions)):
                prediction = val_predictions[val_pred_idx]
                val_pearsons.append(pearsonr(prediction, y_val[val_pred_idx]))
            avg_val_pearson = np.array(val_pearsons).mean()
            print "Pearson R on Val set: {}".format(avg_val_pearson)  
            
            if max_pearson < avg_val_pearson:
                print "Perason on val improved from {} to {}".format(max_pearson, avg_pearson)
#                 _write_1D_deeplift_track(predictions.reshape(7500, 2001),
#                                          normalized_day0_intervals[:7500], os.path.join(srv_dir, 'train'))
#                 _write_1D_deeplift_track(val_predictions.reshape(2500, 2001),
#                                          normalized_day0_intervals[7500:10000], os.path.join(srv_dir, 'val'))
#                 f = open(os.path.join(srv_dir, 'meta.txt'), 'wb')
#                 f.write(str(self.epochs) + "  " + str(logs))
#                 f.close()
                max_pearson = avg_val_pearson
            
            # Plot the progress
            print ("%d [D loss: %f, acc.: %.2f%%] [G loss: %f]" % (epoch, d_losses.mean(), 100.0*d_accuracies.mean(), g_losses.mean()))

# %%
def pearson(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = K.mean(x)
    my = K.mean(y)
    xm, ym = x-mx, y-my
    r_num = K.sum(np.multiply(xm,ym))
    r_den = K.sqrt(np.multiply(K.sum(K.square(xm)), K.sum(K.square(ym))))
    r = r_num / r_den
    r = K.maximum(K.minimum(r, 1.0), -1.0)
    return K.square(r)

# %%
# Helper functions for writing the scores into bigwig file
from itertools import izip
from itertools import groupby
import subprocess

def interval_key(interval):
    return (interval.chrom, interval.start, interval.stop)

def merged_scores(scores, intervals, merge_type):
    # A generator that returns merged intervals/scores
    # Scores should have shape: #examples x #categories x #interval_size
    # Second dimension can be omitted for a 1D signal
    signal_dims = scores.ndim - 1
    assert signal_dims in {1, 2}

    # Only support max for now
    assert merge_type == 'max'
    score_first_dim = 1 if signal_dims == 1 else scores.shape[1]

    dtype = scores.dtype

    sort_idx, sorted_intervals = \
        zip(*sorted(enumerate(intervals),
                    key=lambda item: interval_key(item[1])))
    sorted_intervals = BedTool(sorted_intervals)

    # Require at least 1bp overlap
    # Explicitly convert to list otherwise it will keep opening a file when
    # retrieving an index resulting in an error (too many open files)
    interval_clust = list(sorted_intervals.cluster(d=-1))
    for _, group in groupby(izip(sort_idx, interval_clust),
                            key=lambda item: item[1].fields[-1]):
        idx_interval_pairs = list(group)
        group_idx, group_intervals = zip(*idx_interval_pairs)

        if len(idx_interval_pairs) == 1:
            yield group_intervals[0], scores[group_idx[0], ...]
        else:
            group_chrom = group_intervals[0].chrom
            group_start = min(interval.start for interval in group_intervals)
            group_stop = max(interval.stop for interval in group_intervals)

            # This part needs to change to support more merge_types (e.g. mean)
            group_score = np.full((score_first_dim, group_stop - group_start),
                                  -np.inf, dtype)
            for idx, interval in idx_interval_pairs:
                slice_start = interval.start - group_start
                slice_stop = slice_start + (interval.stop - interval.start)
                group_score[..., slice_start:slice_stop] = \
                    np.maximum(group_score[..., slice_start:slice_stop],
                               scores[idx, ...])
            if signal_dims == 1:
                group_score = group_score.squeeze(axis=0)
            yield Interval(group_chrom, group_start, group_stop), group_score
            
def interval_score_pairs(intervals, scores, merge_type):
    return (izip(intervals, scores) if merge_type is None
            else merged_scores(scores, intervals, merge_type))

def _write_1D_deeplift_track(scores, intervals, file_prefix, merge_type='max',
                             CHROM_SIZES='/mnt/data/annotations/by_release/hg19.GRCh37/hg19.chrom.sizes'):
    assert scores.ndim == 2

    bedgraph = file_prefix + '.bedGraph'
    bigwig = file_prefix + '.bw'

    print 'Writing 1D track of shape: {}'.format(scores.shape)
    print 'Writing to file: {}'.format(bigwig)

    with open(bedgraph, 'w') as fp:
        for interval, score in interval_score_pairs(intervals, scores,
                                                    merge_type):
            chrom = interval.chrom
            start = interval.start
            for score_idx, val in enumerate(score):
                fp.write('%s\t%d\t%d\t%g\n' % (chrom,
                                               start + score_idx,
                                               start + score_idx + 1,
                                               val))
    print 'Wrote bedgraph.'

    try:
        output = subprocess.check_output(
            ['wigToBigWig', bedgraph, CHROM_SIZES, bigwig],
            stderr=subprocess.STDOUT)
        print 'wigToBigWig output: {}'.format(output)
    except subprocess.CalledProcessError as e:
        print 'wigToBigWig terminated with exit code {}'.format(
            e.returncode)
        print 'output was:\n' + e.output

    print 'Wrote bigwig.'

# %%
print "Fitting the model..."
X_train, y_train = atac_seq_day0[:7500], histone_mark_day0[:7500]
X_val, y_val = atac_seq_day0[7500:10000], histone_mark_day0[7500:10000]
X_test, y_test = atac_seq_day0[10000:11000], histone_mark_day0[10000:11000]

gan = GAN()
gan.train(num_epochs, batch_size, X_train, y_train)
# Out:
# Fitting the model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_17 (Flatten)         (None, 2001)              0
# _________________________________________________________________
# dense_57 (Dense)             (None, 512)               1025024
# _________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)   (None, 512)               0
# _________________________________________________________________
# dense_58 (Dense)             (None, 256)               131328
# _________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dense_59 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 1,156,609
# Trainable params: 1,156,609
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_18 (Flatten)         (None, 10005)             0
# _________________________________________________________________
# dense_60 (Dense)             (None, 256)               2561536
# _________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_61 (Dense)             (None, 512)               131584
# _________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_62 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)   (None, 1024)              0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 1024)              4096
# _________________________________________________________________
# dense_63 (Dense)             (None, 2001)              2051025
# _________________________________________________________________
# reshape_9 (Reshape)          (None, 2001, 1)           0
# =================================================================
# Total params: 5,276,625
# Trainable params: 5,273,041
# Non-trainable params: 3,584
# _________________________________________________________________
# Pearson R on Train set: 0.214416489005
# Pearson R on Val set: 0.21262831986
# Perason on val improved from -1.0 to 0.214416489005
# 0 [D loss: 2.275196, acc.: 49.22%] [G loss: 0.031560]
# Pearson R on Train set: 0.183462098241
# Pearson R on Val set: 0.167299956083
# 1 [D loss: 1.915801, acc.: 45.90%] [G loss: 0.100421]
# Pearson R on Train set: 0.138743340969
# Pearson R on Val set: 0.120728634298
# 2 [D loss: 1.929895, acc.: 44.53%] [G loss: 0.089026]
# Pearson R on Train set: 0.110462367535
# Pearson R on Val set: 0.103334359825
# 3 [D loss: 2.564618, acc.: 35.74%] [G loss: 0.113089]
# Pearson R on Train set: 0.079607218504
# Pearson R on Val set: 0.0916267186403
# 4 [D loss: 2.451085, acc.: 38.67%] [G loss: 0.062819]
# Pearson R on Train set: 0.0509584322572
# Pearson R on Val set: 0.0633492618799
# 5 [D loss: 2.648160, acc.: 35.16%] [G loss: 0.081671]
# Pearson R on Train set: 0.071035541594
# Pearson R on Val set: 0.0874612405896
# 6 [D loss: 1.532536, acc.: 42.77%] [G loss: 0.104622]
# Pearson R on Train set: 0.0490476563573
# Pearson R on Val set: 0.0574793331325
# 7 [D loss: 2.078363, acc.: 43.55%] [G loss: 0.061920]
# Pearson R on Train set: 0.0328841097653
# Pearson R on Val set: 0.0415374524891
# 8 [D loss: 2.015645, acc.: 40.62%] [G loss: 0.062717]
# Pearson R on Train set: 0.0345410853624
# Pearson R on Val set: 0.0493251271546
# 9 [D loss: 2.071832, acc.: 39.45%] [G loss: 0.068712]
# Pearson R on Train set: 0.0430440269411
# Pearson R on Val set: 0.0516920164227
# 10 [D loss: 1.781754, acc.: 42.97%] [G loss: 0.069882]
# Pearson R on Train set: 0.0608303137124
# Pearson R on Val set: 0.0653343647718
# 11 [D loss: 1.687938, acc.: 43.55%] [G loss: 0.073282]
# Pearson R on Train set: 0.10072324425
# Pearson R on Val set: 0.0978637486696
# 12 [D loss: 1.428874, acc.: 40.62%] [G loss: 0.117902]
# Pearson R on Train set: 0.108684718609
# Pearson R on Val set: 0.086209885776
# 13 [D loss: 1.342645, acc.: 42.77%] [G loss: 0.131781]
# Pearson R on Train set: 0.0746127218008
# Pearson R on Val set: 0.0730639621615
# 14 [D loss: 1.482312, acc.: 41.41%] [G loss: 0.108866]
# Pearson R on Train set: 0.0591997876763
# Pearson R on Val set: 0.0693114250898
# 15 [D loss: 2.079725, acc.: 33.01%] [G loss: 0.088208]
# Pearson R on Train set: 0.123840369284
# Pearson R on Val set: 0.12905587256
# 16 [D loss: 2.268206, acc.: 38.67%] [G loss: 0.051966]
# Pearson R on Train set: 0.109408609569
# Pearson R on Val set: 0.105493992567
# 17 [D loss: 1.469244, acc.: 41.02%] [G loss: 0.112894]
# Pearson R on Train set: 0.0648683011532
# Pearson R on Val set: 0.0472736097872
# 18 [D loss: 1.377518, acc.: 43.36%] [G loss: 0.107264]
# Pearson R on Train set: 0.0856133624911
# Pearson R on Val set: 0.0756789445877
# 19 [D loss: 1.364647, acc.: 33.59%] [G loss: 0.155381]
# Pearson R on Train set: 0.0766863748431
# Pearson R on Val set: 0.0686246529222
# 20 [D loss: 1.279286, acc.: 40.82%] [G loss: 0.159272]
# Pearson R on Train set: 0.0827837139368
# Pearson R on Val set: 0.0735180452466
# 21 [D loss: 1.154412, acc.: 33.98%] [G loss: 0.222402]
# Pearson R on Train set: 0.0806018263102
# Pearson R on Val set: 0.0731969028711
# 22 [D loss: 1.250589, acc.: 37.50%] [G loss: 0.196784]
# Pearson R on Train set: 0.0721547454596
# Pearson R on Val set: 0.0578960329294
# 23 [D loss: 1.162045, acc.: 39.84%] [G loss: 0.216243]
# Pearson R on Train set: 0.0542282871902
# Pearson R on Val set: 0.0459644235671
# 24 [D loss: 1.038935, acc.: 38.28%] [G loss: 0.241154]
# Pearson R on Train set: 0.0439976118505
# Pearson R on Val set: 0.0421818494797
# 25 [D loss: 1.060501, acc.: 33.98%] [G loss: 0.258192]
# Pearson R on Train set: 0.0533899143338
# Pearson R on Val set: 0.0508635938168
# 26 [D loss: 1.088111, acc.: 38.28%] [G loss: 0.261513]
# Pearson R on Train set: 0.0641137734056
# Pearson R on Val set: 0.0537790358067
# 27 [D loss: 1.112462, acc.: 34.18%] [G loss: 0.254195]
# Pearson R on Train set: 0.0965167954564
# Pearson R on Val set: 0.11151111871
# 28 [D loss: 0.920741, acc.: 38.67%] [G loss: 0.311038]
# Pearson R on Train set: 0.093074887991
# Pearson R on Val set: 0.109028249979
# 29 [D loss: 0.822011, acc.: 31.64%] [G loss: 0.415219]
# Pearson R on Train set: 0.0451768897474
# Pearson R on Val set: 0.053463395685
# 30 [D loss: 0.784831, acc.: 31.84%] [G loss: 0.444529]
# Pearson R on Train set: 0.0420285686851
# Pearson R on Val set: 0.0520627424121
# 31 [D loss: 0.822540, acc.: 31.45%] [G loss: 0.413350]
# Pearson R on Train set: 0.042529899627
# Pearson R on Val set: 0.0522529184818
# 32 [D loss: 0.797019, acc.: 30.86%] [G loss: 0.472095]
# Pearson R on Train set: 0.0496186763048
# Pearson R on Val set: 0.0690567046404
# 33 [D loss: 0.738761, acc.: 32.81%] [G loss: 0.492372]
# Pearson R on Train set: 0.0703312382102
# Pearson R on Val set: 0.0759359151125
# 34 [D loss: 0.757606, acc.: 29.49%] [G loss: 0.492772]
# Pearson R on Train set: 0.0860356092453
# Pearson R on Val set: 0.0864482820034
# 35 [D loss: 0.719857, acc.: 33.20%] [G loss: 0.500077]
# Pearson R on Train set: 0.0660659819841
# Pearson R on Val set: 0.0673041269183
# 36 [D loss: 0.722930, acc.: 30.47%] [G loss: 0.514405]
# Pearson R on Train set: 0.058533359319
# Pearson R on Val set: 0.0677255019546
# 37 [D loss: 0.669292, acc.: 33.79%] [G loss: 0.553494]
# Pearson R on Train set: 0.0588823966682
# Pearson R on Val set: 0.0655718147755
# 38 [D loss: 0.686099, acc.: 32.81%] [G loss: 0.541138]
# Pearson R on Train set: 0.0764488205314
# Pearson R on Val set: 0.084643907845
# 39 [D loss: 0.772171, acc.: 31.64%] [G loss: 0.468244]
# Pearson R on Train set: 0.0846164897084
# Pearson R on Val set: 0.0934795066714
# 40 [D loss: 0.743652, acc.: 27.73%] [G loss: 0.557425]
# Pearson R on Train set: 0.0839923769236
# Pearson R on Val set: 0.0937248393893
# 41 [D loss: 0.657986, acc.: 31.25%] [G loss: 0.600924]
# Pearson R on Train set: 0.104898527265
# Pearson R on Val set: 0.118304885924
# 42 [D loss: 0.625962, acc.: 35.16%] [G loss: 0.628019]
# Pearson R on Train set: 0.0715246275067
# Pearson R on Val set: 0.0768351182342
# 43 [D loss: 0.658907, acc.: 44.73%] [G loss: 0.637829]
# Pearson R on Train set: 0.0870785862207
# Pearson R on Val set: 0.079628534615
# 44 [D loss: 0.779914, acc.: 30.08%] [G loss: 0.508128]
# Pearson R on Train set: 0.0424061119556
# Pearson R on Val set: 0.0440516807139
# 45 [D loss: 1.180473, acc.: 41.80%] [G loss: 0.250251]
# Pearson R on Train set: 0.0392159111798
# Pearson R on Val set: 0.038550850004
# 46 [D loss: 0.890552, acc.: 33.79%] [G loss: 0.410273]
# Pearson R on Train set: 0.0552607774734
# Pearson R on Val set: 0.0546418316662
# 47 [D loss: 0.760111, acc.: 38.48%] [G loss: 0.480283]
# Pearson R on Train set: 0.085331350565
# Pearson R on Val set: 0.0889769494534
# 48 [D loss: 0.688819, acc.: 33.20%] [G loss: 0.555420]
# Pearson R on Train set: 0.092511638999
# Pearson R on Val set: 0.0925892144442
# 49 [D loss: 0.684669, acc.: 28.32%] [G loss: 0.597486]
# Pearson R on Train set: 0.0797978118062
# Pearson R on Val set: 0.0766941681504
# 50 [D loss: 0.630242, acc.: 34.38%] [G loss: 0.609504]
# Pearson R on Train set: 0.0686846226454
# Pearson R on Val set: 0.0602388605475
# 51 [D loss: 0.628650, acc.: 32.81%] [G loss: 0.619007]
# Pearson R on Train set: 0.064719222486
# Pearson R on Val set: 0.0503913983703
# 52 [D loss: 0.652554, acc.: 30.66%] [G loss: 0.621029]
# Pearson R on Train set: 0.0656520575285
# Pearson R on Val set: 0.0484654717147
# 53 [D loss: 0.613148, acc.: 41.99%] [G loss: 0.637643]
# Pearson R on Train set: 0.0603594109416
# Pearson R on Val set: 0.0458969287574
# 54 [D loss: 0.630093, acc.: 37.30%] [G loss: 0.658213]
# Pearson R on Train set: 0.0583998598158
# Pearson R on Val set: 0.0495134107769
# 55 [D loss: 0.639711, acc.: 42.58%] [G loss: 0.660529]
# Pearson R on Train set: 0.0606516078115
# Pearson R on Val set: 0.0516984127462
# 56 [D loss: 0.680100, acc.: 27.34%] [G loss: 0.640578]
# Pearson R on Train set: 0.0594074204564
# Pearson R on Val set: 0.0499453879893
# 57 [D loss: 0.653600, acc.: 31.45%] [G loss: 0.643050]
# Pearson R on Train set: 0.0597996264696
# Pearson R on Val set: 0.0512128174305
# 58 [D loss: 0.668066, acc.: 29.88%] [G loss: 0.643126]
# Pearson R on Train set: 0.0570435784757
# Pearson R on Val set: 0.0570870228112
# 59 [D loss: 0.648742, acc.: 36.91%] [G loss: 0.647254]
# Pearson R on Train set: 0.0693940743804
# Pearson R on Val set: 0.0716662332416
# 60 [D loss: 0.627050, acc.: 33.59%] [G loss: 0.681419]
# Pearson R on Train set: 0.0809672698379
# Pearson R on Val set: 0.0856855139136
# 61 [D loss: 0.608319, acc.: 34.77%] [G loss: 0.672325]
# Pearson R on Train set: 0.0904606953263
# Pearson R on Val set: 0.0926378816366
# 62 [D loss: 0.615488, acc.: 38.09%] [G loss: 0.703639]
# Pearson R on Train set: 0.10327039659
# Pearson R on Val set: 0.100603125989
# 63 [D loss: 0.596012, acc.: 39.06%] [G loss: 0.716669]
# Pearson R on Train set: 0.0666638612747
# Pearson R on Val set: 0.0545407086611
# 64 [D loss: 0.587785, acc.: 36.52%] [G loss: 0.700204]
# Pearson R on Train set: 0.0599661171436
# Pearson R on Val set: 0.0463164262474
# 65 [D loss: 0.783224, acc.: 38.67%] [G loss: 0.594564]
# Pearson R on Train set: 0.0581936128438
# Pearson R on Val set: 0.058430865407
# 66 [D loss: 0.888597, acc.: 36.52%] [G loss: 0.412854]
# Pearson R on Train set: 0.0497008822858
# Pearson R on Val set: 0.0400469340384
# 67 [D loss: 0.709756, acc.: 29.49%] [G loss: 0.555948]
# Pearson R on Train set: 0.048105943948
# Pearson R on Val set: 0.0447702817619
# 68 [D loss: 0.654934, acc.: 37.11%] [G loss: 0.637148]
# Pearson R on Train set: 0.0488819740713
# Pearson R on Val set: 0.0430191084743
# 69 [D loss: 0.640929, acc.: 30.27%] [G loss: 0.641387]
# Pearson R on Train set: 0.0570292212069
# Pearson R on Val set: 0.0594790168107
# 70 [D loss: 0.612233, acc.: 54.49%] [G loss: 0.690456]
# Pearson R on Train set: 0.0934432670474
# Pearson R on Val set: 0.109868980944
# 71 [D loss: 0.628061, acc.: 32.23%] [G loss: 0.650069]
# Pearson R on Train set: 0.0623793751001
# Pearson R on Val set: 0.0707835480571
# 72 [D loss: 0.617993, acc.: 37.70%] [G loss: 0.689686]
# Pearson R on Train set: 0.042601056397
# Pearson R on Val set: 0.0438546687365
# 73 [D loss: 0.606613, acc.: 40.23%] [G loss: 0.675368]
# Pearson R on Train set: 0.0400056093931
# Pearson R on Val set: 0.0479770079255
# 74 [D loss: 0.617744, acc.: 50.00%] [G loss: 0.699780]
# Pearson R on Train set: 0.0387121029198
# Pearson R on Val set: 0.0442957393825
# 75 [D loss: 0.572223, acc.: 46.68%] [G loss: 0.713437]
# Pearson R on Train set: 0.0542485751212
# Pearson R on Val set: 0.0669701993465
# 76 [D loss: 0.598416, acc.: 47.66%] [G loss: 0.711707]
# Pearson R on Train set: 0.0549813061953
# Pearson R on Val set: 0.0648110732436
# 77 [D loss: 0.610905, acc.: 43.75%] [G loss: 0.710648]
# Pearson R on Train set: 0.0510389246047
# Pearson R on Val set: 0.0640560090542
# 78 [D loss: 0.597160, acc.: 58.40%] [G loss: 0.735180]
# Pearson R on Train set: 0.0948835462332
# Pearson R on Val set: 0.108234509826
# 79 [D loss: 0.627245, acc.: 57.81%] [G loss: 0.712654]
# Pearson R on Train set: 0.0794477239251
# Pearson R on Val set: 0.0917637422681
# 80 [D loss: 0.594901, acc.: 50.39%] [G loss: 0.741640]
# Pearson R on Train set: 0.0414495207369
# Pearson R on Val set: 0.0472548417747
# 81 [D loss: 0.581511, acc.: 48.44%] [G loss: 0.733248]
# Pearson R on Train set: 0.051385179162
# Pearson R on Val set: 0.0610700249672
# 82 [D loss: 0.602754, acc.: 57.81%] [G loss: 0.733038]
# Pearson R on Train set: 0.0539739839733
# Pearson R on Val set: 0.0626994594932
# 83 [D loss: 0.571074, acc.: 60.94%] [G loss: 0.741579]
# Pearson R on Train set: 0.0562087744474
# Pearson R on Val set: 0.0676802620292
# 84 [D loss: 0.603151, acc.: 55.66%] [G loss: 0.708353]
# Pearson R on Train set: 0.0610521659255
# Pearson R on Val set: 0.0695625171065
# 85 [D loss: 0.628154, acc.: 44.14%] [G loss: 0.694431]
# Pearson R on Train set: 0.0628285259008
# Pearson R on Val set: 0.0749657601118
# 86 [D loss: 0.581131, acc.: 59.18%] [G loss: 0.731481]
# Pearson R on Train set: 0.053468156606
# Pearson R on Val set: 0.0634083524346
# 87 [D loss: 0.613268, acc.: 54.88%] [G loss: 0.737517]
# Pearson R on Train set: 0.038875091821
# Pearson R on Val set: 0.0491724610329
# 88 [D loss: 0.574390, acc.: 57.81%] [G loss: 0.730506]
# Pearson R on Train set: 0.0324682407081
# Pearson R on Val set: 0.0378625914454
# 89 [D loss: 0.566257, acc.: 55.66%] [G loss: 0.789736]
# Pearson R on Train set: 0.0379294045269
# Pearson R on Val set: 0.0450237952173
# 90 [D loss: 0.580562, acc.: 59.18%] [G loss: 0.733337]
# Pearson R on Train set: 0.0422115437686
# Pearson R on Val set: 0.0534444265068
# 91 [D loss: 0.605125, acc.: 43.16%] [G loss: 0.709068]
# Pearson R on Train set: 0.0451550148427
# Pearson R on Val set: 0.0539927743375
# 92 [D loss: 0.591091, acc.: 56.05%] [G loss: 0.717772]
# Pearson R on Train set: 0.0502835847437
# Pearson R on Val set: 0.0611607246101
# 93 [D loss: 0.599720, acc.: 58.01%] [G loss: 0.715165]
# Pearson R on Train set: 0.0510197766125
# Pearson R on Val set: 0.0606827996671
# 94 [D loss: 0.610625, acc.: 58.79%] [G loss: 0.713789]
# Pearson R on Train set: 0.0570119135082
# Pearson R on Val set: 0.0690770968795
# 95 [D loss: 0.617628, acc.: 56.84%] [G loss: 0.729828]
# Pearson R on Train set: 0.0666762888432
# Pearson R on Val set: 0.0762615203857
# 96 [D loss: 0.587103, acc.: 59.18%] [G loss: 0.760841]
# Pearson R on Train set: 0.0527724027634
# Pearson R on Val set: 0.0546328127384
# 97 [D loss: 0.573848, acc.: 56.45%] [G loss: 0.788975]
# Pearson R on Train set: 0.0461085028946
# Pearson R on Val set: 0.0426279827952
# 98 [D loss: 0.598961, acc.: 46.68%] [G loss: 0.706431]
# Pearson R on Train set: 0.0491047129035
# Pearson R on Val set: 0.0497867427766
# 99 [D loss: 0.631236, acc.: 41.99%] [G loss: 0.702496]
# Pearson R on Train set: 0.0573221109807
# Pearson R on Val set: 0.0726429447532
# 100 [D loss: 0.600844, acc.: 55.08%] [G loss: 0.748089]
# Pearson R on Train set: 0.0544606558979
# Pearson R on Val set: 0.06942024827
# 101 [D loss: 0.570107, acc.: 67.19%] [G loss: 0.791450]
# Pearson R on Train set: 0.0768519043922
# Pearson R on Val set: 0.0945034474134
# 102 [D loss: 0.572058, acc.: 63.48%] [G loss: 0.719893]
# Pearson R on Train set: 0.0539547130466
# Pearson R on Val set: 0.0608012825251
# 103 [D loss: 0.560751, acc.: 58.01%] [G loss: 0.784435]
# Pearson R on Train set: 0.0597649551928
# Pearson R on Val set: 0.074226051569
# 104 [D loss: 0.575144, acc.: 56.05%] [G loss: 0.794749]
# Pearson R on Train set: 0.0401238836348
# Pearson R on Val set: 0.0519972108305
# 105 [D loss: 0.582530, acc.: 59.57%] [G loss: 0.781904]
# Pearson R on Train set: 0.0368197932839
# Pearson R on Val set: 0.0520501360297
# 106 [D loss: 0.565597, acc.: 66.60%] [G loss: 0.802196]
# Pearson R on Train set: 0.0308786984533
# Pearson R on Val set: 0.0502836890519
# 107 [D loss: 0.564048, acc.: 67.77%] [G loss: 0.784725]
# Pearson R on Train set: 0.0229674242437
# Pearson R on Val set: 0.0369457155466
# 108 [D loss: 0.568116, acc.: 70.90%] [G loss: 0.766668]
# Pearson R on Train set: 0.0176947526634
# Pearson R on Val set: 0.031617321074
# 109 [D loss: 0.584393, acc.: 53.91%] [G loss: 0.744763]
# Pearson R on Train set: 0.0199628490955
# Pearson R on Val set: 0.0265255440027
# 110 [D loss: 0.570111, acc.: 64.65%] [G loss: 0.756010]
# Pearson R on Train set: 0.0182210579515
# Pearson R on Val set: 0.0301317349076
# 111 [D loss: 0.553684, acc.: 68.95%] [G loss: 0.751701]
# Pearson R on Train set: 0.0262854043394
# Pearson R on Val set: 0.034527644515
# 112 [D loss: 0.587591, acc.: 56.84%] [G loss: 0.749494]
# Pearson R on Train set: 0.0372038334608
# Pearson R on Val set: 0.0362496823072
# 113 [D loss: 0.600553, acc.: 60.35%] [G loss: 0.754352]
# Pearson R on Train set: 0.0257409457117
# Pearson R on Val set: 0.0274645928293
# 114 [D loss: 0.586906, acc.: 60.35%] [G loss: 0.753120]
# Pearson R on Train set: 0.0364323966205
# Pearson R on Val set: 0.037504311651
# 115 [D loss: 0.605486, acc.: 59.38%] [G loss: 0.724423]
# Pearson R on Train set: 0.0404029339552
# Pearson R on Val set: 0.0429493971169
# 116 [D loss: 0.594483, acc.: 52.54%] [G loss: 0.731639]
# Pearson R on Train set: 0.0426918752491
# Pearson R on Val set: 0.0488996319473
# 117 [D loss: 0.610501, acc.: 40.43%] [G loss: 0.708849]
# Pearson R on Train set: 0.050067845732
# Pearson R on Val set: 0.0507836192846
# 118 [D loss: 0.600662, acc.: 56.64%] [G loss: 0.754499]
# Pearson R on Train set: 0.0562248788774
# Pearson R on Val set: 0.0570474117994
# 119 [D loss: 0.571371, acc.: 56.25%] [G loss: 0.746629]
# Pearson R on Train set: 0.052717782557
# Pearson R on Val set: 0.0589208267629
# 120 [D loss: 0.575946, acc.: 56.25%] [G loss: 0.737447]
# Pearson R on Train set: 0.0476762279868
# Pearson R on Val set: 0.0525117255747
# 121 [D loss: 0.597918, acc.: 54.88%] [G loss: 0.737930]
# Pearson R on Train set: 0.0495902113616
# Pearson R on Val set: 0.0595812387764
# 122 [D loss: 0.589201, acc.: 58.59%] [G loss: 0.743498]
# Pearson R on Train set: 0.0488514453173
# Pearson R on Val set: 0.0542503409088
# 123 [D loss: 0.576811, acc.: 56.45%] [G loss: 0.752241]
# Pearson R on Train set: 0.0469774901867
# Pearson R on Val set: 0.0508399531245
# 124 [D loss: 0.610788, acc.: 46.48%] [G loss: 0.717473]
# Pearson R on Train set: 0.0474924072623
# Pearson R on Val set: 0.0521470084786
# 125 [D loss: 0.591021, acc.: 57.62%] [G loss: 0.767243]
# Pearson R on Train set: 0.0539917498827
# Pearson R on Val set: 0.0507212169468
# 126 [D loss: 0.601092, acc.: 53.32%] [G loss: 0.762976]
# Pearson R on Train set: 0.0608167201281
# Pearson R on Val set: 0.0585914924741
# 127 [D loss: 0.574478, acc.: 61.13%] [G loss: 0.767155]
# Pearson R on Train set: 0.0720919072628
# Pearson R on Val set: 0.0784984752536
# 128 [D loss: 0.580289, acc.: 52.34%] [G loss: 0.757109]
# Pearson R on Train set: 0.0681324526668
# Pearson R on Val set: 0.0758378431201
# 129 [D loss: 0.566981, acc.: 65.62%] [G loss: 0.799011]
# Pearson R on Train set: 0.0610001459718
# Pearson R on Val set: 0.0598627850413
# 130 [D loss: 0.569926, acc.: 73.24%] [G loss: 0.787032]
# Pearson R on Train set: 0.0440853200853
# Pearson R on Val set: 0.039207585156
# 131 [D loss: 0.591884, acc.: 61.72%] [G loss: 0.736246]
# Pearson R on Train set: 0.0435788184404
# Pearson R on Val set: 0.0447637625039
# 132 [D loss: 0.576280, acc.: 58.59%] [G loss: 0.768504]
# Pearson R on Train set: 0.0399379320443
# Pearson R on Val set: 0.0372463986278
# 133 [D loss: 0.548032, acc.: 63.67%] [G loss: 0.778792]
# Pearson R on Train set: 0.0374805666506
# Pearson R on Val set: 0.0398224443197
# 134 [D loss: 0.572298, acc.: 56.45%] [G loss: 0.789846]
# Pearson R on Train set: 0.0443502925336
# Pearson R on Val set: 0.0430015511811
# 135 [D loss: 0.586709, acc.: 55.47%] [G loss: 0.757790]
# Pearson R on Train set: 0.053551107645
# Pearson R on Val set: 0.0606516003609
# 136 [D loss: 0.579006, acc.: 59.38%] [G loss: 0.783746]
# Pearson R on Train set: 0.0748543813825
# Pearson R on Val set: 0.0827234685421
# 137 [D loss: 0.586966, acc.: 56.25%] [G loss: 0.749466]
# Pearson R on Train set: 0.0739970356226
# Pearson R on Val set: 0.0783847570419
# 138 [D loss: 0.587050, acc.: 61.91%] [G loss: 0.795577]
# Pearson R on Train set: 0.064891256392
# Pearson R on Val set: 0.0620427019894
# 139 [D loss: 0.568213, acc.: 66.60%] [G loss: 0.821036]
# Pearson R on Train set: 0.0547306910157
# Pearson R on Val set: 0.0493682064116
# 140 [D loss: 0.554124, acc.: 76.76%] [G loss: 0.818362]
# Pearson R on Train set: 0.0474215559661
# Pearson R on Val set: 0.0472038835287
# 141 [D loss: 0.574214, acc.: 73.83%] [G loss: 0.784984]
# Pearson R on Train set: 0.0415687337518
# Pearson R on Val set: 0.046083342284
# 142 [D loss: 0.530450, acc.: 72.85%] [G loss: 0.822262]
# Pearson R on Train set: 0.0396754443645
# Pearson R on Val set: 0.0369536727667
# 143 [D loss: 0.555691, acc.: 71.09%] [G loss: 0.802740]
# Pearson R on Train set: 0.0354872979224
# Pearson R on Val set: 0.0376155227423
# 144 [D loss: 0.568911, acc.: 64.65%] [G loss: 0.784523]
# Pearson R on Train set: 0.0351852960885
# Pearson R on Val set: 0.0364997088909
# 145 [D loss: 0.578001, acc.: 70.70%] [G loss: 0.807158]
# Pearson R on Train set: 0.0348398089409
# Pearson R on Val set: 0.0400680042803
# 146 [D loss: 0.563029, acc.: 78.32%] [G loss: 0.798259]
# Pearson R on Train set: 0.0376850180328
# Pearson R on Val set: 0.0377785377204
# 147 [D loss: 0.551049, acc.: 71.48%] [G loss: 0.822199]
# Pearson R on Train set: 0.040415275842
# Pearson R on Val set: 0.0418707430363
# 148 [D loss: 0.548832, acc.: 67.58%] [G loss: 0.793379]
# Pearson R on Train set: 0.0267130900174
# Pearson R on Val set: 0.0330982916057
# 149 [D loss: 0.553689, acc.: 54.10%] [G loss: 0.776113]
# Pearson R on Train set: 0.0314744599164
# Pearson R on Val set: 0.0471439957619
# 150 [D loss: 0.569130, acc.: 56.05%] [G loss: 0.796976]
# Pearson R on Train set: 0.033457711339
# Pearson R on Val set: 0.0478186234832
# 151 [D loss: 0.567321, acc.: 65.82%] [G loss: 0.792463]
# Pearson R on Train set: 0.0248014852405
# Pearson R on Val set: 0.0366220325232
# 152 [D loss: 0.570893, acc.: 71.88%] [G loss: 0.794327]
# Pearson R on Train set: 0.0175979491323
# Pearson R on Val set: 0.0303125847131
# 153 [D loss: 0.547557, acc.: 64.26%] [G loss: 0.785021]
# Pearson R on Train set: 0.0158671699464
# Pearson R on Val set: 0.0289595909417
# 154 [D loss: 0.540901, acc.: 61.72%] [G loss: 0.806519]
# Pearson R on Train set: 0.0167198181152
# Pearson R on Val set: 0.025263696909
# 155 [D loss: 0.552966, acc.: 74.61%] [G loss: 0.813655]
# Pearson R on Train set: 0.0203120484948
# Pearson R on Val set: 0.0296612605453
# 156 [D loss: 0.532446, acc.: 74.41%] [G loss: 0.820498]
# Pearson R on Train set: 0.0285373926163
# Pearson R on Val set: 0.0429892130196
# 157 [D loss: 0.539460, acc.: 75.78%] [G loss: 0.837953]
# Pearson R on Train set: 0.0338553823531
# Pearson R on Val set: 0.0433958880603
# 158 [D loss: 0.566485, acc.: 55.27%] [G loss: 0.767672]
# Pearson R on Train set: 0.0272576399148
# Pearson R on Val set: 0.0403630882502
# 159 [D loss: 0.580398, acc.: 52.34%] [G loss: 0.743119]
# Pearson R on Train set: 0.0285400506109
# Pearson R on Val set: 0.041065428406
# 160 [D loss: 0.554492, acc.: 71.09%] [G loss: 0.786294]
# Pearson R on Train set: 0.0343951061368
# Pearson R on Val set: 0.0429497472942
# 161 [D loss: 0.547630, acc.: 69.73%] [G loss: 0.790925]
# Pearson R on Train set: 0.0373498685658
# Pearson R on Val set: 0.0405180864036
# 162 [D loss: 0.566647, acc.: 67.77%] [G loss: 0.812197]
# Pearson R on Train set: 0.0382109805942
# Pearson R on Val set: 0.0391048379242
# 163 [D loss: 0.546912, acc.: 70.90%] [G loss: 0.824021]
# Pearson R on Train set: 0.0334042981267
# Pearson R on Val set: 0.0370368659496
# 164 [D loss: 0.542792, acc.: 66.21%] [G loss: 0.801659]
# Pearson R on Train set: 0.044058047235
# Pearson R on Val set: 0.0511723868549
# 165 [D loss: 0.566615, acc.: 64.45%] [G loss: 0.800840]
# Pearson R on Train set: 0.0380392670631
# Pearson R on Val set: 0.0427936054766
# 166 [D loss: 0.540917, acc.: 66.41%] [G loss: 0.791939]
# Pearson R on Train set: 0.0388731025159
# Pearson R on Val set: 0.0456557609141
# 167 [D loss: 0.545955, acc.: 68.55%] [G loss: 0.808571]
# Pearson R on Train set: 0.0380320623517
# Pearson R on Val set: 0.0497937127948
# 168 [D loss: 0.587005, acc.: 57.81%] [G loss: 0.772132]
# Pearson R on Train set: 0.0420519337058
# Pearson R on Val set: 0.055364202708
# 169 [D loss: 0.546190, acc.: 66.60%] [G loss: 0.817557]
# Pearson R on Train set: 0.0461223050952
# Pearson R on Val set: 0.066112279892
# 170 [D loss: 0.554797, acc.: 73.24%] [G loss: 0.828025]
# Pearson R on Train set: 0.0252441633493
# Pearson R on Val set: 0.0368379540741
# 171 [D loss: 0.540064, acc.: 76.56%] [G loss: 0.843249]
# Pearson R on Train set: 0.0231100711972
# Pearson R on Val set: 0.0333129763603
# 172 [D loss: 0.530264, acc.: 77.54%] [G loss: 0.834047]
# Pearson R on Train set: 0.0177979655564
# Pearson R on Val set: 0.0287257470191
# 173 [D loss: 0.535509, acc.: 81.64%] [G loss: 0.831381]
# Pearson R on Train set: 0.0129898777232
# Pearson R on Val set: 0.0209709312767
# 174 [D loss: 0.554716, acc.: 78.12%] [G loss: 0.819214]
# Pearson R on Train set: 0.0173699501902
# Pearson R on Val set: 0.0252166539431
# 175 [D loss: 0.547278, acc.: 77.73%] [G loss: 0.798675]
# Pearson R on Train set: 0.017462303862
# Pearson R on Val set: 0.0293597467244
# 176 [D loss: 0.566870, acc.: 67.58%] [G loss: 0.783550]
# Pearson R on Train set: 0.0215510986745
# Pearson R on Val set: 0.0336643084884
# 177 [D loss: 0.551971, acc.: 79.49%] [G loss: 0.832589]
# Pearson R on Train set: 0.0264560319483
# Pearson R on Val set: 0.0368463434279
# 178 [D loss: 0.525028, acc.: 82.23%] [G loss: 0.831315]
# Pearson R on Train set: 0.023959569633
# Pearson R on Val set: 0.0350720770657
# 179 [D loss: 0.533158, acc.: 79.30%] [G loss: 0.823846]
# Pearson R on Train set: 0.0257167220116
# Pearson R on Val set: 0.0403709486127
# 180 [D loss: 0.522801, acc.: 82.03%] [G loss: 0.870897]
# Pearson R on Train set: 0.0272974036634
# Pearson R on Val set: 0.0456184744835
# 181 [D loss: 0.533133, acc.: 74.80%] [G loss: 0.855387]
# Pearson R on Train set: 0.0317024290562
# Pearson R on Val set: 0.0559982843697
# 182 [D loss: 0.517937, acc.: 80.27%] [G loss: 0.888135]
# Pearson R on Train set: 0.00806625094265
# Pearson R on Val set: 0.0227255728096
# 183 [D loss: 0.538260, acc.: 77.34%] [G loss: 0.854910]
# Pearson R on Train set: 0.00631016399711
# Pearson R on Val set: 0.0230715703219
# 184 [D loss: 0.574871, acc.: 63.48%] [G loss: 0.784151]
# Pearson R on Train set: 0.00481831887737
# Pearson R on Val set: 0.0288965050131
# 185 [D loss: 0.558362, acc.: 68.75%] [G loss: 0.807026]
# Pearson R on Train set: 0.00789887458086
# Pearson R on Val set: 0.026873132214
# 186 [D loss: 0.556011, acc.: 63.87%] [G loss: 0.789637]
# Pearson R on Train set: 0.0118020055816
# Pearson R on Val set: 0.0250337906182
# 187 [D loss: 0.538979, acc.: 67.38%] [G loss: 0.784321]
# Pearson R on Train set: 0.0126113118604
# Pearson R on Val set: 0.0226493310183
# 188 [D loss: 0.549895, acc.: 76.17%] [G loss: 0.799873]
# Pearson R on Train set: 0.0174063313752
# Pearson R on Val set: 0.0255431551486
# 189 [D loss: 0.558197, acc.: 70.90%] [G loss: 0.823713]
# Pearson R on Train set: 0.0178620610386
# Pearson R on Val set: 0.0294421575963
# 190 [D loss: 0.559822, acc.: 72.66%] [G loss: 0.830150]
# Pearson R on Train set: 0.0301522184163
# Pearson R on Val set: 0.0470703020692
# 191 [D loss: 0.559222, acc.: 74.80%] [G loss: 0.836084]
# Pearson R on Train set: 0.0501190423965
# Pearson R on Val set: 0.0709519982338
# 192 [D loss: 0.551128, acc.: 76.56%] [G loss: 0.856394]
# Pearson R on Train set: 0.0647105947137
# Pearson R on Val set: 0.0867541134357
# 193 [D loss: 0.577440, acc.: 71.48%] [G loss: 0.822741]
# Pearson R on Train set: 0.0284065492451
# Pearson R on Val set: 0.0435965508223
# 194 [D loss: 0.534719, acc.: 68.75%] [G loss: 0.813495]
# Pearson R on Train set: 0.0174865592271
# Pearson R on Val set: 0.0306619592011
# 195 [D loss: 0.546713, acc.: 72.66%] [G loss: 0.792126]
# Pearson R on Train set: 0.0186422877014
# Pearson R on Val set: 0.0265041925013
# 196 [D loss: 0.545422, acc.: 77.34%] [G loss: 0.802857]
# Pearson R on Train set: 0.0191383175552
# Pearson R on Val set: 0.0306432712823
# 197 [D loss: 0.554262, acc.: 68.95%] [G loss: 0.812810]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-73d1029e809e> in <module>()
#       5
#       6 gan = GAN()
# ----> 7 gan.train(num_epochs, batch_size, X_train, y_train)
#
# <ipython-input-53-de4e2c7307d8> in train(self, epochs, batch_size, X_train, y_train)
#     128
#     129                 # Train the generator
# --> 130                 g_loss = self.combined.train_on_batch(gen_noise, valid_y)
#     131
#     132                 d_losses.append(d_loss[0])
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/keras/engine/training.pyc in train_on_batch(self, x, y, sample_weight, class_weight)
#    1847             ins = x + y + sample_weights
#    1848         self._make_train_function()
# -> 1849         outputs = self.train_function(ins)
#    1850         if len(outputs) == 1:
#    1851             return outputs[0]
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
