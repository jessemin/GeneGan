# %% [markdown]
# # Baseline with mse loss with deep
# #### Convert histone mark signals and use deep CNN for training.

# %% [markdown]
# #### NOTE: Need to activate genomelake environment before this code. Simply type 'genomelake' in terminal.

# %%
# %env CUDA_VISIBLE_DEVICES=4,7
import os, sys
sys.path.append("..")
import random
# custom file path package
from data import Data_Directories
# custom utility package
from utils.compute_util import *
# package for genomic data
from pybedtools import Interval, BedTool
from genomelake.extractors import ArrayExtractor, BigwigExtractor
# package for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats.stats import pearsonr,spearmanr
import tensorflow as tf
# Out:
# env: CUDA_VISIBLE_DEVICES=4,7
# Using TensorFlow backend.

# %%
window_size = 2001
process_all = False
sample_num = 1000

# %%
# retrieve data
data = Data_Directories()
print data.intervals.keys()
print data.input_atac['day0'].keys()
print data.output_histone['day0'].keys()
# Out:
# ['day6', 'day3', 'day0']
# ['100', '140']
# ['H3K27me3', 'H3K4me1', 'H3K27ac']

# %%
# get intervals for day0 data
day0_intervals = list(BedTool(data.intervals['day0']))
print '# of Intervals Extracted for day0: {}'.format(len(day0_intervals))

# get intervals for day3 data
day3_intervals = list(BedTool(data.intervals['day3']))
print '# of Intervals Extracted for day3: {}'.format(len(day3_intervals))
# Out:
# # of Intervals Extracted for day0: 267226
# # of Intervals Extracted for day3: 233846

# %%
# create an ArrayExtractor for ATAC-seq for day0 with 140 base pairs
bw_140bp_day0 = ArrayExtractor(data.input_atac['day0']['140'])
print 'Finished extracting bigwig for day0, 140bp'

# create an ArrayExtractor for ATAC-seq for day3 with 140 base pairs
bw_140bp_day3 = ArrayExtractor(data.input_atac['day3']['140'])
print 'Finished extracting bigwig for day3, 140bp'
# Out:
# Finished extracting bigwig for day0, 140bp
# Finished extracting bigwig for day3, 140bp

# %%
# create a BigWigExtractor for histone makr 'H3K27ac' for day0
bw_histone_mark_day0 = BigwigExtractor(data.output_histone['day0']['H3K27ac'])
print 'Finished extracting bigwig for day0, 140bp'

# create a BigWigExtractor for histone makr 'H3K27ac' for day3
bw_histone_mark_day3 = BigwigExtractor(data.output_histone['day3']['H3K27ac'])
print 'Finished extracting bigwig for day3, 140bp'
# Out:
# Finished extracting bigwig for day0, 140bp
# Finished extracting bigwig for day3, 140bp

# %%
# normalize day0 intervals
normalized_day0_intervals = [normalize_interval(interval, window_size) for interval in day0_intervals if normalize_interval(interval, window_size)]
print 'Finished normalizing day0 intervals!'

# normalize day3 intervals
normalized_day3_intervals = [normalize_interval(interval, window_size) for interval in day3_intervals if normalize_interval(interval, window_size)]
print 'Finished normalizing day3 intervals!'
# Out:
# Finished normalizing day0 intervals!
# Finished normalizing day3 intervals!

# %%
assert (len(day0_intervals)==len(normalized_day0_intervals))
assert (len(day3_intervals)==len(normalized_day3_intervals))
print "Examples of original intervals"
print [(int(_interval.start)+int(_interval[-1]), [int(_interval.start), int(_interval.end)])
       for _interval in day0_intervals[:3]]
print "Examples of normalized intervals with window size of {}".format(window_size)
print [([int(_interval.start), int(_interval.end)])
       for _interval in  normalized_day0_intervals[:3]]
# Out:
# Examples of original intervals
# [(123412027, [123411855, 123412989]), (123411941, [123411855, 123412989]), (131908564, [131908487, 131910071])]
# Examples of normalized intervals with window size of 2001
# [[123411027, 123413028], [123410941, 123412942], [131907564, 131909565]]

# %%
atac_seq_day0 = bw_140bp_day0(normalized_day0_intervals)
atac_seq_day3 = bw_140bp_day3(normalized_day3_intervals)
print atac_seq_day0.shape, atac_seq_day3.shape
# Out:
# (267226, 2001, 5) (233846, 2001, 5)

# %%
#TODO: put this into utils if possible
def prune_invalid_intervals(intervals, bigwig_file):
    for _interval in intervals[:]:
        try:
            bigwig_file([_interval])
        except:
            intervals.remove(_interval)
            pass
        
print "Before pruning day0: {}".format(len(normalized_day0_intervals))
prune_invalid_intervals(normalized_day0_intervals, bw_140bp_day0)
print "After pruning day0: {}".format(len(normalized_day0_intervals))

print "Before pruning day3: {}".format(len(normalized_day3_intervals))
prune_invalid_intervals(normalized_day3_intervals, bw_140bp_day3)
print "After pruning day3: {}".format(len(normalized_day3_intervals))
# Out:
# Before pruning day0: 267226
# After pruning day0: 267226
# Before pruning day3: 233846
# After pruning day3: 233846

# %%
print "Dimension of ATAC-seq signal: {}".format(bw_140bp_day0(normalized_day0_intervals[:1]).shape)
# Out:
# Dimension of ATAC-seq signal: (1, 2001, 5)

# %%
print "Dimension of histone mark signal: {}".format(bw_histone_mark_day0(normalized_day0_intervals[:1]).shape)
# Out:
# Dimension of histone mark signal: (1, 2001)

# %%
# replace nan values with zeros and convert it to p-values
histone_mark_day0 = np.nan_to_num(bw_histone_mark_day0(normalized_day0_intervals))
print histone_mark_day0.shape

histone_mark_day3 = np.nan_to_num(bw_histone_mark_day3(normalized_day3_intervals))
print histone_mark_day3.shape
# Out:
# (267226, 2001)
# (233846, 2001)

# %%
histone_mark_day0 = np.expand_dims(histone_mark_day0, axis=2)
histone_mark_day3 = np.expand_dims(histone_mark_day3, axis=2)
print histone_mark_day0.shape, histone_mark_day3.shape
# Out:
# (267226, 2001, 1) (233846, 2001, 1)

# %%
print "Example histone mark signal"
print "\tRaw value: {}".format(bw_histone_mark_day0(normalized_day0_intervals[:1])[0][:5].reshape(-1))
# Out:
# Example histone mark signal
# 	Raw value: [ 0.01014  0.01014  0.01014  0.02435  0.02435]

# %%
from keras.layers import Input, Dense, Conv1D, Dropout
from keras.models import Model
from keras import optimizers
from keras import metrics
from keras import losses
from keras import backend as K
from keras.callbacks import Callback, TensorBoard, ReduceLROnPlateau, ModelCheckpoint

# %%
dropout_rate = 0.5
# parameters for first conv layer
hidden_filters_1 = 16
hidden_kernel_size_1 = 64
# parameters for second conv layer
hidden_filters_2 = 16
hidden_kernel_size_2 = 32
# parameters for the output layer
output_filters = 1
output_kernel_size = 16
# parameters for training
batch_size = 64
num_epochs = 300
evaluation_freq = 10

# %%
'''
Baseline CNN (based on KERAS functional API)
'''
# 
inputs = Input(shape=(window_size, 5, ))
x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1)(inputs)
x = Dropout(dropout_rate)(x)

x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_1,
    kernel_size=hidden_kernel_size_1,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)

x = Conv1D(
    filters=hidden_filters_2,
    kernel_size=hidden_kernel_size_2,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_2,
    kernel_size=hidden_kernel_size_2,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_2,
    kernel_size=hidden_kernel_size_2,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_2,
    kernel_size=hidden_kernel_size_2,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_2,
    kernel_size=hidden_kernel_size_2,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_2,
    kernel_size=hidden_kernel_size_2,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_2,
    kernel_size=hidden_kernel_size_2,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_2,
    kernel_size=hidden_kernel_size_2,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_2,
    kernel_size=hidden_kernel_size_2,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_2,
    kernel_size=hidden_kernel_size_2,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_2,
    kernel_size=hidden_kernel_size_2,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)
x = Conv1D(
    filters=hidden_filters_2,
    kernel_size=hidden_kernel_size_2,
    padding='same',
    activation='relu',
    strides=1)(x)
x = Dropout(dropout_rate)(x)

outputs = Conv1D(
    filters=output_filters,
    kernel_size=output_kernel_size,
    padding='same',
    activation='linear',
    strides=1
    )(x)

model = Model(inputs=inputs, outputs=outputs)

# %%
# Print out model summary
print model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 2001, 5)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2001, 16)          5136
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 2001, 16)          16400
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 2001, 16)          16400
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 2001, 16)          16400
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 2001, 16)          16400
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 2001, 16)          16400
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 2001, 16)          16400
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 2001, 16)          16400
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 2001, 16)          16400
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 2001, 16)          16400
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 2001, 16)          16400
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 2001, 16)          16400
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 2001, 16)          16400
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 2001, 16)          8208
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 2001, 16)          8208
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 2001, 16)          8208
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, 2001, 16)          8208
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_18 (Conv1D)           (None, 2001, 16)          8208
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 2001, 16)          8208
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 2001, 16)          8208
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_21 (Conv1D)           (None, 2001, 16)          8208
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_22 (Conv1D)           (None, 2001, 16)          8208
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_23 (Conv1D)           (None, 2001, 16)          8208
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_24 (Conv1D)           (None, 2001, 16)          8208
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_25 (Conv1D)           (None, 2001, 16)          8208
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 2001, 16)          0
# _________________________________________________________________
# conv1d_26 (Conv1D)           (None, 2001, 1)           257
# =================================================================
# Total params: 300,689
# Trainable params: 300,689
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def pearson(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = K.mean(x)
    my = K.mean(y)
    xm, ym = x-mx, y-my
    r_num = K.sum(np.multiply(xm,ym))
    r_den = K.sqrt(np.multiply(K.sum(K.square(xm)), K.sum(K.square(ym))))
    r = r_num / r_den
    r = K.maximum(K.minimum(r, 1.0), -1.0)
    return K.square(r)

# %%
# Helper functions for writing the scores into bigwig file
from itertools import izip
from itertools import groupby
import subprocess

def interval_key(interval):
    return (interval.chrom, interval.start, interval.stop)

def merged_scores(scores, intervals, merge_type):
    # A generator that returns merged intervals/scores
    # Scores should have shape: #examples x #categories x #interval_size
    # Second dimension can be omitted for a 1D signal
    signal_dims = scores.ndim - 1
    assert signal_dims in {1, 2}

    # Only support max for now
    assert merge_type == 'max'
    score_first_dim = 1 if signal_dims == 1 else scores.shape[1]

    dtype = scores.dtype

    sort_idx, sorted_intervals = \
        zip(*sorted(enumerate(intervals),
                    key=lambda item: interval_key(item[1])))
    sorted_intervals = BedTool(sorted_intervals)

    # Require at least 1bp overlap
    # Explicitly convert to list otherwise it will keep opening a file when
    # retrieving an index resulting in an error (too many open files)
    interval_clust = list(sorted_intervals.cluster(d=-1))
    for _, group in groupby(izip(sort_idx, interval_clust),
                            key=lambda item: item[1].fields[-1]):
        idx_interval_pairs = list(group)
        group_idx, group_intervals = zip(*idx_interval_pairs)

        if len(idx_interval_pairs) == 1:
            yield group_intervals[0], scores[group_idx[0], ...]
        else:
            group_chrom = group_intervals[0].chrom
            group_start = min(interval.start for interval in group_intervals)
            group_stop = max(interval.stop for interval in group_intervals)

            # This part needs to change to support more merge_types (e.g. mean)
            group_score = np.full((score_first_dim, group_stop - group_start),
                                  -np.inf, dtype)
            for idx, interval in idx_interval_pairs:
                slice_start = interval.start - group_start
                slice_stop = slice_start + (interval.stop - interval.start)
                group_score[..., slice_start:slice_stop] = \
                    np.maximum(group_score[..., slice_start:slice_stop],
                               scores[idx, ...])
            if signal_dims == 1:
                group_score = group_score.squeeze(axis=0)
            yield Interval(group_chrom, group_start, group_stop), group_score
            
def interval_score_pairs(intervals, scores, merge_type):
    return (izip(intervals, scores) if merge_type is None
            else merged_scores(scores, intervals, merge_type))

def _write_1D_deeplift_track(scores, intervals, file_prefix, merge_type='max',
                             CHROM_SIZES='/mnt/data/annotations/by_release/hg19.GRCh37/hg19.chrom.sizes'):
    assert scores.ndim == 2

    bedgraph = file_prefix + '.bedGraph'
    bigwig = file_prefix + '.bw'

    print 'Writing 1D track of shape: {}'.format(scores.shape)
    print 'Writing to file: {}'.format(bigwig)

    with open(bedgraph, 'w') as fp:
        for interval, score in interval_score_pairs(intervals, scores,
                                                    merge_type):
            chrom = interval.chrom
            start = interval.start
            for score_idx, val in enumerate(score):
                fp.write('%s\t%d\t%d\t%g\n' % (chrom,
                                               start + score_idx,
                                               start + score_idx + 1,
                                               val))
    print 'Wrote bedgraph.'

    try:
        output = subprocess.check_output(
            ['wigToBigWig', bedgraph, CHROM_SIZES, bigwig],
            stderr=subprocess.STDOUT)
        print 'wigToBigWig output: {}'.format(output)
    except subprocess.CalledProcessError as e:
        print 'wigToBigWig terminated with exit code {}'.format(
            e.returncode)
        print 'output was:\n' + e.output

    print 'Wrote bigwig.'

# %%
model_dir = os.path.join("models", "mse_deep")
log_dir = os.path.join("logs", "mse_deep")
srv_dir = os.path.join("/srv", "www", "kundaje", "jesikmin", "mse_deep")
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
if not os.path.exists(log_dir):
    os.makedirs(log_dir)
if not os.path.exists(srv_dir):
    os.makedirs(srv_dir)

# %%
# setting an adam optimizer with 1.0 clip norm
adam = optimizers.Adam(clipnorm=1.)

print "Compiling a model with adam optimizer"
model.compile(loss=losses.mean_squared_error,
              optimizer=adam,
              metrics=[pearson, metrics.mse, metrics.mae])
# Out:
# Compiling a model with adam optimizer

# %%
# CallBack: tensorboard with grad histogram
tensorboard = TensorBoard(log_dir=log_dir,
                          histogram_freq=1,
                          batch_size=batch_size,
                          write_grads=True)

# %%
# CallBack: reduce learning rate when validation loss meets plateau
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=10,
                              min_lr=1e-5)

# %%
# CallBack: evaluate model for every evaulation epoch
class EvaluateModel(Callback):
    def __init__(self, X_test, y_test):
        self.X_test, self.y_test = X_test, y_test
        self.epochs = 0

    def on_epoch_end(self, batch, logs={}):
        self.epochs += 1
        # evaluate the model
        if self.epochs % evaluation_freq == 0:
            scores = model.evaluate(X_test, y_test)
            print zip(model.metrics_names, scores)
            test_prediction = model.predict(X_test)
            test_spearman_sum = 0.0
            for idx, _pred in enumerate(test_prediction):
                rho, _ = spearmanr(histone_mark_day0[10000+idx], _pred)
                test_spearman_sum += rho
            print "Test spearman: {}".format(test_spearman_sum * 1.0 / 1000)

# %%
# CallBack: store bigwig file for the best model
class SaveBigwig(Callback):
    def __init__(self, X_train, y_train, X_val, y_val, X_test, y_test):
        self.best_val_loss = float('Inf')
        self.best_epoch = -1
        self.X_train, self.y_train = X_train, y_train
        self.X_val, self.y_val = X_val, y_val
        self.X_test, self.y_test = X_test, y_test
        self.epochs = 0
    
    def on_epoch_end(self, batch, logs={}):
        self.epochs += 1
        cur_val_loss = logs['val_loss']
        if cur_val_loss < self.best_val_loss:
            self.best_val_loss = cur_val_loss
            self.best_epoch = self.epochs
            prediction = model.predict(X_train).reshape(7500, 2001)
            _write_1D_deeplift_track(prediction,
                                     normalized_day0_intervals[:7500], os.path.join(srv_dir, 'train'))
            prediction = model.predict(X_val).reshape(2500, 2001)
            _write_1D_deeplift_track(prediction,
                                     normalized_day0_intervals[7500:10000], os.path.join(srv_dir, 'val'))
            prediction = model.predict(X_test).reshape(1000, 2001)
            _write_1D_deeplift_track(prediction,
                                     normalized_day0_intervals[10000:11000], os.path.join(srv_dir, 'test'))
            f = open(os.path.join(srv_dir, 'meta.txt'), 'wb')
            f.write(str(self.epochs) + "  " + str(logs))
            f.close()

# %%
# CallBack: Save model checkpoint based on validation loss
checkpointer = ModelCheckpoint(os.path.join(model_dir, "best_model.h5"),
                               monitor='val_loss',
                               verbose=1,
                               save_best_only=True,
                               mode='min')

# %%
print "Fitting the model..."
X_train, y_train = atac_seq_day0[:7500], histone_mark_day0[:7500]
X_val, y_val = atac_seq_day0[7500:10000], histone_mark_day0[7500:10000]
X_test, y_test = atac_seq_day0[10000:11000], histone_mark_day0[10000:11000]

model.fit(atac_seq_day0[:10000],
          histone_mark_day0[:10000],
          batch_size=batch_size,
          epochs=num_epochs,
          validation_split=0.25,   
          #shuffle=True,
          callbacks=[tensorboard,
                     reduce_lr,
                     EvaluateModel(X_test, y_test),
                     checkpointer,
                     SaveBigwig(X_train, y_train, X_val, y_val, X_test, y_test)])
# Out:
# Fitting the model...
# Train on 7500 samples, validate on 2500 samples
# Epoch 1/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 515.3339 - pearson: 0.1393 - mean_squared_error: 515.3339 - mean_absolute_error: 10.4700
# Epoch 00001: val_loss improved from inf to 201.24927, saving model to models/mse_deep/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 260s 35ms/step - loss: 514.6358 - pearson: 0.1395 - mean_squared_error: 514.6358 - mean_absolute_error: 10.4618 - val_loss: 201.2493 - val_pearson: 4.3545e-04 - val_mean_squared_error: 201.2493 - val_mean_absolute_error: 4.7491
# Epoch 2/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 560.8959 - pearson: 0.1522 - mean_squared_error: 560.8959 - mean_absolute_error: 10.5308
# Epoch 00002: val_loss improved from 201.24927 to 200.65607, saving model to models/mse_deep/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 230s 31ms/step - loss: 560.2398 - pearson: 0.1523 - mean_squared_error: 560.2398 - mean_absolute_error: 10.5279 - val_loss: 200.6561 - val_pearson: 2.3730e-04 - val_mean_squared_error: 200.6561 - val_mean_absolute_error: 4.9761
# Epoch 3/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 419.3630 - pearson: 0.1651 - mean_squared_error: 419.3630 - mean_absolute_error: 9.2682
# Epoch 00003: val_loss did not improve
# 7500/7500 [==============================] - 87s 12ms/step - loss: 418.9293 - pearson: 0.1656 - mean_squared_error: 418.9293 - mean_absolute_error: 9.2619 - val_loss: 201.6911 - val_pearson: 1.8343e-04 - val_mean_squared_error: 201.6911 - val_mean_absolute_error: 4.6372
# Epoch 4/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 428.3143 - pearson: 0.1658 - mean_squared_error: 428.3143 - mean_absolute_error: 9.2454
# Epoch 00004: val_loss improved from 200.65607 to 200.49538, saving model to models/mse_deep/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 231s 31ms/step - loss: 429.6619 - pearson: 0.1656 - mean_squared_error: 429.6619 - mean_absolute_error: 9.2595 - val_loss: 200.4954 - val_pearson: 1.9585e-04 - val_mean_squared_error: 200.4954 - val_mean_absolute_error: 5.0593
# Epoch 5/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 408.1236 - pearson: 0.1713 - mean_squared_error: 408.1236 - mean_absolute_error: 9.0957
# Epoch 00005: val_loss improved from 200.49538 to 200.27592, saving model to models/mse_deep/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 232s 31ms/step - loss: 411.1868 - pearson: 0.1714 - mean_squared_error: 411.1868 - mean_absolute_error: 9.1221 - val_loss: 200.2759 - val_pearson: 1.9324e-04 - val_mean_squared_error: 200.2759 - val_mean_absolute_error: 5.2020
# Epoch 6/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 406.5487 - pearson: 0.1655 - mean_squared_error: 406.5487 - mean_absolute_error: 8.9490
# Epoch 00006: val_loss did not improve
# 7500/7500 [==============================] - 86s 12ms/step - loss: 406.3200 - pearson: 0.1654 - mean_squared_error: 406.3200 - mean_absolute_error: 8.9466 - val_loss: 201.0310 - val_pearson: 1.8306e-04 - val_mean_squared_error: 201.0310 - val_mean_absolute_error: 4.8327
# Epoch 7/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 396.7671 - pearson: 0.1718 - mean_squared_error: 396.7671 - mean_absolute_error: 8.8646
# Epoch 00007: val_loss did not improve
# 7500/7500 [==============================] - 87s 12ms/step - loss: 396.3323 - pearson: 0.1717 - mean_squared_error: 396.3323 - mean_absolute_error: 8.8618 - val_loss: 200.5593 - val_pearson: 1.7470e-04 - val_mean_squared_error: 200.5593 - val_mean_absolute_error: 5.0271
# Epoch 8/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 398.5749 - pearson: 0.1664 - mean_squared_error: 398.5749 - mean_absolute_error: 8.9281
# Epoch 00008: val_loss improved from 200.27592 to 187.17329, saving model to models/mse_deep/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 239s 32ms/step - loss: 398.8159 - pearson: 0.1667 - mean_squared_error: 398.8158 - mean_absolute_error: 8.9326 - val_loss: 187.1733 - val_pearson: 0.0942 - val_mean_squared_error: 187.1733 - val_mean_absolute_error: 5.6097
# Epoch 9/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 393.3937 - pearson: 0.1706 - mean_squared_error: 393.3937 - mean_absolute_error: 8.8250
# Epoch 00009: val_loss did not improve
# 7500/7500 [==============================] - 87s 12ms/step - loss: 393.0379 - pearson: 0.1707 - mean_squared_error: 393.0379 - mean_absolute_error: 8.8222 - val_loss: 191.1670 - val_pearson: 0.0960 - val_mean_squared_error: 191.1670 - val_mean_absolute_error: 4.9481
# Epoch 10/300
# 1000/1000 [==============================] - 1s 977us/steps: 402.7610 - pearson: 0.1695 - mean_squared_error: 402.76
# [('loss', 259.44991769409182), ('pearson', 0.13490986108686776), ('mean_squared_error', 259.44991574096679), ('mean_absolute_error', 5.501958148956299)]
# Test spearman: 0.101152104395
#
# Epoch 00010: val_loss did not improve
# 7500/7500 [==============================] - 90s 12ms/step - loss: 402.3142 - pearson: 0.1697 - mean_squared_error: 402.3142 - mean_absolute_error: 8.9117 - val_loss: 197.8194 - val_pearson: 0.0712 - val_mean_squared_error: 197.8194 - val_mean_absolute_error: 4.6775
# Epoch 11/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 390.1223 - pearson: 0.1776 - mean_squared_error: 390.1223 - mean_absolute_error: 8.6459
# Epoch 00011: val_loss did not improve
# 7500/7500 [==============================] - 88s 12ms/step - loss: 390.3006 - pearson: 0.1784 - mean_squared_error: 390.3006 - mean_absolute_error: 8.6469 - val_loss: 200.9914 - val_pearson: 0.0066 - val_mean_squared_error: 200.9914 - val_mean_absolute_error: 4.7832
# Epoch 12/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 427.3562 - pearson: 0.1647 - mean_squared_error: 427.3562 - mean_absolute_error: 9.3613
# Epoch 00012: val_loss improved from 187.17329 to 181.26536, saving model to models/mse_deep/best_model.h5
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (1000, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/mse_deep/test.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 7500/7500 [==============================] - 236s 31ms/step - loss: 426.9677 - pearson: 0.1646 - mean_squared_error: 426.9677 - mean_absolute_error: 9.3598 - val_loss: 181.2654 - val_pearson: 0.1005 - val_mean_squared_error: 181.2654 - val_mean_absolute_error: 6.0028
# Epoch 13/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 391.5922 - pearson: 0.1716 - mean_squared_error: 391.5922 - mean_absolute_error: 8.9304
# Epoch 00013: val_loss did not improve
# 7500/7500 [==============================] - 86s 12ms/step - loss: 391.4941 - pearson: 0.1717 - mean_squared_error: 391.4941 - mean_absolute_error: 8.9316 - val_loss: 199.8680 - val_pearson: 0.0306 - val_mean_squared_error: 199.8680 - val_mean_absolute_error: 4.8904
# Epoch 14/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 396.1211 - pearson: 0.1765 - mean_squared_error: 396.1211 - mean_absolute_error: 8.9891
# Epoch 00014: val_loss did not improve
# 7500/7500 [==============================] - 88s 12ms/step - loss: 395.7630 - pearson: 0.1769 - mean_squared_error: 395.7630 - mean_absolute_error: 8.9853 - val_loss: 192.7897 - val_pearson: 0.0770 - val_mean_squared_error: 192.7897 - val_mean_absolute_error: 4.9812
# Epoch 15/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 392.8906 - pearson: 0.1653 - mean_squared_error: 392.8906 - mean_absolute_error: 8.8803
# Epoch 00015: val_loss did not improve
# 7500/7500 [==============================] - 88s 12ms/step - loss: 392.3728 - pearson: 0.1657 - mean_squared_error: 392.3728 - mean_absolute_error: 8.8743 - val_loss: 192.7784 - val_pearson: 0.0771 - val_mean_squared_error: 192.7784 - val_mean_absolute_error: 4.9425
# Epoch 16/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 399.5901 - pearson: 0.1621 - mean_squared_error: 399.5901 - mean_absolute_error: 8.8161
# Epoch 00016: val_loss did not improve
# 7500/7500 [==============================] - 88s 12ms/step - loss: 399.0790 - pearson: 0.1621 - mean_squared_error: 399.0790 - mean_absolute_error: 8.8120 - val_loss: 182.9482 - val_pearson: 0.0978 - val_mean_squared_error: 182.9482 - val_mean_absolute_error: 5.7480
# Epoch 17/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 408.8667 - pearson: 0.1519 - mean_squared_error: 408.8667 - mean_absolute_error: 9.2321
# Epoch 00017: val_loss did not improve
# 7500/7500 [==============================] - 86s 12ms/step - loss: 408.4977 - pearson: 0.1517 - mean_squared_error: 408.4977 - mean_absolute_error: 9.2291 - val_loss: 187.6493 - val_pearson: 0.0870 - val_mean_squared_error: 187.6493 - val_mean_absolute_error: 6.0081
# Epoch 18/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 391.6594 - pearson: 0.1667 - mean_squared_error: 391.6594 - mean_absolute_error: 8.8064
# Epoch 00018: val_loss did not improve
# 7500/7500 [==============================] - 87s 12ms/step - loss: 391.3648 - pearson: 0.1669 - mean_squared_error: 391.3648 - mean_absolute_error: 8.8054 - val_loss: 181.5371 - val_pearson: 0.1015 - val_mean_squared_error: 181.5371 - val_mean_absolute_error: 5.4881
# Epoch 19/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 428.5912 - pearson: 0.1050 - mean_squared_error: 428.5912 - mean_absolute_error: 9.3179
# Epoch 00019: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 427.9968 - pearson: 0.1048 - mean_squared_error: 427.9968 - mean_absolute_error: 9.3141 - val_loss: 217.0943 - val_pearson: 1.8332e-04 - val_mean_squared_error: 217.0943 - val_mean_absolute_error: 8.7291
# Epoch 20/300
# 1000/1000 [==============================] - 1s 972us/steps: 457.1302 - pearson: 1.5034e-04 - mean_squared_error: 457.130
# [('loss', 263.01322845458986), ('pearson', 0.00018732771658687853), ('mean_squared_error', 263.01320452880861), ('mean_absolute_error', 8.0785165367126464)]
# Test spearman: 0.0335962212164
#
# Epoch 00020: val_loss did not improve
# 7500/7500 [==============================] - 88s 12ms/step - loss: 456.5321 - pearson: 1.5019e-04 - mean_squared_error: 456.5321 - mean_absolute_error: 10.2163 - val_loss: 207.4281 - val_pearson: 1.6468e-04 - val_mean_squared_error: 207.4281 - val_mean_absolute_error: 7.5862
# Epoch 21/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 456.9588 - pearson: 2.5178e-04 - mean_squared_error: 456.9588 - mean_absolute_error: 10.1511
# Epoch 00021: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 456.3651 - pearson: 2.5191e-04 - mean_squared_error: 456.3651 - mean_absolute_error: 10.1469 - val_loss: 210.7387 - val_pearson: 1.5443e-04 - val_mean_squared_error: 210.7387 - val_mean_absolute_error: 8.0306
# Epoch 22/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 456.1248 - pearson: 1.3010e-04 - mean_squared_error: 456.1248 - mean_absolute_error: 10.1298
# Epoch 00022: val_loss did not improve
# 7500/7500 [==============================] - 84s 11ms/step - loss: 455.7886 - pearson: 1.3863e-04 - mean_squared_error: 455.7886 - mean_absolute_error: 10.1289 - val_loss: 220.9622 - val_pearson: 1.5536e-04 - val_mean_squared_error: 220.9622 - val_mean_absolute_error: 9.0969
# Epoch 23/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 456.1095 - pearson: 1.4825e-04 - mean_squared_error: 456.1095 - mean_absolute_error: 10.1630
# Epoch 00023: val_loss did not improve
# 7500/7500 [==============================] - 87s 12ms/step - loss: 455.4625 - pearson: 1.4801e-04 - mean_squared_error: 455.4625 - mean_absolute_error: 10.1575 - val_loss: 210.2353 - val_pearson: 1.5745e-04 - val_mean_squared_error: 210.2353 - val_mean_absolute_error: 7.9687
# Epoch 24/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.1295 - pearson: 1.3917e-04 - mean_squared_error: 455.1295 - mean_absolute_error: 10.0718
# Epoch 00024: val_loss did not improve
# 7500/7500 [==============================] - 87s 12ms/step - loss: 454.9202 - pearson: 1.3913e-04 - mean_squared_error: 454.9202 - mean_absolute_error: 10.0715 - val_loss: 213.8592 - val_pearson: 1.5775e-04 - val_mean_squared_error: 213.8592 - val_mean_absolute_error: 8.3943
# Epoch 25/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 453.6497 - pearson: 1.3949e-04 - mean_squared_error: 453.6497 - mean_absolute_error: 10.0801
# Epoch 00025: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 455.0674 - pearson: 1.3934e-04 - mean_squared_error: 455.0674 - mean_absolute_error: 10.0907 - val_loss: 215.2773 - val_pearson: 1.5627e-04 - val_mean_squared_error: 215.2773 - val_mean_absolute_error: 8.5462
# Epoch 26/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.3582 - pearson: 1.2876e-04 - mean_squared_error: 455.3582 - mean_absolute_error: 10.1537
# Epoch 00026: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7817 - pearson: 1.3005e-04 - mean_squared_error: 454.7817 - mean_absolute_error: 10.1496 - val_loss: 214.3541 - val_pearson: 1.5566e-04 - val_mean_squared_error: 214.3541 - val_mean_absolute_error: 8.4481
# Epoch 27/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4272 - pearson: 1.6907e-04 - mean_squared_error: 455.4272 - mean_absolute_error: 10.1462
# Epoch 00027: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8234 - pearson: 1.7035e-04 - mean_squared_error: 454.8234 - mean_absolute_error: 10.1414 - val_loss: 213.8279 - val_pearson: 1.5535e-04 - val_mean_squared_error: 213.8279 - val_mean_absolute_error: 8.3909
# Epoch 28/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 453.3339 - pearson: 1.4822e-04 - mean_squared_error: 453.3339 - mean_absolute_error: 10.0512
# Epoch 00028: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 455.0197 - pearson: 1.4856e-04 - mean_squared_error: 455.0197 - mean_absolute_error: 10.0621 - val_loss: 210.4805 - val_pearson: 1.5630e-04 - val_mean_squared_error: 210.4805 - val_mean_absolute_error: 7.9997
# Epoch 29/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 452.5163 - pearson: 1.3245e-04 - mean_squared_error: 452.5163 - mean_absolute_error: 10.1665
# Epoch 00029: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.9137 - pearson: 1.3225e-04 - mean_squared_error: 454.9137 - mean_absolute_error: 10.1772 - val_loss: 208.7427 - val_pearson: 1.5579e-04 - val_mean_squared_error: 208.7427 - val_mean_absolute_error: 7.7734
# Epoch 30/300
# 1000/1000 [==============================] - 1s 988us/steps: 455.7015 - pearson: 1.3188e-04 - mean_squared_error: 455.70
# [('loss', 264.16329852294922), ('pearson', 0.0001742767806572374), ('mean_squared_error', 264.16330157470702), ('mean_absolute_error', 8.318691417694092)]
# Test spearman: 0.0263354863764
#
# Epoch 00030: val_loss did not improve
# 7500/7500 [==============================] - 88s 12ms/step - loss: 455.1478 - pearson: 1.3182e-04 - mean_squared_error: 455.1478 - mean_absolute_error: 9.9364 - val_loss: 209.3244 - val_pearson: 1.5568e-04 - val_mean_squared_error: 209.3244 - val_mean_absolute_error: 7.8514
# Epoch 31/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4540 - pearson: 1.4877e-04 - mean_squared_error: 455.4540 - mean_absolute_error: 10.1349
# Epoch 00031: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8919 - pearson: 1.5136e-04 - mean_squared_error: 454.8919 - mean_absolute_error: 10.1309 - val_loss: 214.2419 - val_pearson: 1.5527e-04 - val_mean_squared_error: 214.2419 - val_mean_absolute_error: 8.4361
# Epoch 32/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4479 - pearson: 1.3479e-04 - mean_squared_error: 455.4479 - mean_absolute_error: 10.1770
# Epoch 00032: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8205 - pearson: 1.3656e-04 - mean_squared_error: 454.8205 - mean_absolute_error: 10.1715 - val_loss: 213.0028 - val_pearson: 1.5640e-04 - val_mean_squared_error: 213.0028 - val_mean_absolute_error: 8.2990
# Epoch 33/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.3947 - pearson: 1.8539e-04 - mean_squared_error: 455.3947 - mean_absolute_error: 10.1952
# Epoch 00033: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 455.1292 - pearson: 1.8634e-04 - mean_squared_error: 455.1292 - mean_absolute_error: 10.1963 - val_loss: 214.1473 - val_pearson: 1.5623e-04 - val_mean_squared_error: 214.1474 - val_mean_absolute_error: 8.4258
# Epoch 34/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4476 - pearson: 1.6305e-04 - mean_squared_error: 455.4476 - mean_absolute_error: 10.2988
# Epoch 00034: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8569 - pearson: 1.6441e-04 - mean_squared_error: 454.8569 - mean_absolute_error: 10.2942 - val_loss: 213.3554 - val_pearson: 1.5620e-04 - val_mean_squared_error: 213.3554 - val_mean_absolute_error: 8.3386
# Epoch 35/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.3494 - pearson: 1.6076e-04 - mean_squared_error: 455.3494 - mean_absolute_error: 10.1998
# Epoch 00035: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7531 - pearson: 1.6266e-04 - mean_squared_error: 454.7531 - mean_absolute_error: 10.1950 - val_loss: 213.1680 - val_pearson: 1.5613e-04 - val_mean_squared_error: 213.1680 - val_mean_absolute_error: 8.3176
# Epoch 36/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 454.5112 - pearson: 1.4677e-04 - mean_squared_error: 454.5112 - mean_absolute_error: 10.1595
# Epoch 00036: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8380 - pearson: 1.4837e-04 - mean_squared_error: 454.8380 - mean_absolute_error: 10.1615 - val_loss: 213.3322 - val_pearson: 1.5608e-04 - val_mean_squared_error: 213.3322 - val_mean_absolute_error: 8.3360
# Epoch 37/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 453.7274 - pearson: 1.6535e-04 - mean_squared_error: 453.7274 - mean_absolute_error: 10.2258
# Epoch 00037: val_loss did not improve
# 7500/7500 [==============================] - 87s 12ms/step - loss: 454.8023 - pearson: 1.6512e-04 - mean_squared_error: 454.8023 - mean_absolute_error: 10.2356 - val_loss: 213.2993 - val_pearson: 1.5595e-04 - val_mean_squared_error: 213.2993 - val_mean_absolute_error: 8.3324
# Epoch 38/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4170 - pearson: 1.3966e-04 - mean_squared_error: 455.4170 - mean_absolute_error: 10.2101
# Epoch 00038: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8449 - pearson: 1.3950e-04 - mean_squared_error: 454.8449 - mean_absolute_error: 10.2054 - val_loss: 212.5459 - val_pearson: 1.5597e-04 - val_mean_squared_error: 212.5459 - val_mean_absolute_error: 8.2471
# Epoch 39/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.1324 - pearson: 1.7500e-04 - mean_squared_error: 455.1324 - mean_absolute_error: 10.1520
# Epoch 00039: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8119 - pearson: 1.7472e-04 - mean_squared_error: 454.8119 - mean_absolute_error: 10.1527 - val_loss: 212.2314 - val_pearson: 1.5596e-04 - val_mean_squared_error: 212.2314 - val_mean_absolute_error: 8.2108
# Epoch 40/300
# 1000/1000 [==============================] - 1s 976us/steps: 455.4298 - pearson: 1.1323e-04 - mean_squared_error: 455.429
# [('loss', 266.28797119140626), ('pearson', 0.00017528613613103516), ('mean_squared_error', 266.28798068237307), ('mean_absolute_error', 8.6794952621459966)]
# Test spearman: 0.026335972819
#
# Epoch 00040: val_loss did not improve
# 7500/7500 [==============================] - 88s 12ms/step - loss: 454.8678 - pearson: 1.1305e-04 - mean_squared_error: 454.8678 - mean_absolute_error: 10.1749 - val_loss: 212.5548 - val_pearson: 1.5593e-04 - val_mean_squared_error: 212.5548 - val_mean_absolute_error: 8.2481
# Epoch 41/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.3291 - pearson: 1.3789e-04 - mean_squared_error: 455.3291 - mean_absolute_error: 10.1200
# Epoch 00041: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8822 - pearson: 1.3798e-04 - mean_squared_error: 454.8822 - mean_absolute_error: 10.1185 - val_loss: 212.4743 - val_pearson: 1.5578e-04 - val_mean_squared_error: 212.4743 - val_mean_absolute_error: 8.2389
# Epoch 42/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 454.9322 - pearson: 1.3768e-04 - mean_squared_error: 454.9322 - mean_absolute_error: 10.1497
# Epoch 00042: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7786 - pearson: 1.3746e-04 - mean_squared_error: 454.7786 - mean_absolute_error: 10.1513 - val_loss: 212.1515 - val_pearson: 1.5576e-04 - val_mean_squared_error: 212.1515 - val_mean_absolute_error: 8.2015
# Epoch 43/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 451.6695 - pearson: 1.5848e-04 - mean_squared_error: 451.6695 - mean_absolute_error: 10.1929
# Epoch 00043: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7876 - pearson: 1.5835e-04 - mean_squared_error: 454.7876 - mean_absolute_error: 10.2078 - val_loss: 213.2051 - val_pearson: 1.5556e-04 - val_mean_squared_error: 213.2051 - val_mean_absolute_error: 8.3219
# Epoch 44/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.3009 - pearson: 1.4107e-04 - mean_squared_error: 455.3009 - mean_absolute_error: 10.2112
# Epoch 00044: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7734 - pearson: 1.4219e-04 - mean_squared_error: 454.7734 - mean_absolute_error: 10.2075 - val_loss: 213.0133 - val_pearson: 1.5556e-04 - val_mean_squared_error: 213.0133 - val_mean_absolute_error: 8.3003
# Epoch 45/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.2423 - pearson: 1.8921e-04 - mean_squared_error: 455.2423 - mean_absolute_error: 10.1981
# Epoch 00045: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7121 - pearson: 1.8922e-04 - mean_squared_error: 454.7121 - mean_absolute_error: 10.1947 - val_loss: 213.0344 - val_pearson: 1.5556e-04 - val_mean_squared_error: 213.0344 - val_mean_absolute_error: 8.3027
# Epoch 46/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.3826 - pearson: 1.5332e-04 - mean_squared_error: 455.3826 - mean_absolute_error: 10.1997
# Epoch 00046: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7810 - pearson: 1.5324e-04 - mean_squared_error: 454.7810 - mean_absolute_error: 10.1953 - val_loss: 212.7013 - val_pearson: 1.5559e-04 - val_mean_squared_error: 212.7013 - val_mean_absolute_error: 8.2649
# Epoch 47/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.1198 - pearson: 1.5189e-04 - mean_squared_error: 455.1198 - mean_absolute_error: 10.1755
# Epoch 00047: val_loss did not improve
# 7500/7500 [==============================] - 84s 11ms/step - loss: 454.7988 - pearson: 1.5375e-04 - mean_squared_error: 454.7988 - mean_absolute_error: 10.1739 - val_loss: 212.5518 - val_pearson: 1.5556e-04 - val_mean_squared_error: 212.5518 - val_mean_absolute_error: 8.2478
# Epoch 48/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.3014 - pearson: 1.2215e-04 - mean_squared_error: 455.3014 - mean_absolute_error: 10.1674
# Epoch 00048: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8111 - pearson: 1.2227e-04 - mean_squared_error: 454.8111 - mean_absolute_error: 10.1645 - val_loss: 212.5333 - val_pearson: 1.5557e-04 - val_mean_squared_error: 212.5333 - val_mean_absolute_error: 8.2457
# Epoch 49/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 454.8960 - pearson: 1.4055e-04 - mean_squared_error: 454.8961 - mean_absolute_error: 10.1665
# Epoch 00049: val_loss did not improve
# 7500/7500 [==============================] - 87s 12ms/step - loss: 454.8111 - pearson: 1.4095e-04 - mean_squared_error: 454.8111 - mean_absolute_error: 10.1694 - val_loss: 212.5637 - val_pearson: 1.5555e-04 - val_mean_squared_error: 212.5637 - val_mean_absolute_error: 8.2492
# Epoch 50/300
# 1000/1000 [==============================] - 1s 970us/steps: 455.3918 - pearson: 1.7349e-04 - mean_squared_error: 455.391
# [('loss', 266.18389660644533), ('pearson', 0.00017480027844430878), ('mean_squared_error', 266.18391226196292), ('mean_absolute_error', 8.6634930763244622)]
# Test spearman: 0.026335972819
#
# Epoch 00050: val_loss did not improve
# 7500/7500 [==============================] - 88s 12ms/step - loss: 454.7958 - pearson: 1.7432e-04 - mean_squared_error: 454.7958 - mean_absolute_error: 10.1593 - val_loss: 212.4020 - val_pearson: 1.5558e-04 - val_mean_squared_error: 212.4020 - val_mean_absolute_error: 8.2306
# Epoch 51/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.3889 - pearson: 1.6881e-04 - mean_squared_error: 455.3889 - mean_absolute_error: 10.1565
# Epoch 00051: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7729 - pearson: 1.6855e-04 - mean_squared_error: 454.7729 - mean_absolute_error: 10.1516 - val_loss: 212.5248 - val_pearson: 1.5554e-04 - val_mean_squared_error: 212.5248 - val_mean_absolute_error: 8.2447
# Epoch 52/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4359 - pearson: 1.3991e-04 - mean_squared_error: 455.4359 - mean_absolute_error: 10.1600
# Epoch 00052: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8148 - pearson: 1.4006e-04 - mean_squared_error: 454.8148 - mean_absolute_error: 10.1544 - val_loss: 212.3940 - val_pearson: 1.5552e-04 - val_mean_squared_error: 212.3940 - val_mean_absolute_error: 8.2296
# Epoch 53/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 454.1409 - pearson: 1.6869e-04 - mean_squared_error: 454.1409 - mean_absolute_error: 10.1362
# Epoch 00053: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7984 - pearson: 1.6910e-04 - mean_squared_error: 454.7985 - mean_absolute_error: 10.1406 - val_loss: 212.1975 - val_pearson: 1.5553e-04 - val_mean_squared_error: 212.1975 - val_mean_absolute_error: 8.2069
# Epoch 54/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 450.9161 - pearson: 1.5094e-04 - mean_squared_error: 450.9161 - mean_absolute_error: 10.1195
# Epoch 00054: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8178 - pearson: 1.5125e-04 - mean_squared_error: 454.8178 - mean_absolute_error: 10.1371 - val_loss: 212.2265 - val_pearson: 1.5554e-04 - val_mean_squared_error: 212.2265 - val_mean_absolute_error: 8.2102
# Epoch 55/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.3925 - pearson: 1.4496e-04 - mean_squared_error: 455.3925 - mean_absolute_error: 10.1571
# Epoch 00055: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7442 - pearson: 1.4480e-04 - mean_squared_error: 454.7442 - mean_absolute_error: 10.1513 - val_loss: 212.4078 - val_pearson: 1.5552e-04 - val_mean_squared_error: 212.4078 - val_mean_absolute_error: 8.2312
# Epoch 56/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 454.9585 - pearson: 1.2723e-04 - mean_squared_error: 454.9585 - mean_absolute_error: 10.1344
# Epoch 00056: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8102 - pearson: 1.2800e-04 - mean_squared_error: 454.8102 - mean_absolute_error: 10.1354 - val_loss: 212.0781 - val_pearson: 1.5555e-04 - val_mean_squared_error: 212.0781 - val_mean_absolute_error: 8.1929
# Epoch 57/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 454.2721 - pearson: 1.3155e-04 - mean_squared_error: 454.2722 - mean_absolute_error: 10.1206
# Epoch 00057: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7721 - pearson: 1.3143e-04 - mean_squared_error: 454.7721 - mean_absolute_error: 10.1283 - val_loss: 212.1932 - val_pearson: 1.5552e-04 - val_mean_squared_error: 212.1933 - val_mean_absolute_error: 8.2064
# Epoch 58/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 454.9810 - pearson: 1.7772e-04 - mean_squared_error: 454.9810 - mean_absolute_error: 10.1289
# Epoch 00058: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8088 - pearson: 1.7764e-04 - mean_squared_error: 454.8088 - mean_absolute_error: 10.1288 - val_loss: 212.1251 - val_pearson: 1.5553e-04 - val_mean_squared_error: 212.1251 - val_mean_absolute_error: 8.1984
# Epoch 59/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 454.9579 - pearson: 1.1903e-04 - mean_squared_error: 454.9579 - mean_absolute_error: 10.1319
# Epoch 00059: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8328 - pearson: 1.1941e-04 - mean_squared_error: 454.8328 - mean_absolute_error: 10.1326 - val_loss: 212.2651 - val_pearson: 1.5552e-04 - val_mean_squared_error: 212.2651 - val_mean_absolute_error: 8.2147
# Epoch 60/300
# 1000/1000 [==============================] - 1s 967us/steps: 453.6775 - pearson: 1.5656e-04 - mean_squared_error: 453.677
# [('loss', 266.20374835205081), ('pearson', 0.0001747034794097999), ('mean_squared_error', 266.203737701416), ('mean_absolute_error', 8.6665793151855475)]
# Test spearman: 0.026335972819
#
# Epoch 00060: val_loss did not improve
# 7500/7500 [==============================] - 88s 12ms/step - loss: 454.7933 - pearson: 1.5696e-04 - mean_squared_error: 454.7933 - mean_absolute_error: 10.1518 - val_loss: 212.4312 - val_pearson: 1.5550e-04 - val_mean_squared_error: 212.4312 - val_mean_absolute_error: 8.2339
# Epoch 61/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 453.5431 - pearson: 1.7016e-04 - mean_squared_error: 453.5431 - mean_absolute_error: 10.1313
# Epoch 00061: val_loss did not improve
# 7500/7500 [==============================] - 87s 12ms/step - loss: 454.8016 - pearson: 1.7034e-04 - mean_squared_error: 454.8015 - mean_absolute_error: 10.1364 - val_loss: 211.9615 - val_pearson: 1.5554e-04 - val_mean_squared_error: 211.9615 - val_mean_absolute_error: 8.1793
# Epoch 62/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4390 - pearson: 1.5220e-04 - mean_squared_error: 455.4390 - mean_absolute_error: 10.1177
# Epoch 00062: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8268 - pearson: 1.5232e-04 - mean_squared_error: 454.8268 - mean_absolute_error: 10.1122 - val_loss: 211.9793 - val_pearson: 1.5553e-04 - val_mean_squared_error: 211.9793 - val_mean_absolute_error: 8.1814
# Epoch 63/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4955 - pearson: 1.3628e-04 - mean_squared_error: 455.4956 - mean_absolute_error: 10.1325
# Epoch 00063: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8315 - pearson: 1.3779e-04 - mean_squared_error: 454.8315 - mean_absolute_error: 10.1259 - val_loss: 212.1146 - val_pearson: 1.5554e-04 - val_mean_squared_error: 212.1146 - val_mean_absolute_error: 8.1972
# Epoch 64/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 454.6102 - pearson: 1.7906e-04 - mean_squared_error: 454.6102 - mean_absolute_error: 10.1357
# Epoch 00064: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8033 - pearson: 1.8049e-04 - mean_squared_error: 454.8033 - mean_absolute_error: 10.1352 - val_loss: 212.2898 - val_pearson: 1.5552e-04 - val_mean_squared_error: 212.2898 - val_mean_absolute_error: 8.2176
# Epoch 65/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 454.5957 - pearson: 1.7154e-04 - mean_squared_error: 454.5957 - mean_absolute_error: 10.1460
# Epoch 00065: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7507 - pearson: 1.7298e-04 - mean_squared_error: 454.7507 - mean_absolute_error: 10.1493 - val_loss: 212.4008 - val_pearson: 1.5552e-04 - val_mean_squared_error: 212.4008 - val_mean_absolute_error: 8.2304
# Epoch 66/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4869 - pearson: 1.4738e-04 - mean_squared_error: 455.4869 - mean_absolute_error: 10.1573
# Epoch 00066: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8245 - pearson: 1.5002e-04 - mean_squared_error: 454.8245 - mean_absolute_error: 10.1510 - val_loss: 212.3143 - val_pearson: 1.5551e-04 - val_mean_squared_error: 212.3143 - val_mean_absolute_error: 8.2204
# Epoch 67/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.2855 - pearson: 1.3437e-04 - mean_squared_error: 455.2855 - mean_absolute_error: 10.1329
# Epoch 00067: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8072 - pearson: 1.3418e-04 - mean_squared_error: 454.8072 - mean_absolute_error: 10.1299 - val_loss: 212.1794 - val_pearson: 1.5551e-04 - val_mean_squared_error: 212.1794 - val_mean_absolute_error: 8.2048
# Epoch 68/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4184 - pearson: 1.2646e-04 - mean_squared_error: 455.4184 - mean_absolute_error: 10.1395
# Epoch 00068: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7795 - pearson: 1.2665e-04 - mean_squared_error: 454.7795 - mean_absolute_error: 10.1338 - val_loss: 212.2608 - val_pearson: 1.5548e-04 - val_mean_squared_error: 212.2608 - val_mean_absolute_error: 8.2142
# Epoch 69/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.3938 - pearson: 1.4754e-04 - mean_squared_error: 455.3938 - mean_absolute_error: 10.1470
# Epoch 00069: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7623 - pearson: 1.5190e-04 - mean_squared_error: 454.7623 - mean_absolute_error: 10.1415 - val_loss: 212.2064 - val_pearson: 1.5546e-04 - val_mean_squared_error: 212.2064 - val_mean_absolute_error: 8.2079
# Epoch 70/300
# 1000/1000 [==============================] - 1s 968us/steps: 453.1851 - pearson: 1.4399e-04 - mean_squared_error: 453.185
# [('loss', 265.99061663818361), ('pearson', 0.00017463010406936519), ('mean_squared_error', 265.99061737060549), ('mean_absolute_error', 8.6333511657714848)]
# Test spearman: 0.026335972819
#
# Epoch 00070: val_loss did not improve
# 7500/7500 [==============================] - 88s 12ms/step - loss: 454.7455 - pearson: 1.4575e-04 - mean_squared_error: 454.7455 - mean_absolute_error: 10.1346 - val_loss: 212.1169 - val_pearson: 1.5543e-04 - val_mean_squared_error: 212.1169 - val_mean_absolute_error: 8.1975
# Epoch 71/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.2739 - pearson: 1.3785e-04 - mean_squared_error: 455.2739 - mean_absolute_error: 10.1340
# Epoch 00071: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8463 - pearson: 1.3885e-04 - mean_squared_error: 454.8463 - mean_absolute_error: 10.1307 - val_loss: 212.0748 - val_pearson: 1.5543e-04 - val_mean_squared_error: 212.0748 - val_mean_absolute_error: 8.1926
# Epoch 72/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4371 - pearson: 1.3998e-04 - mean_squared_error: 455.4371 - mean_absolute_error: 10.1404
# Epoch 00072: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7977 - pearson: 1.3980e-04 - mean_squared_error: 454.7977 - mean_absolute_error: 10.1345 - val_loss: 212.1225 - val_pearson: 1.5541e-04 - val_mean_squared_error: 212.1225 - val_mean_absolute_error: 8.1981
# Epoch 73/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4077 - pearson: 1.4760e-04 - mean_squared_error: 455.4077 - mean_absolute_error: 10.1301
# Epoch 00073: val_loss did not improve
# 7500/7500 [==============================] - 87s 12ms/step - loss: 454.7981 - pearson: 1.4812e-04 - mean_squared_error: 454.7981 - mean_absolute_error: 10.1254 - val_loss: 212.1673 - val_pearson: 1.5538e-04 - val_mean_squared_error: 212.1673 - val_mean_absolute_error: 8.2034
# Epoch 74/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4080 - pearson: 1.6122e-04 - mean_squared_error: 455.4080 - mean_absolute_error: 10.1385
# Epoch 00074: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8046 - pearson: 1.6097e-04 - mean_squared_error: 454.8046 - mean_absolute_error: 10.1340 - val_loss: 212.1657 - val_pearson: 1.5534e-04 - val_mean_squared_error: 212.1657 - val_mean_absolute_error: 8.2032
# Epoch 75/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 454.8039 - pearson: 1.6009e-04 - mean_squared_error: 454.8039 - mean_absolute_error: 10.1081
# Epoch 00075: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8180 - pearson: 1.5994e-04 - mean_squared_error: 454.8180 - mean_absolute_error: 10.1106 - val_loss: 211.9756 - val_pearson: 1.5532e-04 - val_mean_squared_error: 211.9756 - val_mean_absolute_error: 8.1809
# Epoch 76/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.2615 - pearson: 1.8024e-04 - mean_squared_error: 455.2615 - mean_absolute_error: 10.1326
# Epoch 00076: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8222 - pearson: 1.8126e-04 - mean_squared_error: 454.8222 - mean_absolute_error: 10.1311 - val_loss: 211.9630 - val_pearson: 1.5531e-04 - val_mean_squared_error: 211.9630 - val_mean_absolute_error: 8.1795
# Epoch 77/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4615 - pearson: 1.5185e-04 - mean_squared_error: 455.4615 - mean_absolute_error: 10.1152
# Epoch 00077: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8315 - pearson: 1.5162e-04 - mean_squared_error: 454.8315 - mean_absolute_error: 10.1093 - val_loss: 211.9006 - val_pearson: 1.5530e-04 - val_mean_squared_error: 211.9006 - val_mean_absolute_error: 8.1721
# Epoch 78/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.3027 - pearson: 1.6384e-04 - mean_squared_error: 455.3027 - mean_absolute_error: 10.1157
# Epoch 00078: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8115 - pearson: 1.6436e-04 - mean_squared_error: 454.8115 - mean_absolute_error: 10.1121 - val_loss: 211.9182 - val_pearson: 1.5533e-04 - val_mean_squared_error: 211.9182 - val_mean_absolute_error: 8.1742
# Epoch 79/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4532 - pearson: 1.2315e-04 - mean_squared_error: 455.4532 - mean_absolute_error: 10.1081
# Epoch 00079: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8543 - pearson: 1.2397e-04 - mean_squared_error: 454.8543 - mean_absolute_error: 10.1032 - val_loss: 211.9378 - val_pearson: 1.5538e-04 - val_mean_squared_error: 211.9378 - val_mean_absolute_error: 8.1765
# Epoch 80/300
# 1000/1000 [==============================] - 1s 968us/steps: 454.4855 - pearson: 1.4709e-04 - mean_squared_error: 454.485
# [('loss', 265.78371942138671), ('pearson', 0.00017448354720545466), ('mean_squared_error', 265.78373501586913), ('mean_absolute_error', 8.600509956359863)]
# Test spearman: 0.0263358709654
#
# Epoch 00080: val_loss did not improve
# 7500/7500 [==============================] - 88s 12ms/step - loss: 454.8321 - pearson: 1.4913e-04 - mean_squared_error: 454.8321 - mean_absolute_error: 10.1052 - val_loss: 211.8098 - val_pearson: 1.5536e-04 - val_mean_squared_error: 211.8098 - val_mean_absolute_error: 8.1614
# Epoch 81/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 454.7431 - pearson: 1.6078e-04 - mean_squared_error: 454.7431 - mean_absolute_error: 10.1086
# Epoch 00081: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8134 - pearson: 1.6208e-04 - mean_squared_error: 454.8134 - mean_absolute_error: 10.1119 - val_loss: 212.1295 - val_pearson: 1.5552e-04 - val_mean_squared_error: 212.1295 - val_mean_absolute_error: 8.1990
# Epoch 82/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.3582 - pearson: 1.4831e-04 - mean_squared_error: 455.3582 - mean_absolute_error: 10.1435
# Epoch 00082: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8001 - pearson: 1.4808e-04 - mean_squared_error: 454.8001 - mean_absolute_error: 10.1388 - val_loss: 212.2156 - val_pearson: 1.5552e-04 - val_mean_squared_error: 212.2156 - val_mean_absolute_error: 8.2090
# Epoch 83/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.3197 - pearson: 1.5676e-04 - mean_squared_error: 455.3197 - mean_absolute_error: 10.1427
# Epoch 00083: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8137 - pearson: 1.5708e-04 - mean_squared_error: 454.8137 - mean_absolute_error: 10.1382 - val_loss: 212.2631 - val_pearson: 1.5557e-04 - val_mean_squared_error: 212.2631 - val_mean_absolute_error: 8.2145
# Epoch 84/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 454.7727 - pearson: 1.8119e-04 - mean_squared_error: 454.7727 - mean_absolute_error: 10.1330
# Epoch 00084: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8149 - pearson: 1.8130e-04 - mean_squared_error: 454.8149 - mean_absolute_error: 10.1350 - val_loss: 212.2171 - val_pearson: 1.5555e-04 - val_mean_squared_error: 212.2171 - val_mean_absolute_error: 8.2092
# Epoch 85/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.2836 - pearson: 1.2522e-04 - mean_squared_error: 455.2836 - mean_absolute_error: 10.1374
# Epoch 00085: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8589 - pearson: 1.2686e-04 - mean_squared_error: 454.8589 - mean_absolute_error: 10.1360 - val_loss: 212.0980 - val_pearson: 1.5548e-04 - val_mean_squared_error: 212.0980 - val_mean_absolute_error: 8.1953
# Epoch 86/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.1272 - pearson: 1.5966e-04 - mean_squared_error: 455.1272 - mean_absolute_error: 10.1174
# Epoch 00086: val_loss did not improve
# 7500/7500 [==============================] - 87s 12ms/step - loss: 454.7500 - pearson: 1.5967e-04 - mean_squared_error: 454.7500 - mean_absolute_error: 10.1142 - val_loss: 212.0385 - val_pearson: 1.5546e-04 - val_mean_squared_error: 212.0385 - val_mean_absolute_error: 8.1883
# Epoch 87/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 453.7246 - pearson: 1.4175e-04 - mean_squared_error: 453.7246 - mean_absolute_error: 10.1060
# Epoch 00087: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8110 - pearson: 1.4168e-04 - mean_squared_error: 454.8110 - mean_absolute_error: 10.1129 - val_loss: 211.8403 - val_pearson: 1.5539e-04 - val_mean_squared_error: 211.8403 - val_mean_absolute_error: 8.1650
# Epoch 88/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.2677 - pearson: 1.3322e-04 - mean_squared_error: 455.2677 - mean_absolute_error: 10.1063
# Epoch 00088: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.7992 - pearson: 1.3508e-04 - mean_squared_error: 454.7992 - mean_absolute_error: 10.1029 - val_loss: 211.8309 - val_pearson: 1.5540e-04 - val_mean_squared_error: 211.8309 - val_mean_absolute_error: 8.1639
# Epoch 89/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.2454 - pearson: 1.4132e-04 - mean_squared_error: 455.2454 - mean_absolute_error: 10.0999
# Epoch 00089: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8306 - pearson: 1.4140e-04 - mean_squared_error: 454.8306 - mean_absolute_error: 10.0966 - val_loss: 211.8914 - val_pearson: 1.5549e-04 - val_mean_squared_error: 211.8914 - val_mean_absolute_error: 8.1711
# Epoch 90/300
# 1000/1000 [==============================] - 1s 965us/steps: 455.1801 - pearson: 1.7449e-04 - mean_squared_error: 455.180
# [('loss', 265.79523095703127), ('pearson', 0.00017460835387464612), ('mean_squared_error', 265.79523214721678), ('mean_absolute_error', 8.6023641357421869)]
# Test spearman: 0.0263358709654
#
# Epoch 00090: val_loss did not improve
# 7500/7500 [==============================] - 87s 12ms/step - loss: 454.7920 - pearson: 1.7558e-04 - mean_squared_error: 454.7920 - mean_absolute_error: 10.1134 - val_loss: 211.8270 - val_pearson: 1.5549e-04 - val_mean_squared_error: 211.8270 - val_mean_absolute_error: 8.1635
# Epoch 91/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.2847 - pearson: 1.5133e-04 - mean_squared_error: 455.2846 - mean_absolute_error: 10.1037
# Epoch 00091: val_loss did not improve
# 7500/7500 [==============================] - 84s 11ms/step - loss: 454.8171 - pearson: 1.5120e-04 - mean_squared_error: 454.8171 - mean_absolute_error: 10.1006 - val_loss: 211.9620 - val_pearson: 1.5554e-04 - val_mean_squared_error: 211.9620 - val_mean_absolute_error: 8.1794
# Epoch 92/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.0229 - pearson: 1.5290e-04 - mean_squared_error: 455.0229 - mean_absolute_error: 10.1060
# Epoch 00092: val_loss did not improve
# 7500/7500 [==============================] - 84s 11ms/step - loss: 454.8067 - pearson: 1.5280e-04 - mean_squared_error: 454.8067 - mean_absolute_error: 10.1059 - val_loss: 211.8834 - val_pearson: 1.5549e-04 - val_mean_squared_error: 211.8834 - val_mean_absolute_error: 8.1701
# Epoch 93/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 455.4856 - pearson: 1.4010e-04 - mean_squared_error: 455.4856 - mean_absolute_error: 10.1188
# Epoch 00093: val_loss did not improve
# 7500/7500 [==============================] - 84s 11ms/step - loss: 454.8344 - pearson: 1.4185e-04 - mean_squared_error: 454.8344 - mean_absolute_error: 10.1127 - val_loss: 212.1145 - val_pearson: 1.5552e-04 - val_mean_squared_error: 212.1145 - val_mean_absolute_error: 8.1972
# Epoch 94/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 453.9895 - pearson: 1.1936e-04 - mean_squared_error: 453.9895 - mean_absolute_error: 10.1190
# Epoch 00094: val_loss did not improve
# 7500/7500 [==============================] - 84s 11ms/step - loss: 454.8570 - pearson: 1.1944e-04 - mean_squared_error: 454.8570 - mean_absolute_error: 10.1245 - val_loss: 212.0942 - val_pearson: 1.5552e-04 - val_mean_squared_error: 212.0942 - val_mean_absolute_error: 8.1948
# Epoch 95/300
# 7488/7500 [============================>.] - ETA: 0s - loss: 454.9098 - pearson: 1.4648e-04 - mean_squared_error: 454.9099 - mean_absolute_error: 10.1378
# Epoch 00095: val_loss did not improve
# 7500/7500 [==============================] - 85s 11ms/step - loss: 454.8315 - pearson: 1.4628e-04 - mean_squared_error: 454.8315 - mean_absolute_error: 10.1382 - val_loss: 212.2548 - val_pearson: 1.5555e-04 - val_mean_squared_error: 212.2548 - val_mean_absolute_error: 8.2135
# Epoch 96/300
# 5120/7500 [===================>..........] - ETA: 8s - loss: 437.0796 - pearson: 1.3863e-04 - mean_squared_error: 437.0796 - mean_absolute_error: 10.0602
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-ec4d1f074e35> in <module>()
#      14                      EvaluateModel(X_test, y_test),
#      15                      checkpointer,
# ---> 16                      SaveBigwig(X_train, y_train, X_val, y_val, X_test, y_test)])
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1667                               initial_epoch=initial_epoch,
#    1668                               steps_per_epoch=steps_per_epoch,
# -> 1669                               validation_steps=validation_steps)
#    1670
#    1671     def evaluate(self, x=None, y=None,
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/keras/engine/training.pyc in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1204                         ins_batch[i] = ins_batch[i].toarray()
#    1205
# -> 1206                     outs = f(ins_batch)
#    1207                     if not isinstance(outs, list):
#    1208                         outs = [outs]
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /users/jesikmin/anaconda2/envs/genomelake_env/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
