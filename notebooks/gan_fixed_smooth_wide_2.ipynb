# %% [markdown]
# # Gan Baseline

# %% [markdown]
# #### NOTE: Need to activate genomelake environment before this code. Simply type 'genomelake' in terminal.

# %%
# %env CUDA_VISIBLE_DEVICES=3,4
import os, sys
sys.path.append("..")
import random
# custom file path package
from data import Data_Directories
# custom utility package
from utils.compute_util import *
# package for genomic data
from pybedtools import Interval, BedTool
from genomelake.extractors import ArrayExtractor, BigwigExtractor
# package for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats.stats import pearsonr,spearmanr
import tensorflow as tf
# Out:
# env: CUDA_VISIBLE_DEVICES=3,4,5,6
# Using TensorFlow backend.

# %%
window_size = 5001
process_all = False
sample_num = 1000

# %%
# retrieve data
data = Data_Directories()
print data.intervals.keys()
print data.input_atac['day0'].keys()
print data.output_histone['day0'].keys()
# Out:
# ['day6', 'day3', 'day0']
# ['100', '140']
# ['H3K27me3', 'H3K4me1', 'H3K27ac']

# %%
# get intervals for day0 data
day0_intervals = list(BedTool(data.intervals['day0']))
print '# of Intervals Extracted for day0: {}'.format(len(day0_intervals))
# Out:
# # of Intervals Extracted for day0: 267226

# %%
# create an ArrayExtractor for ATAC-seq for day0 with 140 base pairs
bw_140bp_day0 = ArrayExtractor(data.input_atac['day0']['140'])
print 'Finished extracting bigwig for day0, 140bp'
# Out:
# Finished extracting bigwig for day0, 140bp

# %%
# create a BigWigExtractor for histone makr 'H3K27ac' for day0
bw_histone_mark_day0 = BigwigExtractor(data.output_histone['day0']['H3K27ac'])
print 'Finished extracting bigwig for day0, 140bp'
# Out:
# Finished extracting bigwig for day0, 140bp

# %%
# normalize day0 intervals
normalized_day0_intervals = [normalize_interval(interval, window_size) for interval in day0_intervals if normalize_interval(interval, window_size)]
print 'Finished normalizing day0 intervals!'
# Out:
# Finished normalizing day0 intervals!

# %%
assert (len(day0_intervals)==len(normalized_day0_intervals))
print "Examples of original intervals"
print [(int(_interval.start)+int(_interval[-1]), [int(_interval.start), int(_interval.end)])
       for _interval in day0_intervals[:3]]
print "Examples of normalized intervals with window size of {}".format(window_size)
print [([int(_interval.start), int(_interval.end)])
       for _interval in  normalized_day0_intervals[:3]]
# Out:
# Examples of original intervals
# [(123412027, [123411855, 123412989]), (123411941, [123411855, 123412989]), (131908564, [131908487, 131910071])]
# Examples of normalized intervals with window size of 2001
# [[123411027, 123413028], [123410941, 123412942], [131907564, 131909565]]

# %%
atac_seq_day0 = bw_140bp_day0(normalized_day0_intervals)
print atac_seq_day0.shape
# Out:
# (267226, 2001, 5)

# %%
#TODO: put this into utils if possible
def prune_invalid_intervals(intervals, bigwig_file):
    for _interval in intervals[:]:
        try:
            bigwig_file([_interval])
        except:
            intervals.remove(_interval)
            pass
        
print "Before pruning day0: {}".format(len(normalized_day0_intervals))
prune_invalid_intervals(normalized_day0_intervals, bw_140bp_day0)
print "After pruning day0: {}".format(len(normalized_day0_intervals))
# Out:
# Before pruning day0: 267226
# After pruning day0: 267226

# %%
print "Dimension of ATAC-seq signal: {}".format(bw_140bp_day0(normalized_day0_intervals[:1]).shape)
# Out:
# Dimension of ATAC-seq signal: (1, 2001, 5)

# %%
print "Dimension of histone mark signal: {}".format(bw_histone_mark_day0(normalized_day0_intervals[:1]).shape)
# Out:
# Dimension of histone mark signal: (1, 2001)

# %%
# replace nan values with zeros and convert it to p-values
histone_mark_day0 = np.nan_to_num(bw_histone_mark_day0(normalized_day0_intervals))
print histone_mark_day0.shape
# Out:
# (267226, 2001)

# %%
histone_mark_day0 = np.expand_dims(histone_mark_day0, axis=2)
print histone_mark_day0.shape
# Out:
# (267226, 2001, 1)

# %%
print "Example histone mark signal"
print "\tRaw value: {}".format(bw_histone_mark_day0(normalized_day0_intervals[:1])[0][:5].reshape(-1))
# Out:
# Example histone mark signal
# 	Raw value: [ 0.01014  0.01014  0.01014  0.02435  0.02435]

# %%
from keras.layers import AveragePooling1D, Input, Dense, Conv1D, Dropout, BatchNormalization, Activation, ZeroPadding1D, Reshape, Flatten
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from keras import optimizers
from keras import metrics
from keras import losses
from keras import backend as K
from keras.callbacks import Callback, TensorBoard, ReduceLROnPlateau, ModelCheckpoint
from keras.optimizers import Adam, SGD

# %%
smooth_rate = 0.05
dropout_rate = 0.5
# parameters for first conv layer
hidden_filters_1 = 32
hidden_kernel_size_1 = window_size
# parameters for second conv layer
output_filters = 1
output_kernel_size = 16
# parameters for training
batch_size = 128
num_epochs = 200
evaluation_freq = 10

# %%
# Helper functions for writing the scores into bigwig file
from itertools import izip
from itertools import groupby
import subprocess

def interval_key(interval):
    return (interval.chrom, interval.start, interval.stop)

def merged_scores(scores, intervals, merge_type):
    # A generator that returns merged intervals/scores
    # Scores should have shape: #examples x #categories x #interval_size
    # Second dimension can be omitted for a 1D signal
    signal_dims = scores.ndim - 1
    assert signal_dims in {1, 2}

    # Only support max for now
    assert merge_type == 'max'
    score_first_dim = 1 if signal_dims == 1 else scores.shape[1]

    dtype = scores.dtype

    sort_idx, sorted_intervals = \
        zip(*sorted(enumerate(intervals),
                    key=lambda item: interval_key(item[1])))
    sorted_intervals = BedTool(sorted_intervals)

    # Require at least 1bp overlap
    # Explicitly convert to list otherwise it will keep opening a file when
    # retrieving an index resulting in an error (too many open files)
    interval_clust = list(sorted_intervals.cluster(d=-1))
    for _, group in groupby(izip(sort_idx, interval_clust),
                            key=lambda item: item[1].fields[-1]):
        idx_interval_pairs = list(group)
        group_idx, group_intervals = zip(*idx_interval_pairs)

        if len(idx_interval_pairs) == 1:
            yield group_intervals[0], scores[group_idx[0], ...]
        else:
            group_chrom = group_intervals[0].chrom
            group_start = min(interval.start for interval in group_intervals)
            group_stop = max(interval.stop for interval in group_intervals)

            # This part needs to change to support more merge_types (e.g. mean)
            group_score = np.full((score_first_dim, group_stop - group_start),
                                  -np.inf, dtype)
            for idx, interval in idx_interval_pairs:
                slice_start = interval.start - group_start
                slice_stop = slice_start + (interval.stop - interval.start)
                group_score[..., slice_start:slice_stop] = \
                    np.maximum(group_score[..., slice_start:slice_stop],
                               scores[idx, ...])
            if signal_dims == 1:
                group_score = group_score.squeeze(axis=0)
            yield Interval(group_chrom, group_start, group_stop), group_score
            
def interval_score_pairs(intervals, scores, merge_type):
    return (izip(intervals, scores) if merge_type is None
            else merged_scores(scores, intervals, merge_type))

def _write_1D_deeplift_track(scores, intervals, file_prefix, merge_type='max',
                             CHROM_SIZES='/mnt/data/annotations/by_release/hg19.GRCh37/hg19.chrom.sizes'):
    assert scores.ndim == 2

    bedgraph = file_prefix + '.bedGraph'
    bigwig = file_prefix + '.bw'

    print 'Writing 1D track of shape: {}'.format(scores.shape)
    print 'Writing to file: {}'.format(bigwig)

    with open(bedgraph, 'w') as fp:
        for interval, score in interval_score_pairs(intervals, scores,
                                                    merge_type):
            chrom = interval.chrom
            start = interval.start
            for score_idx, val in enumerate(score):
                fp.write('%s\t%d\t%d\t%g\n' % (chrom,
                                               start + score_idx,
                                               start + score_idx + 1,
                                               val))
    print 'Wrote bedgraph.'

    try:
        output = subprocess.check_output(
            ['wigToBigWig', bedgraph, CHROM_SIZES, bigwig],
            stderr=subprocess.STDOUT)
        print 'wigToBigWig output: {}'.format(output)
    except subprocess.CalledProcessError as e:
        print 'wigToBigWig terminated with exit code {}'.format(
            e.returncode)
        print 'output was:\n' + e.output

    print 'Wrote bigwig.'

# %%
model_dir = os.path.join("models", "gan_fixed_smooth_wide_2")
log_dir = os.path.join("logs", "gan_fixed_smooth_wide_2")
srv_dir = os.path.join("/srv", "www", "kundaje", "jesikmin", "gan_fixed_smooth_wide_2")
#srv_dir = os.path.join("/users", "jesikmin", "gan_fixed_smooth_2")
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
if not os.path.exists(log_dir):
    os.makedirs(log_dir)
if not os.path.exists(srv_dir):
    os.makedirs(srv_dir)

# %%
class GAN():
    def __init__(self):
        
        self.window_size = window_size
        self.channels = 5
        self.input_shape = (self.window_size, self.channels,)
        self.output_shape = (self.window_size, 1,)

        optimizer = Adam(0.002, beta_1=0.5)
        doptimizer = Adam(0.001, beta_1=0.5)

        # Build and compile the discriminator
        self.discriminator = self.build_discriminator()
        self.discriminator.compile(loss='binary_crossentropy', 
                                   optimizer=doptimizer,
                                   metrics=['accuracy'])

        # Build and compile the generator
        self.generator = self.build_generator()
        self.generator.compile(loss='binary_crossentropy',
                               optimizer=optimizer)

        # The generator takes noise as input and generated imgs
        z = Input(shape=self.input_shape)
        img = self.generator(z)

        # For the combined model we will only train the generator
        self.discriminator.trainable = False

        # The valid takes generated images as input and determines validity
        valid = self.discriminator(img)

        # The combined model  (stacked generator and discriminator) takes
        # noise as input => generates images => determines validity 
        self.combined = Model(z, valid)
        self.combined.compile(loss='binary_crossentropy',
                              optimizer=optimizer)
        print "Combined Model"
        print self.combined.summary()

    def build_generator(self):

        noise_shape = self.input_shape
        
        model = Sequential()

        model.add(Conv1D(hidden_filters_1,
                         hidden_kernel_size_1,
                         padding="valid",
                         strides=1,
                         input_shape=noise_shape,
                         activation='relu'))
        model.add(Dropout(dropout_rate))

        model.add(Conv1D(output_filters,
                         output_kernel_size,
                         padding='same',
                         strides=1))
        model.add(Activation('linear'))
        
        print "Generator"
        model.summary()

        noise = Input(shape=noise_shape)
        img = model(noise)

        return Model(noise, img)

    def build_discriminator(self):
        model = Sequential()
        
        model.add(Conv1D(hidden_filters_1,
                         500,
                         padding="valid",
                         strides=1,
                         input_shape=self.output_shape))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(dropout_rate))
        model.add(BatchNormalization(momentum=0.8))
        
        model.add(AveragePooling1D(25))
        model.add(Flatten())
        model.add(Dense(int(window_size/16)))
        model.add(LeakyReLU(alpha=0.2)) 
        
        model.add(Dense(1, activation='sigmoid'))
        
        print "Discriminator"
        model.summary()

        img = Input(shape=self.output_shape)
        validity = model(img)

        return Model(img, validity)

    def train(self, epochs, batch_size, X_train, y_train):
        
        max_pearson = -1.0

        half_batch = int(batch_size / 2)
            
        d_loss_real, d_loss_fake, g_loss = [1, 0], [1, 0], [1, 0]
            
        for epoch in range(epochs):
            
            # list for storing losses/accuracies for both discriminator and generator
            d_losses, d_accuracies, g_losses = [], [], []
            
            # sufficient number of minibatches for each epoch
            for _minibatch_idx in range(128):

                # ---------------------
                #  Train Discriminator
                # ---------------------

                # Select a random half batch of images
                dis_idx = np.random.randint(0, y_train.shape[0], half_batch)
                imgs = y_train[dis_idx]
                dis_noise = X_train[dis_idx]

                # Generate a half batch of new images
                gen_imgs = self.generator.predict(dis_noise)
                
                # Train the discriminator with label smoothing
                #smoothed_idx = np.random.choice(half_batch, int(half_batch*smooth_rate), replace=False)
                smoothed_labels = np.ones((half_batch, 1))
                #smoothed_labels[smoothed_idx] = 0
                
                # Train the discriminator
                all_imgs = np.concatenate([imgs, gen_imgs])
                all_labels = np.concatenate([smoothed_labels, np.zeros((half_batch, 1))])
                d_loss = self.discriminator.train_on_batch(all_imgs, all_labels)
                
#                 if epoch % 5 == 0:
#                     d_loss = self.discriminator.train_on_batch(all_imgs, all_labels)
#                 else:
#                     d_loss = (-1, -1)
                
#                 d_loss_real = self.discriminator.train_on_batch(imgs, smoothed_labels)
#                 d_loss_fake = self.discriminator.train_on_batch(gen_imgs, np.zeros((half_batch, 1)))
                    
                # take the average of each loss and accuracy
                #d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
                
                # ---------------------
                #  Train Generator
                # ---------------------
                
                gen_idx = np.random.randint(0, y_train.shape[0], batch_size)
                gen_noise = X_train[gen_idx]
                #noise = np.random.normal(0, 1, (batch_size, 100))

                # The generator wants the discriminator to label the generated samples
                # as valid (ones)
                valid_y = np.array([1] * batch_size)

                # Train the generator
                g_loss = self.combined.train_on_batch(gen_noise, valid_y)
                
                d_losses.append(d_loss[0])
                d_accuracies.append(d_loss[1])
                
                g_losses.append(g_loss)
                
            # convert each histories into numpy arrays to get means
            d_losses = np.array(d_losses)
            d_accuracies = np.array(d_accuracies)
            g_losses = np.array(g_losses)
            
            predictions = self.generator.predict(X_train).flatten()
            avg_pearson = pearsonr(predictions, y_train.flatten())
            print "Pearson R on Train set: {}".format(avg_pearson)
            
            val_predictions = self.generator.predict(X_val).flatten()
            avg_val_pearson = pearsonr(val_predictions, y_val.flatten())
            print "Pearson R on Val set: {}".format(avg_val_pearson)
            
#             predictions = self.generator.predict(X_train)
#             pearsons = []
#             for pred_idx in range(len(predictions)):
#                 prediction = predictions[pred_idx]
#                 pearsons.append(pearsonr(prediction, y_train[pred_idx]))
#             avg_pearson = np.array(pearsons).mean()
#             print "Pearson R on Train set: {}".format(avg_pearson)
            
#             val_predictions = self.generator.predict(X_val)
#             val_pearsons = []
#             for val_pred_idx in range(len(val_predictions)):
#                 prediction = val_predictions[val_pred_idx]
#                 val_pearsons.append(pearsonr(prediction, y_val[val_pred_idx]))
#             avg_val_pearson = np.array(val_pearsons).mean()
#             print "Pearson R on Val set: {}".format(avg_val_pearson)  
            
            if max_pearson < avg_val_pearson:
                print "Perason on val improved from {} to {}".format(max_pearson, avg_val_pearson)
                _write_1D_deeplift_track(predictions.reshape(7500, 5001),
                                         normalized_day0_intervals[:7500], os.path.join(srv_dir, 'train'))
                _write_1D_deeplift_track(val_predictions.reshape(2500, 5001),
                                         normalized_day0_intervals[7500:10000], os.path.join(srv_dir, 'val'))
                f = open(os.path.join(srv_dir, 'meta.txt'), 'wb')
                f.write(str(epoch) + " " + str(avg_pearson) + "  " + str(avg_val_pearson))
                f.close()
                max_pearson = avg_val_pearson
            
            # Plot the progress
            print ("%d [D loss: %f, acc.: %.2f%%] [G loss: %f]" % (epoch, d_losses.mean(), 100.0*d_accuracies.mean(), g_losses.mean()))

# %%
def pearson(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = K.mean(x)
    my = K.mean(y)
    xm, ym = x-mx, y-my
    r_num = K.sum(np.multiply(xm,ym))
    r_den = K.sqrt(np.multiply(K.sum(K.square(xm)), K.sum(K.square(ym))))
    r = r_num / r_den
    r = K.maximum(K.minimum(r, 1.0), -1.0)
    return K.square(r)

# %%
print "Fitting the model..."
X_train, y_train = atac_seq_day0[:7500], histone_mark_day0[:7500]
X_val, y_val = atac_seq_day0[7500:10000], histone_mark_day0[7500:10000]
X_test, y_test = atac_seq_day0[10000:11000], histone_mark_day0[10000:11000]

gan = GAN()
gan.train(num_epochs, batch_size, X_train, y_train)
# Out:
# Fitting the model...
# Discriminator
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_25 (Conv1D)           (None, 1802, 32)          6432
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 1802, 32)          0
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 1802, 32)          0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 1802, 32)          128
# _________________________________________________________________
# average_pooling1d_9 (Average (None, 72, 32)            0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 125)               288125
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 125)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 126
# =================================================================
# Total params: 294,811
# Trainable params: 294,747
# Non-trainable params: 64
# _________________________________________________________________
# Generator
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_26 (Conv1D)           (None, 2001, 32)          320192
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 2001, 32)          0
# _________________________________________________________________
# conv1d_27 (Conv1D)           (None, 2001, 1)           513
# _________________________________________________________________
# activation_9 (Activation)    (None, 2001, 1)           0
# =================================================================
# Total params: 320,705
# Trainable params: 320,705
# Non-trainable params: 0
# _________________________________________________________________
# Combined Model
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_27 (InputLayer)        (None, 2001, 5)           0
# _________________________________________________________________
# model_26 (Model)             (None, 2001, 1)           320705
# _________________________________________________________________
# model_25 (Model)             (None, 1)                 294811
# =================================================================
# Total params: 615,516
# Trainable params: 320,705
# Non-trainable params: 294,811
# _________________________________________________________________
# None
# Pearson R on Train set: (0.31439361, 0.0)
# Pearson R on Val set: (0.33898374, 0.0)
# Perason on val improved from -1.0 to (0.33898374, 0.0)
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 0 [D loss: 0.585139, acc.: 75.04%] [G loss: 1.302129]
# Pearson R on Train set: (0.21178222, 0.0)
# Pearson R on Val set: (0.25451234, 0.0)
# 1 [D loss: 0.431233, acc.: 82.16%] [G loss: 1.237247]
# Pearson R on Train set: (0.26262641, 0.0)
# Pearson R on Val set: (0.28457311, 0.0)
# 2 [D loss: 0.161813, acc.: 94.37%] [G loss: 2.079501]
# Pearson R on Train set: (0.25903696, 0.0)
# Pearson R on Val set: (0.27224475, 0.0)
# 3 [D loss: 0.256731, acc.: 90.58%] [G loss: 1.499895]
# Pearson R on Train set: (0.31175974, 0.0)
# Pearson R on Val set: (0.32695049, 0.0)
# 4 [D loss: 0.227150, acc.: 91.50%] [G loss: 1.659673]
# Pearson R on Train set: (0.27672952, 0.0)
# Pearson R on Val set: (0.28974459, 0.0)
# 5 [D loss: 0.241620, acc.: 91.09%] [G loss: 1.779148]
# Pearson R on Train set: (0.26438782, 0.0)
# Pearson R on Val set: (0.28283408, 0.0)
# 6 [D loss: 0.200159, acc.: 92.61%] [G loss: 1.848552]
# Pearson R on Train set: (0.26918507, 0.0)
# Pearson R on Val set: (0.27930066, 0.0)
# 7 [D loss: 0.369392, acc.: 84.58%] [G loss: 1.436221]
# Pearson R on Train set: (0.23624401, 0.0)
# Pearson R on Val set: (0.257007, 0.0)
# 8 [D loss: 0.396670, acc.: 82.67%] [G loss: 1.343552]
# Pearson R on Train set: (0.24589522, 0.0)
# Pearson R on Val set: (0.26618221, 0.0)
# 9 [D loss: 0.409261, acc.: 81.25%] [G loss: 1.250416]
# Pearson R on Train set: (0.29874539, 0.0)
# Pearson R on Val set: (0.31482917, 0.0)
# 10 [D loss: 0.362334, acc.: 84.01%] [G loss: 1.334945]
# Pearson R on Train set: (0.28369617, 0.0)
# Pearson R on Val set: (0.30863377, 0.0)
# 11 [D loss: 0.413303, acc.: 81.31%] [G loss: 1.141595]
# Pearson R on Train set: (0.31934413, 0.0)
# Pearson R on Val set: (0.33678308, 0.0)
# 12 [D loss: 0.357516, acc.: 85.46%] [G loss: 1.152708]
# Pearson R on Train set: (0.33471072, 0.0)
# Pearson R on Val set: (0.35088003, 0.0)
# Perason on val improved from (0.33898374, 0.0) to (0.35088003, 0.0)
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 13 [D loss: 0.355733, acc.: 85.83%] [G loss: 1.163314]
# Pearson R on Train set: (0.32105875, 0.0)
# Pearson R on Val set: (0.35538721, 0.0)
# Perason on val improved from (0.35088003, 0.0) to (0.35538721, 0.0)
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 14 [D loss: 0.338178, acc.: 87.07%] [G loss: 1.201495]
# Pearson R on Train set: (0.30581272, 0.0)
# Pearson R on Val set: (0.33414721, 0.0)
# 15 [D loss: 0.319029, acc.: 88.47%] [G loss: 1.297834]
# Pearson R on Train set: (0.35104632, 0.0)
# Pearson R on Val set: (0.36411068, 0.0)
# Perason on val improved from (0.35538721, 0.0) to (0.36411068, 0.0)
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 16 [D loss: 0.289529, acc.: 88.78%] [G loss: 1.271952]
# Pearson R on Train set: (0.34000972, 0.0)
# Pearson R on Val set: (0.3555468, 0.0)
# 17 [D loss: 0.274720, acc.: 89.61%] [G loss: 1.204011]
# Pearson R on Train set: (0.3549062, 0.0)
# Pearson R on Val set: (0.37008572, 0.0)
# Perason on val improved from (0.36411068, 0.0) to (0.37008572, 0.0)
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 18 [D loss: 0.269612, acc.: 89.82%] [G loss: 1.256798]
# Pearson R on Train set: (0.35028633, 0.0)
# Pearson R on Val set: (0.36340824, 0.0)
# 19 [D loss: 0.299042, acc.: 89.32%] [G loss: 1.553302]
# Pearson R on Train set: (0.3449026, 0.0)
# Pearson R on Val set: (0.36455536, 0.0)
# 20 [D loss: 0.247916, acc.: 90.71%] [G loss: 1.302043]
# Pearson R on Train set: (0.3429572, 0.0)
# Pearson R on Val set: (0.37115765, 0.0)
# Perason on val improved from (0.37008572, 0.0) to (0.37115765, 0.0)
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 21 [D loss: 0.244936, acc.: 91.05%] [G loss: 1.416943]
# Pearson R on Train set: (0.34228599, 0.0)
# Pearson R on Val set: (0.36605787, 0.0)
# 22 [D loss: 0.217742, acc.: 92.22%] [G loss: 1.318332]
# Pearson R on Train set: (0.36217627, 0.0)
# Pearson R on Val set: (0.38050869, 0.0)
# Perason on val improved from (0.37115765, 0.0) to (0.38050869, 0.0)
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 23 [D loss: 0.251536, acc.: 90.88%] [G loss: 1.590900]
# Pearson R on Train set: (0.30113956, 0.0)
# Pearson R on Val set: (0.32490602, 0.0)
# 24 [D loss: 0.222277, acc.: 92.16%] [G loss: 1.378849]
# Pearson R on Train set: (0.35665709, 0.0)
# Pearson R on Val set: (0.3785162, 0.0)
# 25 [D loss: 0.223370, acc.: 91.83%] [G loss: 1.501278]
# Pearson R on Train set: (0.36513206, 0.0)
# Pearson R on Val set: (0.38615453, 0.0)
# Perason on val improved from (0.38050869, 0.0) to (0.38615453, 0.0)
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 26 [D loss: 0.193351, acc.: 93.45%] [G loss: 1.419171]
# Pearson R on Train set: (0.35472167, 0.0)
# Pearson R on Val set: (0.36970675, 0.0)
# 27 [D loss: 0.221241, acc.: 92.82%] [G loss: 1.671629]
# Pearson R on Train set: (0.36912531, 0.0)
# Pearson R on Val set: (0.38059512, 0.0)
# 28 [D loss: 0.177300, acc.: 93.82%] [G loss: 1.398159]
# Pearson R on Train set: (0.36760351, 0.0)
# Pearson R on Val set: (0.37925667, 0.0)
# 29 [D loss: 0.192668, acc.: 93.07%] [G loss: 1.406848]
# Pearson R on Train set: (0.35402408, 0.0)
# Pearson R on Val set: (0.3758288, 0.0)
# 30 [D loss: 0.222215, acc.: 92.31%] [G loss: 1.694120]
# Pearson R on Train set: (0.39146742, 0.0)
# Pearson R on Val set: (0.40357396, 0.0)
# Perason on val improved from (0.38615453, 0.0) to (0.40357396, 0.0)
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 31 [D loss: 0.173712, acc.: 93.73%] [G loss: 1.504468]
# Pearson R on Train set: (0.39272884, 0.0)
# Pearson R on Val set: (0.40556443, 0.0)
# Perason on val improved from (0.40357396, 0.0) to (0.40556443, 0.0)
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 32 [D loss: 0.170080, acc.: 93.59%] [G loss: 1.389521]
# Pearson R on Train set: (0.39587206, 0.0)
# Pearson R on Val set: (0.41150075, 0.0)
# Perason on val improved from (0.40556443, 0.0) to (0.41150075, 0.0)
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 33 [D loss: 0.156623, acc.: 94.13%] [G loss: 1.444127]
# Pearson R on Train set: (0.38692591, 0.0)
# Pearson R on Val set: (0.40299213, 0.0)
# 34 [D loss: 0.141814, acc.: 94.79%] [G loss: 1.523898]
# Pearson R on Train set: (0.38556248, 0.0)
# Pearson R on Val set: (0.39847186, 0.0)
# 35 [D loss: 0.143371, acc.: 94.84%] [G loss: 1.626192]
# Pearson R on Train set: (0.38762495, 0.0)
# Pearson R on Val set: (0.40914086, 0.0)
# 36 [D loss: 0.144883, acc.: 94.59%] [G loss: 1.607622]
# Pearson R on Train set: (0.38729197, 0.0)
# Pearson R on Val set: (0.40074047, 0.0)
# 37 [D loss: 0.131352, acc.: 95.29%] [G loss: 1.772125]
# Pearson R on Train set: (0.37612629, 0.0)
# Pearson R on Val set: (0.39915282, 0.0)
# 38 [D loss: 0.196108, acc.: 92.63%] [G loss: 1.752601]
# Pearson R on Train set: (0.40212962, 0.0)
# Pearson R on Val set: (0.42091474, 0.0)
# Perason on val improved from (0.41150075, 0.0) to (0.42091474, 0.0)
# Writing 1D track of shape: (7500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/train.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# Writing 1D track of shape: (2500, 2001)
# Writing to file: /srv/www/kundaje/jesikmin/gan_fixed_smooth_new/val.bw
# Wrote bedgraph.
# wigToBigWig output:
# Wrote bigwig.
# 39 [D loss: 0.305281, acc.: 89.92%] [G loss: 1.743161]
# Pearson R on Train set: (0.3779113, 0.0)
# Pearson R on Val set: (0.39865777, 0.0)
# 40 [D loss: 0.236362, acc.: 91.60%] [G loss: 1.798799]
# Pearson R on Train set: (0.37878004, 0.0)
# Pearson R on Val set: (0.40008211, 0.0)
# 41 [D loss: 0.238726, acc.: 91.38%] [G loss: 1.743711]
# Pearson R on Train set: (0.37235367, 0.0)
# Pearson R on Val set: (0.39372939, 0.0)
# 42 [D loss: 0.185600, acc.: 93.17%] [G loss: 1.686961]
# Pearson R on Train set: (0.37284431, 0.0)
# Pearson R on Val set: (0.39521059, 0.0)
# 43 [D loss: 0.190554, acc.: 92.90%] [G loss: 1.742477]
# Pearson R on Train set: (0.34592995, 0.0)
# Pearson R on Val set: (0.36963758, 0.0)
# 44 [D loss: 0.131286, acc.: 95.25%] [G loss: 1.717908]
# Pearson R on Train set: (0.31999514, 0.0)
# Pearson R on Val set: (0.34102878, 0.0)
# 45 [D loss: 0.118829, acc.: 95.28%] [G loss: 1.684952]
# Pearson R on Train set: (0.219134, 0.0)
# Pearson R on Val set: (0.24178523, 0.0)
# 46 [D loss: 0.884543, acc.: 83.01%] [G loss: 3.823529]
# Pearson R on Train set: (0.011423334, 0.0)
# Pearson R on Val set: (-0.0053816233, 2.2770388692148538e-33)
# 47 [D loss: 0.131742, acc.: 94.25%] [G loss: 1.272282]
# Pearson R on Train set: (0.020536739, 0.0)
# Pearson R on Val set: (0.01532461, 1.701983105914206e-257)
# 48 [D loss: 0.008743, acc.: 99.91%] [G loss: 0.615638]
# Pearson R on Train set: (0.0049055177, 1.5848087449414119e-80)
# Pearson R on Val set: (0.003206182, 7.4424871689429729e-13)
# 49 [D loss: 0.004128, acc.: 99.94%] [G loss: 0.288627]
# Pearson R on Train set: (0.0060276948, 1.3397795757594008e-120)
# Pearson R on Val set: (0.0070299436, 1.0430902613004941e-55)
# 50 [D loss: 0.000504, acc.: 100.00%] [G loss: 0.085530]
# Pearson R on Train set: (0.002008253, 7.2592284732888295e-15)
# Pearson R on Val set: (-0.003309242, 1.3459577863458465e-13)
# 51 [D loss: 0.000304, acc.: 99.99%] [G loss: 0.053898]
# Pearson R on Train set: (0.0052310131, 2.6287928953884302e-91)
# Pearson R on Val set: (0.0049265218, 3.0997548098298723e-28)
# 52 [D loss: 0.000250, acc.: 100.00%] [G loss: 0.048220]
# Pearson R on Train set: (0.0042863111, 6.4081606573852441e-62)
# Pearson R on Val set: (0.00047628759, 0.28675039744348224)
# 53 [D loss: 0.000251, acc.: 100.00%] [G loss: 0.032344]
# Pearson R on Train set: (0.0041665663, 1.3108814239846639e-58)
# Pearson R on Val set: (-0.0015380144, 0.0005817881997801466)
# 54 [D loss: 0.000155, acc.: 100.00%] [G loss: 0.028907]
# Pearson R on Train set: (0.0052825478, 4.4646585390995771e-93)
# Pearson R on Val set: (-0.00013562098, 0.76163574302523918)
# 55 [D loss: 0.000149, acc.: 100.00%] [G loss: 0.028991]
# Pearson R on Train set: (0.0048171487, 1.0181905695034078e-77)
# Pearson R on Val set: (0.00071100477, 0.11177796304855601)
# 56 [D loss: 0.000093, acc.: 100.00%] [G loss: 0.028679]
# Pearson R on Train set: (0.0045795212, 2.0253803348586212e-70)
# Pearson R on Val set: (-0.0012875887, 0.0039785671274348289)
# 57 [D loss: 0.000075, acc.: 100.00%] [G loss: 0.025730]
# Pearson R on Train set: (0.0046217176, 1.0895547547470425e-71)
# Pearson R on Val set: (-0.00034856971, 0.43561444775291791)
# 58 [D loss: 0.000127, acc.: 100.00%] [G loss: 0.025658]
# Pearson R on Train set: (0.0042399117, 1.2609096636894358e-60)
# Pearson R on Val set: (-0.00050496851, 0.25871818563122256)
# 59 [D loss: 0.000068, acc.: 100.00%] [G loss: 0.021408]
# Pearson R on Train set: (0.0039803032, 1.2092326018426739e-53)
# Pearson R on Val set: (-0.0021933198, 9.312181738712883e-07)
# 60 [D loss: 0.000100, acc.: 100.00%] [G loss: 0.017965]
# Pearson R on Train set: (0.0039207609, 4.1892391613536939e-52)
# Pearson R on Val set: (-0.0020200477, 6.2398001000381587e-06)
# 61 [D loss: 0.000162, acc.: 100.00%] [G loss: 0.020815]
# Pearson R on Train set: (0.0041309362, 1.215418952806831e-57)
# Pearson R on Val set: (-0.00086665811, 0.052575568243743674)
# 62 [D loss: 0.000025, acc.: 100.00%] [G loss: 0.014573]
# Pearson R on Train set: (0.0039215568, 3.9967679383162048e-52)
# Pearson R on Val set: (-0.0021860055, 1.0120375614863094e-06)
# 63 [D loss: 0.000165, acc.: 100.00%] [G loss: 0.020956]
# Pearson R on Train set: (0.0042306273, 2.2799218443331538e-60)
# Pearson R on Val set: (-0.0010683991, 0.016866264129675609)
# 64 [D loss: 0.000059, acc.: 100.00%] [G loss: 0.023423]
# Pearson R on Train set: (0.0040625921, 8.2571220176322811e-56)
# Pearson R on Val set: (-0.00086980127, 0.051724351311536493)
# 65 [D loss: 0.000091, acc.: 100.00%] [G loss: 0.019377]
# Pearson R on Train set: (0.0039162599, 5.4649632914861166e-52)
# Pearson R on Val set: (-0.0020230529, 6.0447483236128071e-06)
# 66 [D loss: 0.000063, acc.: 100.00%] [G loss: 0.026796]
# Pearson R on Train set: (0.0035305221, 1.3910728181736562e-42)
# Pearson R on Val set: (-0.00057412055, 0.19910932169021128)
# 67 [D loss: 0.000025, acc.: 100.00%] [G loss: 0.025543]
# Pearson R on Train set: (0.0023636306, 5.3557094339727284e-20)
# Pearson R on Val set: (-0.00049920508, 0.26419306155750433)
# 68 [D loss: 0.000029, acc.: 100.00%] [G loss: 0.023968]
# Pearson R on Train set: (0.0038817665, 4.1492816334797308e-51)
# Pearson R on Val set: (-0.0016022783, 0.00033876083528871918)
# 69 [D loss: 0.000015, acc.: 100.00%] [G loss: 0.015763]
# Pearson R on Train set: (0.0030422085, 4.6424209214969881e-32)
# Pearson R on Val set: (-0.0033937718, 3.1837493683034e-14)
# 70 [D loss: 0.000017, acc.: 100.00%] [G loss: 0.018680]
# Pearson R on Train set: (0.002964163, 1.6052053276154444e-30)
# Pearson R on Val set: (-0.0044047777, 6.72671991997581e-23)
# 71 [D loss: 0.000090, acc.: 100.00%] [G loss: 0.012320]
# Pearson R on Train set: (0.0028905075, 4.184185420265189e-29)
# Pearson R on Val set: (-0.0054773493, 1.6619164217737987e-34)
# 72 [D loss: 0.000018, acc.: 100.00%] [G loss: 0.016971]
# Pearson R on Train set: (0.0026076839, 5.4095325563074569e-24)
# Pearson R on Val set: (-0.0034685193, 8.6411829833520451e-15)
# 73 [D loss: 0.000013, acc.: 100.00%] [G loss: 0.020541]
# Pearson R on Train set: (0.0038891684, 2.6896895149116705e-51)
# Pearson R on Val set: (-0.0040573291, 1.1392129861358945e-19)
# 74 [D loss: 0.000136, acc.: 100.00%] [G loss: 0.018359]
# Pearson R on Train set: (0.0096580954, 2.1577348346801149e-306)
# Pearson R on Val set: (0.011226086, 3.9312759440341511e-139)
# 75 [D loss: 0.000057, acc.: 100.00%] [G loss: 0.015048]
# Pearson R on Train set: (0.0029164033, 1.3419745004666959e-29)
# Pearson R on Val set: (0.0014895562, 0.00086353720964146602)
# 76 [D loss: 0.000120, acc.: 100.00%] [G loss: 0.017805]
# Pearson R on Train set: (0.0029309387, 7.0572526332823685e-30)
# Pearson R on Val set: (0.00051997311, 0.24483532672922928)
# 77 [D loss: 0.000217, acc.: 100.00%] [G loss: 0.019168]
# Pearson R on Train set: (-0.0017384887, 1.6412703161930694e-11)
# Pearson R on Val set: (-0.0084246928, 3.339858561439052e-79)
# 78 [D loss: 0.000008, acc.: 100.00%] [G loss: 0.015348]
# Pearson R on Train set: (0.0021463339, 9.1905318883399957e-17)
# Pearson R on Val set: (-0.0074951882, 4.4619488688973564e-63)
# 79 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.001415]
# Pearson R on Train set: (0.0027609917, 1.0630459376387081e-26)
# Pearson R on Val set: (-0.0074113281, 1.0288832683964181e-61)
# 80 [D loss: 0.000005, acc.: 100.00%] [G loss: 0.001210]
# Pearson R on Train set: (0.0022110103, 1.0774204335605866e-17)
# Pearson R on Val set: (-0.0094326884, 8.3202561747350672e-99)
# 81 [D loss: 0.000003, acc.: 100.00%] [G loss: 0.001136]
# Pearson R on Train set: (-0.00035478402, 0.1693125737293609)
# Pearson R on Val set: (-0.014268609, 1.6446880765934805e-223)
# 82 [D loss: 0.000003, acc.: 100.00%] [G loss: 0.001080]
# Pearson R on Train set: (6.5284425e-05, 0.8003387892943139)
# Pearson R on Val set: (-0.013131399, 1.2776485628535376e-189)
# 83 [D loss: 0.000004, acc.: 100.00%] [G loss: 0.000987]
# Pearson R on Train set: (0.034252308, 0.0)
# Pearson R on Val set: (0.017766152, 0.0)
# 84 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000877]
# Pearson R on Train set: (0.032897796, 0.0)
# Pearson R on Val set: (0.010498191, 6.3516728169884543e-122)
# 85 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000901]
# Pearson R on Train set: (0.026215592, 0.0)
# Pearson R on Val set: (0.009076166, 1.2751607314636438e-91)
# 86 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000782]
# Pearson R on Train set: (0.028283283, 0.0)
# Pearson R on Val set: (0.0088831345, 7.6027896126775524e-88)
# 87 [D loss: 0.000005, acc.: 100.00%] [G loss: 0.000760]
# Pearson R on Train set: (0.036727648, 0.0)
# Pearson R on Val set: (0.015839916, 5.8554135390355448e-275)
# 88 [D loss: 0.000003, acc.: 100.00%] [G loss: 0.000617]
# Pearson R on Train set: (0.031877354, 0.0)
# Pearson R on Val set: (0.0089192148, 1.5185624910807666e-88)
# 89 [D loss: 0.000007, acc.: 100.00%] [G loss: 0.000525]
# Pearson R on Train set: (0.018161688, 0.0)
# Pearson R on Val set: (0.0010671992, 0.016989889310017148)
# 90 [D loss: 0.000004, acc.: 100.00%] [G loss: 0.000460]
# Pearson R on Train set: (0.02361005, 0.0)
# Pearson R on Val set: (0.0036321059, 4.5221775215115002e-16)
# 91 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000392]
# Pearson R on Train set: (0.028888548, 0.0)
# Pearson R on Val set: (0.0080104191, 8.7513118089492059e-72)
# 92 [D loss: 0.000003, acc.: 100.00%] [G loss: 0.000369]
# Pearson R on Train set: (0.030652249, 0.0)
# Pearson R on Val set: (0.010559972, 2.437510346490092e-123)
# 93 [D loss: 0.000003, acc.: 100.00%] [G loss: 0.000319]
# Pearson R on Train set: (0.037537467, 0.0)
# Pearson R on Val set: (0.015053402, 1.550137279798488e-248)
# 94 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000283]
# Pearson R on Train set: (0.029476324, 0.0)
# Pearson R on Val set: (0.0062059099, 8.3236882041782928e-44)
# 95 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000275]
# Pearson R on Train set: (0.036444645, 0.0)
# Pearson R on Val set: (0.013034502, 7.3152693399192117e-187)
# 96 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000246]
# Pearson R on Train set: (0.039944284, 0.0)
# Pearson R on Val set: (0.012613145, 4.165053336291117e-175)
# 97 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000213]
# Pearson R on Train set: (0.0023597027, 6.1657100983147388e-20)
# Pearson R on Val set: (-0.0081123197, 1.4185158422835242e-73)
# 98 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000356]
# Pearson R on Train set: (-0.0016706891, 9.6603786188863088e-11)
# Pearson R on Val set: (-0.012645158, 5.4956128525712255e-176)
# 99 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000351]
# Pearson R on Train set: (-0.00025503704, 0.32315213207545834)
# Pearson R on Val set: (-0.011082263, 1.2185100559483811e-135)
# 100 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000338]
# Pearson R on Train set: (0.0030843501, 6.5988271224080612e-33)
# Pearson R on Val set: (-0.0067727477, 7.7775691729974337e-52)
# 101 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000312]
# Pearson R on Train set: (0.0084896227, 3.159559882686676e-237)
# Pearson R on Val set: (-9.4713316e-05, 0.83223318704866511)
# 102 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000279]
# Pearson R on Train set: (0.011703114, 0.0)
# Pearson R on Val set: (0.008385458, 1.7467922398513345e-78)
# 103 [D loss: 0.000002, acc.: 100.00%] [G loss: 0.000286]
# Pearson R on Train set: (0.0078409482, 1.1428176558529381e-202)
# Pearson R on Val set: (-0.00012808747, 0.77450758645788775)
# 104 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000274]
# Pearson R on Train set: (0.0069897929, 1.7667889003359478e-161)
# Pearson R on Val set: (-0.0024169204, 6.4535693529638003e-08)
# 105 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000262]
# Pearson R on Train set: (0.0091517735, 2.493243806255235e-275)
# Pearson R on Val set: (0.00038125055, 0.39381734113230216)
# 106 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000252]
# Pearson R on Train set: (0.0084408661, 1.5573926165027527e-234)
# Pearson R on Val set: (-0.0014577761, 0.0011121514278866036)
# 107 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000240]
# Pearson R on Train set: (0.006646723, 3.2766744752572332e-146)
# Pearson R on Val set: (-0.0038652411, 5.3742952310605078e-18)
# 108 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000229]
# Pearson R on Train set: (0.0065838601, 1.6985634837025207e-143)
# Pearson R on Val set: (-0.0044265185, 4.141311582359846e-23)
# 109 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000206]
# Pearson R on Train set: (0.0073590395, 9.0748636640765251e-179)
# Pearson R on Val set: (-0.0038853614, 3.6201074905031438e-18)
# 110 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000196]
# Pearson R on Train set: (0.006897531, 2.6828424088584011e-157)
# Pearson R on Val set: (-0.0050290064, 2.3668977799285336e-29)
# 111 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000179]
# Pearson R on Train set: (0.0066507212, 2.1973935991140989e-146)
# Pearson R on Val set: (-0.0059268726, 4.1477673447301636e-40)
# 112 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000171]
# Pearson R on Train set: (0.0061375103, 5.8275704939735971e-125)
# Pearson R on Val set: (-0.0071038338, 7.573687167911261e-57)
# 113 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000154]
# Pearson R on Train set: (0.0055884281, 6.1487827579897386e-104)
# Pearson R on Val set: (-0.0080962861, 2.7227781661629115e-73)
# 114 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000146]
# Pearson R on Train set: (0.0026855383, 2.3858216522944665e-25)
# Pearson R on Val set: (-0.011926343, 9.0057459374684122e-157)
# 115 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000138]
# Pearson R on Train set: (-0.0026758171, 3.5402334602984082e-25)
# Pearson R on Val set: (-0.016485026, 1.235914639601086e-297)
# 116 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000119]
# Pearson R on Train set: (0.0016661893, 1.084045783576923e-10)
# Pearson R on Val set: (-0.01104591, 9.1447560803152562e-135)
# 117 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000106]
# Pearson R on Train set: (0.016236104, 0.0)
# Pearson R on Val set: (0.00050412532, 0.25951421831692434)
# 118 [D loss: 0.000001, acc.: 100.00%] [G loss: 0.000096]
# Pearson R on Train set: (0.025072975, 0.0)
# Pearson R on Val set: (0.0082596894, 3.3341120105858796e-76)
# 119 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000084]
# Pearson R on Train set: (0.039217666, 0.0)
# Pearson R on Val set: (0.020899888, 0.0)
# 120 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000073]
# Pearson R on Train set: (0.017870571, 0.0)
# Pearson R on Val set: (0.011804447, 1.2638069299394509e-153)
# 121 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000083]
# Pearson R on Train set: (0.023638509, 0.0)
# Pearson R on Val set: (0.017172642, 8.3991159793011913e-323)
# 122 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000077]
# Pearson R on Train set: (0.025208397, 0.0)
# Pearson R on Val set: (0.018329544, 0.0)
# 123 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000072]
# Pearson R on Train set: (0.040317319, 0.0)
# Pearson R on Val set: (0.028279703, 0.0)
# 124 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000062]
# Pearson R on Train set: (0.07919433, 0.0)
# Pearson R on Val set: (0.070807762, 0.0)
# 125 [D loss: 0.002883, acc.: 99.96%] [G loss: 0.070543]
# Pearson R on Train set: (0.005710491, 1.9265637205990953e-108)
# Pearson R on Val set: (-0.00021917847, 0.62397797597995697)
# 126 [D loss: 0.000135, acc.: 100.00%] [G loss: 0.088549]
# Pearson R on Train set: (0.00099258276, 0.0001204452726083238)
# Pearson R on Val set: (-0.0015388527, 0.00057777070778726859)
# 127 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.003004]
# Pearson R on Train set: (0.0045338445, 4.6495635714060882e-69)
# Pearson R on Val set: (-0.013345704, 8.6012245698011247e-196)
# 128 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.002588]
# Pearson R on Train set: (-0.0037020589, 1.2017358290082182e-46)
# Pearson R on Val set: (-0.013469697, 2.0802923656652421e-199)
# 129 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000049]
# Pearson R on Train set: (-0.0010166293, 8.2035936321672332e-05)
# Pearson R on Val set: (-0.01340042, 2.2020216567669296e-197)
# 130 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.001948]
# Pearson R on Train set: (-0.0010224731, 7.4632827772911928e-05)
# Pearson R on Val set: (-0.013424886, 4.2554642508414844e-198)
# 131 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.001032544, 6.3335554362628477e-05)
# Pearson R on Val set: (-0.013465973, 2.6744679158575499e-199)
# 132 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.0010421013, 5.4127392682166438e-05)
# Pearson R on Val set: (-0.013503726, 2.0882742080453474e-200)
# 133 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.0010544587, 4.4091528794331201e-05)
# Pearson R on Val set: (-0.013547041, 1.1101287809956449e-201)
# 134 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.0010655023, 3.6640174114407376e-05)
# Pearson R on Val set: (-0.01358821, 6.7657498374540745e-203)
# 135 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.0010770011, 3.0160531226810719e-05)
# Pearson R on Val set: (-0.013638837, 2.1431668477671404e-204)
# 136 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.0010926337, 2.3078861721765777e-05)
# Pearson R on Val set: (-0.013695502, 4.4302027073500519e-206)
# 137 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.0011104584, 1.6936809368927939e-05)
# Pearson R on Val set: (-0.013762186, 4.5181773490283513e-208)
# 138 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.0011264731, 1.2776222692645089e-05)
# Pearson R on Val set: (-0.013791168, 6.1156529666899462e-209)
# 139 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.0011411186, 9.8409418664631882e-06)
# Pearson R on Val set: (-0.013848464, 1.1588996659995783e-210)
# 140 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.0011613315, 6.8292104400152283e-06)
# Pearson R on Val set: (-0.013917843, 9.3083925793457268e-213)
# 141 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.0011827383, 4.6083159214447482e-06)
# Pearson R on Val set: (-0.013993502, 4.7004765022412108e-215)
# 142 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.0012083519, 2.8534243438772207e-06)
# Pearson R on Val set: (-0.014085542, 7.266928212892976e-218)
# 143 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.0012314799, 1.8359146875175781e-06)
# Pearson R on Val set: (-0.014170508, 1.7794984201911629e-220)
# 144 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.0012528981, 1.2119853876073665e-06)
# Pearson R on Val set: (-0.014239542, 1.310020718351978e-222)
# 145 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.0012765769, 7.5988244176286377e-07)
# Pearson R on Val set: (-0.014322056, 3.5826586238695391e-225)
# 146 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.0013116172, 3.7517022934964808e-07)
# Pearson R on Val set: (-0.014440796, 6.9161503395401471e-229)
# 147 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.0013518922, 1.6306020459341128e-07)
# Pearson R on Val set: (-0.01456252, 1.0009810660155852e-232)
# 148 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.001392153, 6.923880329922834e-08)
# Pearson R on Val set: (-0.014686368, 1.1506757291351601e-236)
# 149 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.0014482229, 2.019204898941569e-08)
# Pearson R on Val set: (-0.014864134, 2.2295240864092304e-242)
# 150 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.0015203301, 3.8692567623883033e-09)
# Pearson R on Val set: (-0.015078711, 2.2962675819631027e-249)
# 151 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.0015944113, 6.5465427158039236e-10)
# Pearson R on Val set: (-0.015288003, 2.8158973052425584e-256)
# 152 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.0016535327, 1.4967180704956306e-10)
# Pearson R on Val set: (-0.015460701, 4.7313487211994117e-262)
# 153 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.0016914899, 5.6485486408322686e-11)
# Pearson R on Val set: (-0.015571222, 8.8188692735930125e-266)
# 154 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000048]
# Pearson R on Train set: (-0.0017644801, 8.1710840378008291e-12)
# Pearson R on Val set: (-0.015765738, 2.0746650195580757e-272)
# 155 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.001830115, 1.3432344635479773e-12)
# Pearson R on Val set: (-0.01594525, 1.3391363536704252e-278)
# 156 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.001862257, 5.4212527494062791e-13)
# Pearson R on Val set: (-0.016034452, 1.0588493588089867e-281)
# 157 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.0019881516, 1.3394272362491984e-14)
# Pearson R on Val set: (-0.016369566, 1.6474829699615406e-293)
# 158 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.0021236835, 1.9187197517867647e-16)
# Pearson R on Val set: (-0.016709812, 9.5139886949206015e-306)
# 159 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000046]
# Pearson R on Train set: (-0.0022287348, 5.9232434773381206e-18)
# Pearson R on Val set: (-0.016979633, 1.2422619456624315e-315)
# 160 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.0023557446, 7.1042781313858044e-20)
# Pearson R on Val set: (-0.017304724, 0.0)
# 161 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000046]
# Pearson R on Train set: (-0.0023832715, 2.6391819380774295e-20)
# Pearson R on Val set: (-0.017389612, 0.0)
# 162 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.0025081278, 2.5674733934535968e-22)
# Pearson R on Val set: (-0.017662341, 0.0)
# 163 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.0026040853, 6.2354658415309572e-24)
# Pearson R on Val set: (-0.017851779, 0.0)
# 164 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000047]
# Pearson R on Train set: (-0.0027351293, 3.1174061953512554e-26)
# Pearson R on Val set: (-0.01808612, 0.0)
# 165 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000046]
# Pearson R on Train set: (-0.0029072291, 2.0100380283622261e-29)
# Pearson R on Val set: (-0.018413508, 0.0)
# 166 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000045]
# Pearson R on Train set: (-0.003135703, 5.9081396788407972e-34)
# Pearson R on Val set: (-0.01878643, 0.0)
# 167 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000046]
# Pearson R on Train set: (-0.0033428872, 2.3428868768853035e-38)
# Pearson R on Val set: (-0.019130953, 0.0)
# 168 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000045]
# Pearson R on Train set: (-0.0034126344, 6.6891784771291626e-40)
# Pearson R on Val set: (-0.019195549, 0.0)
# 169 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000045]
# Pearson R on Train set: (-0.0035625782, 2.5030533229946443e-43)
# Pearson R on Val set: (-0.019405881, 0.0)
# 170 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000044]
# Pearson R on Train set: (-0.0038628769, 1.2497542599087908e-50)
# Pearson R on Val set: (-0.019780947, 0.0)
# 171 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000045]
# Pearson R on Train set: (-0.0039674416, 2.6123346416142033e-53)
# Pearson R on Val set: (-0.019919856, 0.0)
# 172 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000044]
# Pearson R on Train set: (-0.0042304886, 2.3001727207810374e-60)
# Pearson R on Val set: (-0.020195521, 0.0)
# 173 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000044]
# Pearson R on Train set: (-0.0048035653, 2.7222483986050514e-77)
# Pearson R on Val set: (-0.020644821, 0.0)
# 174 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000045]
# Pearson R on Train set: (-0.004534205, 4.5365608093820011e-69)
# Pearson R on Val set: (-0.020259788, 0.0)
# 175 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000044]
# Pearson R on Train set: (-0.0050061871, 8.6983219928458106e-84)
# Pearson R on Val set: (-0.02063543, 0.0)
# 176 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000044]
# Pearson R on Train set: (-0.0054406775, 1.2912108100315648e-98)
# Pearson R on Val set: (-0.020529613, 0.0)
# 177 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000044]
# Pearson R on Train set: (-0.0057047922, 3.1420944048071805e-108)
# Pearson R on Val set: (-0.02076479, 0.0)
# 178 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000045]
# Pearson R on Train set: (-0.0058886334, 3.4478252618261149e-115)
# Pearson R on Val set: (-0.021242622, 0.0)
# 179 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000044]
# Pearson R on Train set: (-0.0050885268, 1.67335987689004e-86)
# Pearson R on Val set: (-0.020923365, 0.0)
# 180 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000044]
# Pearson R on Train set: (-0.0060791974, 1.2338819598954987e-122)
# Pearson R on Val set: (-0.021929879, 0.0)
# 181 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000043]
# Pearson R on Train set: (-0.0055731493, 2.2168599658447036e-103)
# Pearson R on Val set: (-0.021386947, 0.0)
# 182 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000043]
# Pearson R on Train set: (-0.0059961169, 2.3264168146125282e-119)
# Pearson R on Val set: (-0.022002386, 0.0)
# 183 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000042]
# Pearson R on Train set: (0.0024752161, 8.9045688891300567e-22)
# Pearson R on Val set: (0.0114209, 6.2210216054614027e-144)
# 184 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000045]
# Pearson R on Train set: (0.0024018898, 1.3422321918019953e-20)
# Pearson R on Val set: (0.011153727, 2.2732895076753851e-137)
# 185 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000040]
# Pearson R on Train set: (0.002345385, 1.0282579130542797e-19)
# Pearson R on Val set: (0.010878262, 9.1399536786331039e-131)
# 186 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000039]
# Pearson R on Train set: (0.0022669889, 1.6028579866105141e-18)
# Pearson R on Val set: (0.010564107, 1.9583055636729732e-123)
# 187 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000040]
# Pearson R on Train set: (0.0022200022, 7.9583674620782565e-18)
# Pearson R on Val set: (0.010319344, 7.1639780371528005e-118)
# 188 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000040]
# Pearson R on Train set: (0.0019371234, 6.1744371529360541e-14)
# Pearson R on Val set: (0.0085795522, 4.5205602564653274e-82)
# 189 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000039]
# Pearson R on Train set: (0.0019900899, 1.2629316256195913e-14)
# Pearson R on Val set: (0.0089744078, 1.2760558594051999e-89)
# 190 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000039]
# Pearson R on Train set: (0.0019775948, 1.8432837210748391e-14)
# Pearson R on Val set: (0.0087049194, 1.9719059957399304e-84)
# 191 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000038]
# Pearson R on Train set: (0.0016813419, 7.3448457349199475e-11)
# Pearson R on Val set: (0.0060124081, 3.1789052560218729e-41)
# 192 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000037]
# Pearson R on Train set: (0.0016842867, 6.8069980273093607e-11)
# Pearson R on Val set: (0.0059121242, 6.4352057126450623e-40)
# 193 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000037]
# Pearson R on Train set: (0.0017184952, 2.7876850197441917e-11)
# Pearson R on Val set: (0.00609056, 2.9458595798613095e-42)
# 194 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000037]
# Pearson R on Train set: (0.0017910342, 3.9660841461070061e-12)
# Pearson R on Val set: (0.0065387958, 1.9457273141105723e-48)
# 195 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000037]
# Pearson R on Train set: (0.0017950688, 3.5503476506515166e-12)
# Pearson R on Val set: (0.0064612753, 2.4489562728238315e-47)
# 196 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000036]
# Pearson R on Train set: (0.0018719694, 4.1089094392343506e-13)
# Pearson R on Val set: (0.006858658, 4.1043012633502205e-53)
# 197 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000035]
# Pearson R on Train set: (0.0019825529, 1.5869075185314716e-14)
# Pearson R on Val set: (0.0073028496, 5.6585625082271059e-60)
# 198 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000035]
# Pearson R on Train set: (0.0021025452, 3.7876034039042285e-16)
# Pearson R on Val set: (0.0079373047, 1.6320041658044836e-70)
# 199 [D loss: 0.000000, acc.: 100.00%] [G loss: 0.000032]
